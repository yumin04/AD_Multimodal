# %% [markdown]
# ## Imports

# %%
import keras
import numpy as np

import time

import os

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow.keras.layers as tfl

# import misc

import pandas as pd

import datetime

import glob

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, GlobalAveragePooling2D, Input, Conv1D, MaxPooling1D, Flatten, \
                                    Masking, LSTM, Softmax, Multiply, Layer, Concatenate, Lambda, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# from keras.utils import np_utils
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.datasets import load_files
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
# import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.preprocessing import image_dataset_from_directory

from sklearn.model_selection import train_test_split

import tensorly as tl
from tensorly.decomposition import tucker
# Out:
# 2025-03-15 11:04:06.647030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742061846.665769   46172 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742061846.671574   46172 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-15 11:04:06.691053: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set up imports & packages.

tl.set_backend('tensorflow')  # Use TensorFlow tensors instead of NumPy

# %% [markdown]
# ## Declare Sub-Models

# %%
# Default 16.
feature_vector_size = 512

# %% [markdown]
# ### Visual Embedder (VGG-16)

# %%
def build_visual_embedder():
    # Load the VGG16 model without the top layers
    visual_base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze the base model to retain pretrained weights during training
    visual_base_model.trainable = False

    # Add a top for 3-way classification
    x = visual_base_model.output
    x = GlobalAveragePooling2D()(x)  # Global Average Pooling layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(256, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization

    visual_base_features = Dense(feature_vector_size, activation='relu')(x) 

    # Define the final model
    visual_model = Model(inputs=visual_base_model.input, outputs=visual_base_features, name="VisualEmbedder")
    return visual_model

# %% [markdown]
# ### Demographic Embedder

# %%
def build_demographics_embedder():
    # Input layer for demographics data
    input_layer = Input(shape=(6, ), name="demographics_input")

    x = Dense(16, activation='relu')(input_layer)
    x = Dropout(0.1)(x)
    x = Dense(4, activation='relu')(x)
    x = Dropout(0.1)(x)
    
    # Classification head
    demographics_base_features = Dense(feature_vector_size, activation='relu')(x)
    
    # Define the model
    demographics_model = Model(inputs=input_layer, outputs=demographics_base_features, name="DemographicsEmbedder")
    return demographics_model

# %% [markdown]
# ### Time-Series Embedder

# %%
max_seq_length = 6

# %%
def build_time_embedder():
    # Input layer for time series data (4 input variables)
    time_series_input = Input(shape=(max_seq_length, 4), name="time_series_input")
    masked_input = Masking(mask_value=0.0)(time_series_input)

    # Use the last hidden state
    x = LSTM(32, return_sequences=False)(masked_input)

    # Dense layer to create time series output
    time_base_features = Dense(feature_vector_size, activation="relu")(x)
    
    # Define the model
    time_model = Model(inputs=time_series_input, outputs=time_base_features, name="TimeSeriesEmbedder")
    return time_model

# %% [markdown]
# ## Joint Model

# %%
visual_dim = feature_vector_size
demographics_dim = feature_vector_size
time_dim = feature_vector_size

# Tensor Fusion Layer
def tensor_fusion_layer(inputs):
    """
    Tensor fusion using Kronecker product via `tf.einsum`.
    Adds a 1 to each input tensor for core (0,0,0) alignment.
    """
    visual, demographics, time_series = inputs

    # Add a "1" to the feature vectors
    visual_h = tf.concat([tf.ones((tf.shape(visual)[0], 1)), visual], axis=1)
    demographics_h = tf.concat([tf.ones((tf.shape(demographics)[0], 1)), demographics], axis=1)
    time_series_h = tf.concat([tf.ones((tf.shape(time_series)[0], 1)), time_series], axis=1)

    # Perform Kronecker product using tf.einsum
    outer_xy = tf.einsum('bi,bj->bij', demographics_h, time_series_h)  # Shape: (batch_size, d_dim, t_dim)
    outer_xyz = tf.einsum('bij,bk->bijk', outer_xy, visual_h)  # Shape: (batch_size, d_dim, t_dim, v_dim)

    # core, factors = tucker(outer_xyz, rank=(8,8,8))

    # # Flatten the fused tensor
    fused_tensor = tf.reshape(outer_xyz, (tf.shape(outer_xyz)[0], -1))  # Shape: (batch_size, d_dim * t_dim * v_dim)

    return fused_tensor #outer_xyz

# %%
# Visual embedder
visual_embedder = build_visual_embedder()

# Demographics embedder
demographics_embedder = build_demographics_embedder()

# Time Series Embedder
time_embedder = build_time_embedder()

# Outputs from embedders
visual_features = visual_embedder.output
demographics_features = demographics_embedder.output
time_features = time_embedder.output

# Output shape of the fused tensor
fused_tensor_shape = (None, (visual_dim + 1) * (demographics_dim + 1) * (time_dim + 1))

# Apply Tensor Fusion
fused_features = Lambda(tensor_fusion_layer, output_shape=fused_tensor_shape)([visual_features, demographics_features, time_features])

# Add final classification layers
x = Dense(128, activation='relu')(fused_features)
x = Dense(64, activation='relu')(x)
final_output = Dense(3, activation='softmax', name="final_output")(x)

# Define the combined model
combined_model = Model(inputs=[visual_embedder.input, demographics_embedder.input, time_embedder.input], 
                       outputs=final_output, name="CombinedModel")
# Out:
# W0000 00:00:1742061849.338174   46172 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# #### Joint-Model Structure

# %%
combined_model.summary()
# Out:
# Model: "CombinedModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ demographics_input  │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    262,656 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │        112 │ demographics_inp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_series_input   │ (None, 6, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 6, 4)      │          0 │ time_series_inpu… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4)         │         68 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 6, 4)      │          0 │ time_series_inpu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 6)         │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4)         │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 32)        │      4,736 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │     65,792 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │      1,280 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │      8,448 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, None,      │          0 │ dense_3[0][0],    │
# │                     │ 16974593)         │            │ dense_6[0][0],    │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, None, 128) │ 2,172,748… │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, None, 64)  │      8,256 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, None, 3)   │        195 │ dense_9[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,188,208,247 (8.15 GB)
#  Trainable params: 2,173,493,559 (8.10 GB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# # Train Joint-Model

# %% [markdown]
# #### Load Data

# %%
# Mapping for string labels to integers
label_mapping = {"CN": 0, "MCI": 1, "Dementia": 2}

# %%
manifest = pd.read_csv("/home/mason/TFN_AD/AD_Patient_Manifest.csv")

# %%
# Load all data into memory. Not elegant, but works.
def load_all_data(manifest, target_size=(224, 224), demographic_columns=None, time_series_columns=None, label_mapping=None):
    image_data = []
    demographics_data = []
    time_series_data = []
    labels = []
    label_mapping = label_mapping or {}

    for _, row in manifest.iterrows():
        patient_path = row["path"]
        patient_df = pd.read_pickle(patient_path)

        # Load image data
        image_paths = [patient_df['image_path'].iloc[0]]
        for path in image_paths:
            img = load_img(path, target_size=target_size)
            img_array = img_to_array(img)
            img_array = preprocess_input(img_array)
            image_data.append(img_array)

        # Process demographics data
        if demographic_columns is None:
            raise ValueError("Please specify the demographics columns.")
        
        # Get first row of demographic data (since it doesn't change over time)
        demographics = patient_df[demographic_columns].iloc[0]
        demographics = demographics.values.astype(np.float32)  # Convert to NumPy array
        demographics_data.append(demographics)

        # Process time series data
        if time_series_columns is None:
            raise ValueError("Please specify the time series columns.")
        
        # Extract the relevant time series columns
        time_series = patient_df[time_series_columns].values  # Extract as NumPy array

        # Truncate or pad to max_seq_length
        if len(time_series) > max_seq_length:
            time_series = time_series[:max_seq_length, :]
        elif len(time_series) < max_seq_length:
            padding = np.zeros((max_seq_length - len(time_series), len(time_series_columns)))
            time_series = np.vstack([time_series, padding])
        time_series_data.append(time_series)

        # Load labels
        label_str = patient_df['DX'].iloc[0]
        label_int = label_mapping[label_str]
        labels.append(label_int)

    # Convert to numpy arrays
    image_data = np.array(image_data, dtype=np.float32)
    demographics_data = np.array(demographics_data, dtype=np.float32)
    time_series_data = np.array(time_series_data, dtype=np.float32)
    labels = np.array(labels, dtype=np.int32)

    return image_data, demographics_data, time_series_data, labels

# %%
# Demographic variables to extract
demographic_columns = ['AGE', 'PTEDUCAT', 'PTGENDER_encoded', 
                        'PTETHCAT_encoded', 'PTRACCAT_encoded', 'PTMARRY_encoded']
# Time series variables to extract
time_series_columns = ['Years_bl', 'ADAS11', 'ADAS13', 'ADASQ4']

# Load all data into memory
image_data, demographics_data, time_series_data, labels = load_all_data(manifest, target_size=(224, 224), demographic_columns=demographic_columns, 
                                                      time_series_columns=time_series_columns, label_mapping=label_mapping)

# Split the data
test_size = 0.2  # 20% of the data for testing

(image_train, image_test,
 demographics_train, demographics_test,
 time_train, time_test,
 labels_train, labels_test) = train_test_split(
    image_data, demographics_data, time_series_data, labels, test_size=test_size, random_state=42, stratify=labels
)

# %%
batch_size = 64

# Create training dataset
train_dataset = tf.data.Dataset.from_tensor_slices(((image_train, demographics_train, time_train), labels_train))
train_dataset = train_dataset.shuffle(100).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Create testing (validation) dataset
test_dataset = tf.data.Dataset.from_tensor_slices(((image_test, demographics_test, time_test), labels_test))
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
print(f"Image train shape: {image_train.shape}")
print(f"Demographics train shape: {demographics_train.shape}")
print(f"Time train shape: {time_train.shape}")
print(f"Labels train shape: {labels_train.shape}")
# Out:
# Image train shape: (305, 224, 224, 3)
# Demographics train shape: (305, 6)
# Time train shape: (305, 6, 4)
# Labels train shape: (305,)

# %% [markdown]
# #### Train the Model

# %%
# Compile the model
combined_model.compile(optimizer=Adam(learning_rate=0.0001),
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

# %%
print("Model inputs:", combined_model.input)
# Out:
# Model inputs: [<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>, <KerasTensor shape=(None, 6), dtype=float32, sparse=False, name=demographics_input>, <KerasTensor shape=(None, 6, 4), dtype=float32, sparse=False, name=time_series_input>]

# %%
# Early stopping to prevent redundant training.
early_stopping = EarlyStopping(monitor='val_accuracy', patience=100, restore_best_weights=True)

# %%
# Train the model
history = combined_model.fit(
    train_dataset, 
    validation_data=test_dataset,
    epochs=600,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/600
# /home/mason/.conda/envs/LOSresearch/lib/python3.9/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'demographics_input', 'time_series_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.5023 - loss: 29.9003 - val_accuracy: 0.7143 - val_loss: 2.6702
# Epoch 2/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 6s/step - accuracy: 0.5456 - loss: 13.2291 - val_accuracy: 0.6494 - val_loss: 5.3123
# Epoch 3/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.6431 - loss: 7.7806 - val_accuracy: 0.7532 - val_loss: 3.3413
# Epoch 4/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.6998 - loss: 4.3720 - val_accuracy: 0.7792 - val_loss: 2.2080
# Epoch 5/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.7590 - loss: 3.0391 - val_accuracy: 0.7792 - val_loss: 1.2131
# Epoch 6/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.7568 - loss: 1.6999 - val_accuracy: 0.7273 - val_loss: 1.2628
# Epoch 7/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.7508 - loss: 1.6007 - val_accuracy: 0.7662 - val_loss: 0.9751
# Epoch 8/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.7211 - loss: 1.6494 - val_accuracy: 0.7143 - val_loss: 1.4504
# Epoch 9/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.7448 - loss: 1.4648 - val_accuracy: 0.8312 - val_loss: 0.5964
# Epoch 10/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.7196 - loss: 1.4668 - val_accuracy: 0.8182 - val_loss: 0.9595
# Epoch 11/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8221 - loss: 0.9236 - val_accuracy: 0.7922 - val_loss: 0.6955
# Epoch 12/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8386 - loss: 0.6956 - val_accuracy: 0.7532 - val_loss: 0.8063
# Epoch 13/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8018 - loss: 0.8753 - val_accuracy: 0.7662 - val_loss: 0.8231
# Epoch 14/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8318 - loss: 0.7079 - val_accuracy: 0.7792 - val_loss: 0.5589
# Epoch 15/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8049 - loss: 0.8022 - val_accuracy: 0.7532 - val_loss: 0.5797
# Epoch 16/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8145 - loss: 0.5661 - val_accuracy: 0.7922 - val_loss: 0.6053
# Epoch 17/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8064 - loss: 0.6400 - val_accuracy: 0.7792 - val_loss: 0.4115
# Epoch 18/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8295 - loss: 0.5576 - val_accuracy: 0.7792 - val_loss: 0.5527
# Epoch 19/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8377 - loss: 0.5039 - val_accuracy: 0.8182 - val_loss: 0.4353
# Epoch 20/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8666 - loss: 0.3536 - val_accuracy: 0.8182 - val_loss: 0.4547
# Epoch 21/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8521 - loss: 0.4871 - val_accuracy: 0.7532 - val_loss: 0.5048
# Epoch 22/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8508 - loss: 0.4125 - val_accuracy: 0.8052 - val_loss: 0.5727
# Epoch 23/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.8595 - loss: 0.4290 - val_accuracy: 0.8571 - val_loss: 0.4498
# Epoch 24/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8603 - loss: 0.4791 - val_accuracy: 0.8442 - val_loss: 0.5788
# Epoch 25/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8456 - loss: 0.4519 - val_accuracy: 0.8182 - val_loss: 0.5033
# Epoch 26/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8625 - loss: 0.4633 - val_accuracy: 0.8182 - val_loss: 0.5093
# Epoch 27/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8607 - loss: 0.4713 - val_accuracy: 0.7662 - val_loss: 0.4814
# Epoch 28/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8871 - loss: 0.3372 - val_accuracy: 0.8182 - val_loss: 0.4894
# Epoch 29/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8575 - loss: 0.4293 - val_accuracy: 0.8052 - val_loss: 0.6609
# Epoch 30/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8954 - loss: 0.3817 - val_accuracy: 0.8312 - val_loss: 0.5263
# Epoch 31/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9082 - loss: 0.2862 - val_accuracy: 0.7922 - val_loss: 0.7715
# Epoch 32/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8839 - loss: 0.4114 - val_accuracy: 0.8052 - val_loss: 0.4341
# Epoch 33/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9436 - loss: 0.1718 - val_accuracy: 0.8312 - val_loss: 0.5161
# Epoch 34/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9141 - loss: 0.2803 - val_accuracy: 0.8442 - val_loss: 0.4299
# Epoch 35/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8823 - loss: 0.3211 - val_accuracy: 0.8312 - val_loss: 0.5063
# Epoch 36/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8969 - loss: 0.3122 - val_accuracy: 0.8571 - val_loss: 0.4163
# Epoch 37/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.8977 - loss: 0.3265 - val_accuracy: 0.8701 - val_loss: 0.4106
# Epoch 38/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8747 - loss: 0.4071 - val_accuracy: 0.8312 - val_loss: 0.4986
# Epoch 39/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9023 - loss: 0.3570 - val_accuracy: 0.8571 - val_loss: 0.3984
# Epoch 40/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8836 - loss: 0.3760 - val_accuracy: 0.8571 - val_loss: 0.4273
# Epoch 41/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9119 - loss: 0.2634 - val_accuracy: 0.8442 - val_loss: 0.3871
# Epoch 42/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8669 - loss: 0.4309 - val_accuracy: 0.8052 - val_loss: 0.5405
# Epoch 43/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8721 - loss: 0.3459 - val_accuracy: 0.8442 - val_loss: 0.4029
# Epoch 44/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8728 - loss: 0.2916 - val_accuracy: 0.8312 - val_loss: 0.7478
# Epoch 45/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9166 - loss: 0.2526 - val_accuracy: 0.8312 - val_loss: 0.4207
# Epoch 46/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9219 - loss: 0.2386 - val_accuracy: 0.8182 - val_loss: 0.7526
# Epoch 47/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9069 - loss: 0.3442 - val_accuracy: 0.8571 - val_loss: 0.4766
# Epoch 48/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9188 - loss: 0.2780 - val_accuracy: 0.8182 - val_loss: 0.6199
# Epoch 49/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9145 - loss: 0.2499 - val_accuracy: 0.8571 - val_loss: 0.3549
# Epoch 50/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9049 - loss: 0.3171 - val_accuracy: 0.8442 - val_loss: 0.5672
# Epoch 51/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9269 - loss: 0.2585 - val_accuracy: 0.8312 - val_loss: 0.4538
# Epoch 52/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9128 - loss: 0.2154 - val_accuracy: 0.8312 - val_loss: 0.5176
# Epoch 53/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9321 - loss: 0.2482 - val_accuracy: 0.8442 - val_loss: 0.4933
# Epoch 54/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9345 - loss: 0.1961 - val_accuracy: 0.8442 - val_loss: 0.6022
# Epoch 55/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9004 - loss: 0.2495 - val_accuracy: 0.8312 - val_loss: 0.5974
# Epoch 56/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9021 - loss: 0.2955 - val_accuracy: 0.8312 - val_loss: 0.5785
# Epoch 57/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9219 - loss: 0.2162 - val_accuracy: 0.8312 - val_loss: 0.4786
# Epoch 58/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9406 - loss: 0.1630 - val_accuracy: 0.8442 - val_loss: 0.5146
# Epoch 59/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9599 - loss: 0.1305 - val_accuracy: 0.8312 - val_loss: 0.4929
# Epoch 60/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9380 - loss: 0.1801 - val_accuracy: 0.8312 - val_loss: 0.6019
# Epoch 61/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9167 - loss: 0.1995 - val_accuracy: 0.8052 - val_loss: 0.5444
# Epoch 62/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9252 - loss: 0.1947 - val_accuracy: 0.8052 - val_loss: 0.8044
# Epoch 63/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9526 - loss: 0.1486 - val_accuracy: 0.8052 - val_loss: 0.4470
# Epoch 64/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9078 - loss: 0.2698 - val_accuracy: 0.8052 - val_loss: 0.8851
# Epoch 65/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.8778 - loss: 0.4329 - val_accuracy: 0.8182 - val_loss: 0.4757
# Epoch 66/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9223 - loss: 0.2984 - val_accuracy: 0.8182 - val_loss: 0.7106
# Epoch 67/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9163 - loss: 0.3174 - val_accuracy: 0.8182 - val_loss: 0.4424
# Epoch 68/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9426 - loss: 0.1799 - val_accuracy: 0.8052 - val_loss: 0.6824
# Epoch 69/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9232 - loss: 0.1966 - val_accuracy: 0.8182 - val_loss: 0.4478
# Epoch 70/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9372 - loss: 0.2225 - val_accuracy: 0.8182 - val_loss: 0.5813
# Epoch 71/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9319 - loss: 0.2448 - val_accuracy: 0.8701 - val_loss: 0.3421
# Epoch 72/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.9602 - loss: 0.1532 - val_accuracy: 0.8831 - val_loss: 0.4243
# Epoch 73/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9563 - loss: 0.1181 - val_accuracy: 0.8312 - val_loss: 0.6792
# Epoch 74/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9439 - loss: 0.1706 - val_accuracy: 0.8571 - val_loss: 0.4868
# Epoch 75/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9591 - loss: 0.1086 - val_accuracy: 0.8182 - val_loss: 0.5828
# Epoch 76/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9687 - loss: 0.1362 - val_accuracy: 0.8831 - val_loss: 0.3673
# Epoch 77/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9378 - loss: 0.1634 - val_accuracy: 0.8312 - val_loss: 0.6746
# Epoch 78/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9450 - loss: 0.1373 - val_accuracy: 0.8701 - val_loss: 0.4431
# Epoch 79/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9641 - loss: 0.1962 - val_accuracy: 0.8571 - val_loss: 0.5010
# Epoch 80/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9526 - loss: 0.1396 - val_accuracy: 0.8831 - val_loss: 0.4853
# Epoch 81/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9471 - loss: 0.2026 - val_accuracy: 0.8831 - val_loss: 0.5126
# Epoch 82/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9478 - loss: 0.1488 - val_accuracy: 0.8571 - val_loss: 0.4984
# Epoch 83/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9484 - loss: 0.1417 - val_accuracy: 0.8442 - val_loss: 0.4780
# Epoch 84/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9565 - loss: 0.1238 - val_accuracy: 0.8571 - val_loss: 0.4697
# Epoch 85/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9613 - loss: 0.1133 - val_accuracy: 0.8571 - val_loss: 0.4330
# Epoch 86/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9499 - loss: 0.1520 - val_accuracy: 0.8701 - val_loss: 0.4204
# Epoch 87/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9496 - loss: 0.1783 - val_accuracy: 0.8571 - val_loss: 0.4115
# Epoch 88/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9476 - loss: 0.1614 - val_accuracy: 0.8182 - val_loss: 0.5302
# Epoch 89/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9467 - loss: 0.1316 - val_accuracy: 0.8182 - val_loss: 0.5348
# Epoch 90/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9645 - loss: 0.1115 - val_accuracy: 0.8182 - val_loss: 0.6714
# Epoch 91/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9315 - loss: 0.1466 - val_accuracy: 0.8571 - val_loss: 0.4061
# Epoch 92/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9558 - loss: 0.1260 - val_accuracy: 0.8052 - val_loss: 0.7811
# Epoch 93/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9454 - loss: 0.1850 - val_accuracy: 0.8182 - val_loss: 0.4767
# Epoch 94/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9582 - loss: 0.1649 - val_accuracy: 0.8571 - val_loss: 0.4535
# Epoch 95/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9530 - loss: 0.1014 - val_accuracy: 0.8182 - val_loss: 0.6013
# Epoch 96/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9421 - loss: 0.1480 - val_accuracy: 0.8701 - val_loss: 0.4553
# Epoch 97/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9522 - loss: 0.1204 - val_accuracy: 0.8052 - val_loss: 0.8888
# Epoch 98/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9315 - loss: 0.1899 - val_accuracy: 0.8442 - val_loss: 0.5621
# Epoch 99/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9469 - loss: 0.1400 - val_accuracy: 0.8052 - val_loss: 0.9594
# Epoch 100/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9152 - loss: 0.2295 - val_accuracy: 0.8442 - val_loss: 0.5162
# Epoch 101/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9498 - loss: 0.1671 - val_accuracy: 0.8701 - val_loss: 0.5734
# Epoch 102/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.9513 - loss: 0.1943 - val_accuracy: 0.8961 - val_loss: 0.4214
# Epoch 103/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9574 - loss: 0.0972 - val_accuracy: 0.8831 - val_loss: 0.4380
# Epoch 104/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.9637 - loss: 0.1454 - val_accuracy: 0.9221 - val_loss: 0.3634
# Epoch 105/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9809 - loss: 0.0559 - val_accuracy: 0.8961 - val_loss: 0.3976
# Epoch 106/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9770 - loss: 0.0787 - val_accuracy: 0.8831 - val_loss: 0.4487
# Epoch 107/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9476 - loss: 0.1240 - val_accuracy: 0.8442 - val_loss: 0.4818
# Epoch 108/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9513 - loss: 0.1300 - val_accuracy: 0.8312 - val_loss: 0.5145
# Epoch 109/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9680 - loss: 0.0893 - val_accuracy: 0.9091 - val_loss: 0.4120
# Epoch 110/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9782 - loss: 0.0586 - val_accuracy: 0.8961 - val_loss: 0.4471
# Epoch 111/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9593 - loss: 0.0989 - val_accuracy: 0.8831 - val_loss: 0.4828
# Epoch 112/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9693 - loss: 0.0889 - val_accuracy: 0.8701 - val_loss: 0.5243
# Epoch 113/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9878 - loss: 0.0667 - val_accuracy: 0.8701 - val_loss: 0.5105
# Epoch 114/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9784 - loss: 0.0697 - val_accuracy: 0.8701 - val_loss: 0.5647
# Epoch 115/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9735 - loss: 0.0867 - val_accuracy: 0.8701 - val_loss: 0.4296
# Epoch 116/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9735 - loss: 0.0832 - val_accuracy: 0.8442 - val_loss: 0.6303
# Epoch 117/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9634 - loss: 0.1329 - val_accuracy: 0.8831 - val_loss: 0.5902
# Epoch 118/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9735 - loss: 0.0714 - val_accuracy: 0.8701 - val_loss: 0.5979
# Epoch 119/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9615 - loss: 0.1165 - val_accuracy: 0.8182 - val_loss: 0.9496
# Epoch 120/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9545 - loss: 0.1705 - val_accuracy: 0.8961 - val_loss: 0.5426
# Epoch 121/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9672 - loss: 0.0758 - val_accuracy: 0.8182 - val_loss: 0.8414
# Epoch 122/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9739 - loss: 0.0791 - val_accuracy: 0.8312 - val_loss: 0.8186
# Epoch 123/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9852 - loss: 0.0558 - val_accuracy: 0.8831 - val_loss: 0.5126
# Epoch 124/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9587 - loss: 0.0951 - val_accuracy: 0.8571 - val_loss: 0.6217
# Epoch 125/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9743 - loss: 0.0788 - val_accuracy: 0.8831 - val_loss: 0.4324
# Epoch 126/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9678 - loss: 0.1220 - val_accuracy: 0.8831 - val_loss: 0.7051
# Epoch 127/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9789 - loss: 0.0623 - val_accuracy: 0.8701 - val_loss: 0.6845
# Epoch 128/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9797 - loss: 0.0629 - val_accuracy: 0.8701 - val_loss: 0.6666
# Epoch 129/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9608 - loss: 0.1316 - val_accuracy: 0.8701 - val_loss: 0.6233
# Epoch 130/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9719 - loss: 0.1217 - val_accuracy: 0.8571 - val_loss: 0.5292
# Epoch 131/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9791 - loss: 0.0740 - val_accuracy: 0.8571 - val_loss: 0.5974
# Epoch 132/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9572 - loss: 0.1643 - val_accuracy: 0.8701 - val_loss: 0.5647
# Epoch 133/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9743 - loss: 0.0944 - val_accuracy: 0.8571 - val_loss: 0.8557
# Epoch 134/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9904 - loss: 0.0688 - val_accuracy: 0.8442 - val_loss: 0.7282
# Epoch 135/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9654 - loss: 0.1047 - val_accuracy: 0.8571 - val_loss: 0.7811
# Epoch 136/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9850 - loss: 0.0507 - val_accuracy: 0.8571 - val_loss: 0.6809
# Epoch 137/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9509 - loss: 0.0849 - val_accuracy: 0.8831 - val_loss: 0.7143
# Epoch 138/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9824 - loss: 0.0678 - val_accuracy: 0.8961 - val_loss: 0.5730
# Epoch 139/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9787 - loss: 0.1314 - val_accuracy: 0.9091 - val_loss: 0.5109
# Epoch 140/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9876 - loss: 0.0420 - val_accuracy: 0.8961 - val_loss: 0.4669
# Epoch 141/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9700 - loss: 0.0608 - val_accuracy: 0.8961 - val_loss: 0.5052
# Epoch 142/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9813 - loss: 0.0584 - val_accuracy: 0.9221 - val_loss: 0.4887
# Epoch 143/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9804 - loss: 0.0657 - val_accuracy: 0.8701 - val_loss: 0.4668
# Epoch 144/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9717 - loss: 0.0793 - val_accuracy: 0.8701 - val_loss: 0.7591
# Epoch 145/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9715 - loss: 0.0619 - val_accuracy: 0.8701 - val_loss: 0.8231
# Epoch 146/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9983 - loss: 0.0291 - val_accuracy: 0.8571 - val_loss: 0.6625
# Epoch 147/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9839 - loss: 0.0368 - val_accuracy: 0.8701 - val_loss: 0.8076
# Epoch 148/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9806 - loss: 0.0647 - val_accuracy: 0.8701 - val_loss: 0.7961
# Epoch 149/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9822 - loss: 0.0416 - val_accuracy: 0.8571 - val_loss: 0.6948
# Epoch 150/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9937 - loss: 0.0320 - val_accuracy: 0.8701 - val_loss: 0.8082
# Epoch 151/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9878 - loss: 0.0421 - val_accuracy: 0.8701 - val_loss: 0.7466
# Epoch 152/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9893 - loss: 0.0214 - val_accuracy: 0.8571 - val_loss: 0.6716
# Epoch 153/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9791 - loss: 0.0618 - val_accuracy: 0.8571 - val_loss: 0.5867
# Epoch 154/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9591 - loss: 0.0994 - val_accuracy: 0.8442 - val_loss: 0.9232
# Epoch 155/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9948 - loss: 0.0422 - val_accuracy: 0.8831 - val_loss: 0.6767
# Epoch 156/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9774 - loss: 0.0533 - val_accuracy: 0.8701 - val_loss: 0.8503
# Epoch 157/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9867 - loss: 0.0407 - val_accuracy: 0.8571 - val_loss: 0.7067
# Epoch 158/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9767 - loss: 0.0501 - val_accuracy: 0.8701 - val_loss: 0.5341
# Epoch 159/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9865 - loss: 0.0411 - val_accuracy: 0.8701 - val_loss: 0.7125
# Epoch 160/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9843 - loss: 0.0671 - val_accuracy: 0.8701 - val_loss: 0.5412
# Epoch 161/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9870 - loss: 0.0465 - val_accuracy: 0.8571 - val_loss: 0.4006
# Epoch 162/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9867 - loss: 0.0468 - val_accuracy: 0.8831 - val_loss: 0.4768
# Epoch 163/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8961 - val_loss: 0.5237
# Epoch 164/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9754 - loss: 0.0755 - val_accuracy: 0.8701 - val_loss: 0.4789
# Epoch 165/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9891 - loss: 0.0409 - val_accuracy: 0.8701 - val_loss: 0.5448
# Epoch 166/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9961 - loss: 0.0317 - val_accuracy: 0.8701 - val_loss: 0.4940
# Epoch 167/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9896 - loss: 0.0341 - val_accuracy: 0.8701 - val_loss: 0.6115
# Epoch 168/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9972 - loss: 0.0171 - val_accuracy: 0.8701 - val_loss: 0.6244
# Epoch 169/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9989 - loss: 0.0194 - val_accuracy: 0.8831 - val_loss: 0.5769
# Epoch 170/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9865 - loss: 0.0485 - val_accuracy: 0.8831 - val_loss: 0.5990
# Epoch 171/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9861 - loss: 0.0395 - val_accuracy: 0.8571 - val_loss: 0.8379
# Epoch 172/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9906 - loss: 0.0353 - val_accuracy: 0.8571 - val_loss: 0.8630
# Epoch 173/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9913 - loss: 0.0359 - val_accuracy: 0.8701 - val_loss: 0.8247
# Epoch 174/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9804 - loss: 0.0352 - val_accuracy: 0.8571 - val_loss: 0.6626
# Epoch 175/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9813 - loss: 0.0432 - val_accuracy: 0.8831 - val_loss: 0.4632
# Epoch 176/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9843 - loss: 0.0287 - val_accuracy: 0.8831 - val_loss: 0.4284
# Epoch 177/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9844 - loss: 0.0534 - val_accuracy: 0.8701 - val_loss: 0.6568
# Epoch 178/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9961 - loss: 0.0202 - val_accuracy: 0.8701 - val_loss: 0.6343
# Epoch 179/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9989 - loss: 0.0164 - val_accuracy: 0.8571 - val_loss: 0.6380
# Epoch 180/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9935 - loss: 0.0386 - val_accuracy: 0.8571 - val_loss: 0.7005
# Epoch 181/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9956 - loss: 0.0211 - val_accuracy: 0.8571 - val_loss: 0.7097
# Epoch 182/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9906 - loss: 0.0240 - val_accuracy: 0.8701 - val_loss: 0.7109
# Epoch 183/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.8831 - val_loss: 0.6969
# Epoch 184/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9820 - loss: 0.0403 - val_accuracy: 0.8701 - val_loss: 0.7198
# Epoch 185/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9735 - loss: 0.0635 - val_accuracy: 0.8831 - val_loss: 0.5866
# Epoch 186/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9885 - loss: 0.0373 - val_accuracy: 0.8831 - val_loss: 0.6577
# Epoch 187/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9880 - loss: 0.0960 - val_accuracy: 0.8701 - val_loss: 0.8994
# Epoch 188/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9828 - loss: 0.0734 - val_accuracy: 0.8701 - val_loss: 0.8907
# Epoch 189/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9932 - loss: 0.0553 - val_accuracy: 0.8701 - val_loss: 0.8068
# Epoch 190/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9896 - loss: 0.0293 - val_accuracy: 0.8571 - val_loss: 1.0448
# Epoch 191/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9719 - loss: 0.0609 - val_accuracy: 0.8831 - val_loss: 0.8417
# Epoch 192/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9819 - loss: 0.0544 - val_accuracy: 0.8571 - val_loss: 0.9289
# Epoch 193/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9896 - loss: 0.0466 - val_accuracy: 0.8831 - val_loss: 0.7313
# Epoch 194/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9956 - loss: 0.0315 - val_accuracy: 0.8571 - val_loss: 0.5600
# Epoch 195/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9932 - loss: 0.0301 - val_accuracy: 0.8701 - val_loss: 0.6346
# Epoch 196/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9900 - loss: 0.0323 - val_accuracy: 0.8831 - val_loss: 0.5398
# Epoch 197/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9713 - loss: 0.0730 - val_accuracy: 0.8701 - val_loss: 0.5946
# Epoch 198/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9915 - loss: 0.0283 - val_accuracy: 0.8831 - val_loss: 0.7726
# Epoch 199/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9793 - loss: 0.0462 - val_accuracy: 0.8961 - val_loss: 0.5984
# Epoch 200/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9622 - loss: 0.1051 - val_accuracy: 0.8701 - val_loss: 0.8862
# Epoch 201/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9893 - loss: 0.0333 - val_accuracy: 0.8701 - val_loss: 0.6387
# Epoch 202/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9819 - loss: 0.0374 - val_accuracy: 0.8961 - val_loss: 0.5828
# Epoch 203/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9954 - loss: 0.0184 - val_accuracy: 0.8442 - val_loss: 0.9148
# Epoch 204/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step - accuracy: 0.9752 - loss: 0.0763 - val_accuracy: 0.8701 - val_loss: 0.6711

# %% [markdown]
# #### Visualize Training Performance

# %%
# Get training and validation accuracy and loss from the history object
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation accuracy
plt.figure()
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
# Plot training and validation loss
plt.figure()
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
# Get the final accuracy and loss for the last epoch
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

# Print the final accuracy and loss
print("Final Training Accuracy:", final_train_acc)
print("Final Validation Accuracy:", final_val_acc)
print("Final Training Loss:", final_train_loss)
print("Final Validation Loss:", final_val_loss)
# Out:
# Final Training Accuracy: 0.9737704992294312
# Final Validation Accuracy: 0.8701298832893372
# Final Training Loss: 0.10178685188293457
# Final Validation Loss: 0.6710932850837708

# %%
# Save the entire model as a `.keras` zip archive.
# combined_model.save('MTFN_32Rank.keras')

# %% [markdown]
# ## Visualizations

# %% [markdown]
# #### VGG Feature Maps

# %%
iterator = iter(train_dataset)
first_element, label = next(iterator)

# %%
# Load the existing model (if needed)
# combined_model = tf.keras.models.load_model('AD_Multimodal_Model.keras')

# Choose a layer to visualize (e.g., the output of the first convolutional layer)
layer_name = 'block1_conv1'
intermediate_layer_model = tf.keras.models.Model(inputs=combined_model.input, outputs=combined_model.get_layer(layer_name).output)

# Load and preprocess an image
def load_and_preprocess_image(image_path):
    img = tf.keras.utils.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.vgg16.preprocess_input(img_array)
    return img_array

image_path = '/home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I124297.png'
preprocessed_image = load_and_preprocess_image(image_path)

# Get the feature maps
feature_maps = intermediate_layer_model.predict(first_element)

# Visualize the feature maps
def visualize_feature_maps(feature_maps):
    num_feature_maps = feature_maps.shape[-1]
    
    # Determine the layout for subplots (adjust as needed)
    grid_size = int(np.ceil(np.sqrt(num_feature_maps)))
    
    plt.figure(figsize=(12, 12))
    for i in range(num_feature_maps):
        plt.subplot(grid_size, grid_size, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(feature_maps[0, :, :, i], cmap='gray')
    plt.show()

visualize_feature_maps(feature_maps)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
plt.imshow(feature_maps[0, :, :, 1], cmap='CMRmap')
# plt.savefig('VGG_Feature_Map.png', dpi=300)  # Save as PNG with 300 DPI

# %% [markdown]
# ValueError: 'green' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
