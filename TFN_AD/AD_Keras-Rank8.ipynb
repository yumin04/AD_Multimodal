# %% [markdown]
# ## Imports

# %%
import keras
import numpy as np

import time

import os

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow.keras.layers as tfl

# import misc

import pandas as pd

import datetime

import glob

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, GlobalAveragePooling2D, Input, Conv1D, MaxPooling1D, Flatten, \
                                    Masking, LSTM, Softmax, Multiply, Layer, Concatenate, Lambda, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# from keras.utils import np_utils
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.datasets import load_files
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
# import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.preprocessing import image_dataset_from_directory

from sklearn.model_selection import train_test_split

import tensorly as tl
from tensorly.decomposition import tucker
# Out:
# 2025-03-04 22:11:18.300397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741155078.323407   65167 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741155078.338761   65167 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 22:11:18.362769: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set up imports & packages.

tl.set_backend('tensorflow')  # Use TensorFlow tensors instead of NumPy

# %% [markdown]
# ## Declare Sub-Models

# %%
# Default 16.
feature_vector_size = 8

# %% [markdown]
# ### Visual Embedder (VGG-16)

# %%
def build_visual_embedder():
    # Load the VGG16 model without the top layers
    visual_base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze the base model to retain pretrained weights during training
    visual_base_model.trainable = False

    # Add a top for 3-way classification
    x = visual_base_model.output
    x = GlobalAveragePooling2D()(x)  # Global Average Pooling layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(256, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization

    visual_base_features = Dense(feature_vector_size, activation='relu')(x) 

    # Define the final model
    visual_model = Model(inputs=visual_base_model.input, outputs=visual_base_features, name="VisualEmbedder")
    return visual_model

# %% [markdown]
# ### Demographic Embedder

# %%
def build_demographics_embedder():
    # Input layer for demographics data
    input_layer = Input(shape=(6, ), name="demographics_input")

    x = Dense(16, activation='relu')(input_layer)
    x = Dropout(0.1)(x)
    x = Dense(4, activation='relu')(x)
    x = Dropout(0.1)(x)
    
    # Classification head
    demographics_base_features = Dense(feature_vector_size, activation='relu')(x)
    
    # Define the model
    demographics_model = Model(inputs=input_layer, outputs=demographics_base_features, name="DemographicsEmbedder")
    return demographics_model

# %% [markdown]
# ### Time-Series Embedder

# %%
max_seq_length = 6

# %%
def build_time_embedder():
    # Input layer for time series data (4 input variables)
    time_series_input = Input(shape=(max_seq_length, 4), name="time_series_input")
    masked_input = Masking(mask_value=0.0)(time_series_input)

    # Use the last hidden state
    x = LSTM(32, return_sequences=False)(masked_input)

    # Dense layer to create time series output
    time_base_features = Dense(feature_vector_size, activation="relu")(x)
    
    # Define the model
    time_model = Model(inputs=time_series_input, outputs=time_base_features, name="TimeSeriesEmbedder")
    return time_model

# %% [markdown]
# ## Joint Model

# %%
visual_dim = feature_vector_size
demographics_dim = feature_vector_size
time_dim = feature_vector_size

# Tensor Fusion Layer
def tensor_fusion_layer(inputs):
    """
    Tensor fusion using Kronecker product via `tf.einsum`.
    Adds a 1 to each input tensor for core (0,0,0) alignment.
    """
    visual, demographics, time_series = inputs

    # Add a "1" to the feature vectors
    visual_h = tf.concat([tf.ones((tf.shape(visual)[0], 1)), visual], axis=1)
    demographics_h = tf.concat([tf.ones((tf.shape(demographics)[0], 1)), demographics], axis=1)
    time_series_h = tf.concat([tf.ones((tf.shape(time_series)[0], 1)), time_series], axis=1)

    # Perform Kronecker product using tf.einsum
    outer_xy = tf.einsum('bi,bj->bij', demographics_h, time_series_h)  # Shape: (batch_size, d_dim, t_dim)
    outer_xyz = tf.einsum('bij,bk->bijk', outer_xy, visual_h)  # Shape: (batch_size, d_dim, t_dim, v_dim)

    # core, factors = tucker(outer_xyz, rank=(8,8,8))

    # # Flatten the fused tensor
    fused_tensor = tf.reshape(outer_xyz, (tf.shape(outer_xyz)[0], -1))  # Shape: (batch_size, d_dim * t_dim * v_dim)

    return fused_tensor #outer_xyz

# %%
# Visual embedder
visual_embedder = build_visual_embedder()

# Demographics embedder
demographics_embedder = build_demographics_embedder()

# Time Series Embedder
time_embedder = build_time_embedder()

# Outputs from embedders
visual_features = visual_embedder.output
demographics_features = demographics_embedder.output
time_features = time_embedder.output

# Output shape of the fused tensor
fused_tensor_shape = (None, (visual_dim + 1) * (demographics_dim + 1) * (time_dim + 1))

# Apply Tensor Fusion
fused_features = Lambda(tensor_fusion_layer, output_shape=fused_tensor_shape)([visual_features, demographics_features, time_features])

# Add final classification layers
x = Dense(128, activation='relu')(fused_features)
x = Dense(64, activation='relu')(x)
final_output = Dense(3, activation='softmax', name="final_output")(x)

# Define the combined model
combined_model = Model(inputs=[visual_embedder.input, demographics_embedder.input, time_embedder.input], 
                       outputs=final_output, name="CombinedModel")
# Out:
# W0000 00:00:1741155084.620385   65167 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# #### Joint-Model Structure

# %%
combined_model.summary()
# Out:
# Model: "CombinedModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ demographics_input  │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    262,656 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │        112 │ demographics_inp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_series_input   │ (None, 6, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 6, 4)      │          0 │ time_series_inpu… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4)         │         68 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 6, 4)      │          0 │ time_series_inpu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 6)         │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4)         │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 32)        │      4,736 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 8)         │      2,056 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 8)         │         40 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 8)         │        264 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, None, 729) │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_6[0][0],    │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, None, 128) │     93,440 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, None, 64)  │      8,256 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, None, 3)   │        195 │ dense_9[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,480,495 (59.05 MB)
#  Trainable params: 765,807 (2.92 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# # Train Joint-Model

# %% [markdown]
# #### Load Data

# %%
# Mapping for string labels to integers
label_mapping = {"CN": 0, "MCI": 1, "Dementia": 2}

# %%
manifest = pd.read_csv("/home/mason/TFN_AD/AD_Patient_Manifest.csv")

# %%
# Load all data into memory. Not elegant, but works.
def load_all_data(manifest, target_size=(224, 224), demographic_columns=None, time_series_columns=None, label_mapping=None):
    image_data = []
    demographics_data = []
    time_series_data = []
    labels = []
    label_mapping = label_mapping or {}

    for _, row in manifest.iterrows():
        patient_path = row["path"]
        patient_df = pd.read_pickle(patient_path)

        # Load image data
        image_paths = [patient_df['image_path'].iloc[0]]
        for path in image_paths:
            img = load_img(path, target_size=target_size)
            img_array = img_to_array(img)
            img_array = preprocess_input(img_array)
            image_data.append(img_array)

        # Process demographics data
        if demographic_columns is None:
            raise ValueError("Please specify the demographics columns.")
        
        # Get first row of demographic data (since it doesn't change over time)
        demographics = patient_df[demographic_columns].iloc[0]
        demographics = demographics.values.astype(np.float32)  # Convert to NumPy array
        demographics_data.append(demographics)

        # Process time series data
        if time_series_columns is None:
            raise ValueError("Please specify the time series columns.")
        
        # Extract the relevant time series columns
        time_series = patient_df[time_series_columns].values  # Extract as NumPy array

        # Truncate or pad to max_seq_length
        if len(time_series) > max_seq_length:
            time_series = time_series[:max_seq_length, :]
        elif len(time_series) < max_seq_length:
            padding = np.zeros((max_seq_length - len(time_series), len(time_series_columns)))
            time_series = np.vstack([time_series, padding])
        time_series_data.append(time_series)

        # Load labels
        label_str = patient_df['DX'].iloc[0]
        label_int = label_mapping[label_str]
        labels.append(label_int)

    # Convert to numpy arrays
    image_data = np.array(image_data, dtype=np.float32)
    demographics_data = np.array(demographics_data, dtype=np.float32)
    time_series_data = np.array(time_series_data, dtype=np.float32)
    labels = np.array(labels, dtype=np.int32)

    return image_data, demographics_data, time_series_data, labels

# %%
# Demographic variables to extract
demographic_columns = ['AGE', 'PTEDUCAT', 'PTGENDER_encoded', 
                        'PTETHCAT_encoded', 'PTRACCAT_encoded', 'PTMARRY_encoded']
# Time series variables to extract
time_series_columns = ['Years_bl', 'ADAS11', 'ADAS13', 'ADASQ4']

# Load all data into memory
image_data, demographics_data, time_series_data, labels = load_all_data(manifest, target_size=(224, 224), demographic_columns=demographic_columns, 
                                                      time_series_columns=time_series_columns, label_mapping=label_mapping)

# Split the data
test_size = 0.2  # 20% of the data for testing

(image_train, image_test,
 demographics_train, demographics_test,
 time_train, time_test,
 labels_train, labels_test) = train_test_split(
    image_data, demographics_data, time_series_data, labels, test_size=test_size, random_state=42, stratify=labels
)

# %%
batch_size = 64

# Create training dataset
train_dataset = tf.data.Dataset.from_tensor_slices(((image_train, demographics_train, time_train), labels_train))
train_dataset = train_dataset.shuffle(100).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Create testing (validation) dataset
test_dataset = tf.data.Dataset.from_tensor_slices(((image_test, demographics_test, time_test), labels_test))
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
print(f"Image train shape: {image_train.shape}")
print(f"Demographics train shape: {demographics_train.shape}")
print(f"Time train shape: {time_train.shape}")
print(f"Labels train shape: {labels_train.shape}")
# Out:
# Image train shape: (305, 224, 224, 3)
# Demographics train shape: (305, 6)
# Time train shape: (305, 6, 4)
# Labels train shape: (305,)

# %% [markdown]
# #### Train the Model

# %%
# Compile the model
combined_model.compile(optimizer=Adam(learning_rate=0.0001),
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

# %%
print("Model inputs:", combined_model.input)
# Out:
# Model inputs: [<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>, <KerasTensor shape=(None, 6), dtype=float32, sparse=False, name=demographics_input>, <KerasTensor shape=(None, 6, 4), dtype=float32, sparse=False, name=time_series_input>]

# %%
# Early stopping to prevent redundant training.
early_stopping = EarlyStopping(monitor='val_accuracy', patience=100, restore_best_weights=True)

# %%
# Train the model
history = combined_model.fit(
    train_dataset, 
    validation_data=test_dataset,
    epochs=600,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/600
# /home/mason/.conda/envs/LOSresearch/lib/python3.9/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'demographics_input', 'time_series_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.3709 - loss: 11.5341 - val_accuracy: 0.4156 - val_loss: 1.4904
# Epoch 2/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.3931 - loss: 2.3662 - val_accuracy: 0.4286 - val_loss: 1.1754
# Epoch 3/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.3794 - loss: 1.7652 - val_accuracy: 0.4026 - val_loss: 1.1228
# Epoch 4/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.3866 - loss: 1.3418 - val_accuracy: 0.3896 - val_loss: 1.1498
# Epoch 5/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4226 - loss: 1.1846 - val_accuracy: 0.3896 - val_loss: 1.0624
# Epoch 6/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.4635 - loss: 1.0761 - val_accuracy: 0.4545 - val_loss: 0.9901
# Epoch 7/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4466 - loss: 1.0638 - val_accuracy: 0.5584 - val_loss: 0.9622
# Epoch 8/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5208 - loss: 1.0204 - val_accuracy: 0.6234 - val_loss: 0.9439
# Epoch 9/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5030 - loss: 1.0258 - val_accuracy: 0.6623 - val_loss: 0.9272
# Epoch 10/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.5245 - loss: 1.0123 - val_accuracy: 0.6883 - val_loss: 0.9067
# Epoch 11/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6034 - loss: 0.9625 - val_accuracy: 0.6883 - val_loss: 0.8834
# Epoch 12/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4958 - loss: 0.9746 - val_accuracy: 0.7403 - val_loss: 0.8610
# Epoch 13/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6198 - loss: 0.9063 - val_accuracy: 0.7662 - val_loss: 0.8381
# Epoch 14/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6027 - loss: 0.8760 - val_accuracy: 0.7662 - val_loss: 0.8161
# Epoch 15/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5622 - loss: 0.9134 - val_accuracy: 0.7662 - val_loss: 0.7955
# Epoch 16/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6719 - loss: 0.8198 - val_accuracy: 0.7662 - val_loss: 0.7745
# Epoch 17/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6641 - loss: 0.8501 - val_accuracy: 0.7532 - val_loss: 0.7534
# Epoch 18/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7019 - loss: 0.7912 - val_accuracy: 0.7662 - val_loss: 0.7308
# Epoch 19/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7346 - loss: 0.7595 - val_accuracy: 0.7403 - val_loss: 0.7083
# Epoch 20/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6866 - loss: 0.7713 - val_accuracy: 0.7532 - val_loss: 0.6894
# Epoch 21/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6824 - loss: 0.7517 - val_accuracy: 0.7532 - val_loss: 0.6694
# Epoch 22/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6730 - loss: 0.7604 - val_accuracy: 0.7662 - val_loss: 0.6533
# Epoch 23/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7050 - loss: 0.7220 - val_accuracy: 0.7662 - val_loss: 0.6371
# Epoch 24/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7202 - loss: 0.7069 - val_accuracy: 0.7662 - val_loss: 0.6221
# Epoch 25/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7335 - loss: 0.6832 - val_accuracy: 0.7662 - val_loss: 0.6131
# Epoch 26/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7207 - loss: 0.6721 - val_accuracy: 0.7662 - val_loss: 0.6038
# Epoch 27/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7329 - loss: 0.6710 - val_accuracy: 0.7662 - val_loss: 0.5913
# Epoch 28/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7468 - loss: 0.6730 - val_accuracy: 0.7662 - val_loss: 0.5784
# Epoch 29/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7357 - loss: 0.6524 - val_accuracy: 0.7922 - val_loss: 0.5687
# Epoch 30/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7496 - loss: 0.6332 - val_accuracy: 0.7922 - val_loss: 0.5596
# Epoch 31/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7427 - loss: 0.6200 - val_accuracy: 0.7922 - val_loss: 0.5522
# Epoch 32/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7335 - loss: 0.6423 - val_accuracy: 0.7922 - val_loss: 0.5461
# Epoch 33/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7559 - loss: 0.5999 - val_accuracy: 0.8052 - val_loss: 0.5413
# Epoch 34/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7560 - loss: 0.6254 - val_accuracy: 0.8052 - val_loss: 0.5375
# Epoch 35/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7792 - loss: 0.6009 - val_accuracy: 0.8052 - val_loss: 0.5329
# Epoch 36/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7437 - loss: 0.6035 - val_accuracy: 0.8052 - val_loss: 0.5276
# Epoch 37/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7329 - loss: 0.6129 - val_accuracy: 0.8052 - val_loss: 0.5194
# Epoch 38/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7361 - loss: 0.5896 - val_accuracy: 0.8052 - val_loss: 0.5118
# Epoch 39/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7401 - loss: 0.5863 - val_accuracy: 0.8052 - val_loss: 0.5053
# Epoch 40/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7609 - loss: 0.5820 - val_accuracy: 0.8182 - val_loss: 0.5001
# Epoch 41/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7536 - loss: 0.5621 - val_accuracy: 0.8182 - val_loss: 0.4953
# Epoch 42/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7636 - loss: 0.5377 - val_accuracy: 0.8312 - val_loss: 0.4913
# Epoch 43/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7810 - loss: 0.5480 - val_accuracy: 0.8182 - val_loss: 0.4903
# Epoch 44/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7497 - loss: 0.5884 - val_accuracy: 0.8182 - val_loss: 0.4919
# Epoch 45/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7732 - loss: 0.5376 - val_accuracy: 0.8312 - val_loss: 0.4841
# Epoch 46/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7968 - loss: 0.5406 - val_accuracy: 0.8312 - val_loss: 0.4695
# Epoch 47/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7510 - loss: 0.5513 - val_accuracy: 0.8312 - val_loss: 0.4585
# Epoch 48/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7718 - loss: 0.5260 - val_accuracy: 0.8442 - val_loss: 0.4558
# Epoch 49/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.7586 - loss: 0.5433 - val_accuracy: 0.8442 - val_loss: 0.4573
# Epoch 50/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.8005 - loss: 0.5337 - val_accuracy: 0.8312 - val_loss: 0.4625
# Epoch 51/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.7782 - loss: 0.5326 - val_accuracy: 0.8442 - val_loss: 0.4571
# Epoch 52/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7788 - loss: 0.5506 - val_accuracy: 0.8442 - val_loss: 0.4420
# Epoch 53/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8051 - loss: 0.5144 - val_accuracy: 0.8442 - val_loss: 0.4347
# Epoch 54/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8007 - loss: 0.5158 - val_accuracy: 0.8442 - val_loss: 0.4252
# Epoch 55/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7801 - loss: 0.5340 - val_accuracy: 0.8312 - val_loss: 0.4266
# Epoch 56/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8229 - loss: 0.4981 - val_accuracy: 0.8312 - val_loss: 0.4263
# Epoch 57/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8125 - loss: 0.4910 - val_accuracy: 0.8442 - val_loss: 0.4224
# Epoch 58/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8116 - loss: 0.5206 - val_accuracy: 0.8442 - val_loss: 0.4189
# Epoch 59/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8288 - loss: 0.5073 - val_accuracy: 0.8442 - val_loss: 0.4136
# Epoch 60/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8323 - loss: 0.4794 - val_accuracy: 0.8312 - val_loss: 0.4139
# Epoch 61/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8184 - loss: 0.4813 - val_accuracy: 0.8312 - val_loss: 0.4136
# Epoch 62/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8171 - loss: 0.4726 - val_accuracy: 0.8442 - val_loss: 0.4073
# Epoch 63/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8451 - loss: 0.4644 - val_accuracy: 0.8442 - val_loss: 0.4060
# Epoch 64/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8427 - loss: 0.4979 - val_accuracy: 0.8442 - val_loss: 0.3981
# Epoch 65/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8562 - loss: 0.4712 - val_accuracy: 0.8442 - val_loss: 0.3919
# Epoch 66/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8625 - loss: 0.4619 - val_accuracy: 0.8442 - val_loss: 0.3921
# Epoch 67/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8408 - loss: 0.4639 - val_accuracy: 0.8442 - val_loss: 0.3906
# Epoch 68/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8266 - loss: 0.4700 - val_accuracy: 0.8442 - val_loss: 0.3873
# Epoch 69/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8521 - loss: 0.4852 - val_accuracy: 0.8442 - val_loss: 0.3854
# Epoch 70/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8499 - loss: 0.4363 - val_accuracy: 0.8442 - val_loss: 0.3803
# Epoch 71/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8533 - loss: 0.4496 - val_accuracy: 0.8442 - val_loss: 0.3797
# Epoch 72/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8555 - loss: 0.4552 - val_accuracy: 0.8442 - val_loss: 0.3763
# Epoch 73/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8683 - loss: 0.4537 - val_accuracy: 0.8442 - val_loss: 0.3738
# Epoch 74/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8723 - loss: 0.4199 - val_accuracy: 0.8442 - val_loss: 0.3734
# Epoch 75/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8427 - loss: 0.4605 - val_accuracy: 0.8442 - val_loss: 0.3751
# Epoch 76/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8731 - loss: 0.4362 - val_accuracy: 0.8442 - val_loss: 0.3729
# Epoch 77/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8393 - loss: 0.4541 - val_accuracy: 0.8442 - val_loss: 0.3724
# Epoch 78/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8549 - loss: 0.4614 - val_accuracy: 0.8442 - val_loss: 0.3724
# Epoch 79/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8429 - loss: 0.4122 - val_accuracy: 0.8442 - val_loss: 0.3659
# Epoch 80/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8571 - loss: 0.4364 - val_accuracy: 0.8312 - val_loss: 0.3596
# Epoch 81/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8645 - loss: 0.4243 - val_accuracy: 0.8442 - val_loss: 0.3574
# Epoch 82/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8569 - loss: 0.4666 - val_accuracy: 0.8442 - val_loss: 0.3612
# Epoch 83/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8312 - loss: 0.4436 - val_accuracy: 0.8442 - val_loss: 0.3686
# Epoch 84/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8564 - loss: 0.4141 - val_accuracy: 0.8442 - val_loss: 0.3612
# Epoch 85/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8755 - loss: 0.4390 - val_accuracy: 0.8442 - val_loss: 0.3571
# Epoch 86/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8734 - loss: 0.4225 - val_accuracy: 0.8442 - val_loss: 0.3547
# Epoch 87/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8501 - loss: 0.4241 - val_accuracy: 0.8442 - val_loss: 0.3571
# Epoch 88/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8610 - loss: 0.4271 - val_accuracy: 0.8442 - val_loss: 0.3523
# Epoch 89/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8790 - loss: 0.4296 - val_accuracy: 0.8442 - val_loss: 0.3533
# Epoch 90/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8851 - loss: 0.4292 - val_accuracy: 0.8442 - val_loss: 0.3515
# Epoch 91/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8536 - loss: 0.4320 - val_accuracy: 0.8442 - val_loss: 0.3555
# Epoch 92/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8623 - loss: 0.4024 - val_accuracy: 0.8442 - val_loss: 0.3455
# Epoch 93/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8595 - loss: 0.3911 - val_accuracy: 0.8442 - val_loss: 0.3454
# Epoch 94/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8825 - loss: 0.4201 - val_accuracy: 0.8442 - val_loss: 0.3456
# Epoch 95/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8640 - loss: 0.4168 - val_accuracy: 0.8442 - val_loss: 0.3464
# Epoch 96/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8443 - loss: 0.4287 - val_accuracy: 0.8442 - val_loss: 0.3412
# Epoch 97/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8623 - loss: 0.4280 - val_accuracy: 0.8442 - val_loss: 0.3450
# Epoch 98/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8655 - loss: 0.3713 - val_accuracy: 0.8442 - val_loss: 0.3496
# Epoch 99/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8653 - loss: 0.4031 - val_accuracy: 0.8442 - val_loss: 0.3478
# Epoch 100/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8688 - loss: 0.3899 - val_accuracy: 0.8442 - val_loss: 0.3406
# Epoch 101/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8818 - loss: 0.3613 - val_accuracy: 0.8442 - val_loss: 0.3367
# Epoch 102/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8905 - loss: 0.3982 - val_accuracy: 0.8701 - val_loss: 0.3290
# Epoch 103/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8668 - loss: 0.3943 - val_accuracy: 0.8701 - val_loss: 0.3300
# Epoch 104/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8899 - loss: 0.3919 - val_accuracy: 0.8571 - val_loss: 0.3321
# Epoch 105/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8799 - loss: 0.3822 - val_accuracy: 0.8442 - val_loss: 0.3317
# Epoch 106/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8771 - loss: 0.3861 - val_accuracy: 0.8442 - val_loss: 0.3319
# Epoch 107/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8719 - loss: 0.4185 - val_accuracy: 0.8701 - val_loss: 0.3301
# Epoch 108/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8853 - loss: 0.4047 - val_accuracy: 0.8571 - val_loss: 0.3276
# Epoch 109/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8999 - loss: 0.3895 - val_accuracy: 0.8442 - val_loss: 0.3238
# Epoch 110/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8705 - loss: 0.3939 - val_accuracy: 0.8831 - val_loss: 0.3206
# Epoch 111/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8742 - loss: 0.3756 - val_accuracy: 0.8831 - val_loss: 0.3156
# Epoch 112/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8755 - loss: 0.3948 - val_accuracy: 0.8701 - val_loss: 0.3161
# Epoch 113/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8864 - loss: 0.3516 - val_accuracy: 0.8701 - val_loss: 0.3211
# Epoch 114/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8806 - loss: 0.3925 - val_accuracy: 0.8442 - val_loss: 0.3291
# Epoch 115/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8723 - loss: 0.3941 - val_accuracy: 0.8571 - val_loss: 0.3189
# Epoch 116/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8860 - loss: 0.3886 - val_accuracy: 0.8831 - val_loss: 0.3134
# Epoch 117/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8564 - loss: 0.3788 - val_accuracy: 0.8831 - val_loss: 0.3104
# Epoch 118/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8756 - loss: 0.3568 - val_accuracy: 0.8831 - val_loss: 0.3101
# Epoch 119/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8903 - loss: 0.3734 - val_accuracy: 0.8831 - val_loss: 0.3113
# Epoch 120/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8699 - loss: 0.3929 - val_accuracy: 0.8442 - val_loss: 0.3262
# Epoch 121/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8729 - loss: 0.3743 - val_accuracy: 0.8442 - val_loss: 0.3255
# Epoch 122/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8829 - loss: 0.3997 - val_accuracy: 0.8701 - val_loss: 0.3146
# Epoch 123/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8953 - loss: 0.3496 - val_accuracy: 0.8701 - val_loss: 0.3115
# Epoch 124/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8727 - loss: 0.3862 - val_accuracy: 0.8831 - val_loss: 0.3051
# Epoch 125/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8816 - loss: 0.3770 - val_accuracy: 0.8831 - val_loss: 0.3092
# Epoch 126/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8895 - loss: 0.3646 - val_accuracy: 0.8442 - val_loss: 0.3166
# Epoch 127/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8797 - loss: 0.3650 - val_accuracy: 0.8701 - val_loss: 0.3074
# Epoch 128/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8825 - loss: 0.3769 - val_accuracy: 0.8831 - val_loss: 0.3054
# Epoch 129/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8925 - loss: 0.3661 - val_accuracy: 0.8701 - val_loss: 0.3074
# Epoch 130/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8942 - loss: 0.3293 - val_accuracy: 0.8571 - val_loss: 0.3091
# Epoch 131/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9014 - loss: 0.3452 - val_accuracy: 0.8701 - val_loss: 0.3042
# Epoch 132/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8951 - loss: 0.3776 - val_accuracy: 0.8831 - val_loss: 0.3019
# Epoch 133/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8840 - loss: 0.3405 - val_accuracy: 0.8831 - val_loss: 0.3008
# Epoch 134/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8927 - loss: 0.3018 - val_accuracy: 0.8571 - val_loss: 0.3031
# Epoch 135/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8871 - loss: 0.3453 - val_accuracy: 0.8701 - val_loss: 0.3017
# Epoch 136/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8982 - loss: 0.3375 - val_accuracy: 0.8701 - val_loss: 0.3060
# Epoch 137/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8745 - loss: 0.3625 - val_accuracy: 0.8571 - val_loss: 0.3055
# Epoch 138/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9012 - loss: 0.3463 - val_accuracy: 0.8571 - val_loss: 0.3066
# Epoch 139/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8971 - loss: 0.3558 - val_accuracy: 0.8701 - val_loss: 0.3025
# Epoch 140/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8904 - loss: 0.3532 - val_accuracy: 0.8701 - val_loss: 0.2976
# Epoch 141/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8701 - loss: 0.3441 - val_accuracy: 0.8571 - val_loss: 0.2994
# Epoch 142/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8860 - loss: 0.3500 - val_accuracy: 0.8571 - val_loss: 0.3027
# Epoch 143/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8819 - loss: 0.3491 - val_accuracy: 0.8701 - val_loss: 0.2948
# Epoch 144/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9177 - loss: 0.3004 - val_accuracy: 0.8831 - val_loss: 0.2912
# Epoch 145/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8832 - loss: 0.3427 - val_accuracy: 0.8701 - val_loss: 0.2985
# Epoch 146/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8908 - loss: 0.3280 - val_accuracy: 0.8442 - val_loss: 0.3081
# Epoch 147/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8832 - loss: 0.3456 - val_accuracy: 0.8701 - val_loss: 0.3010
# Epoch 148/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9069 - loss: 0.3273 - val_accuracy: 0.8701 - val_loss: 0.2960
# Epoch 149/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8873 - loss: 0.3386 - val_accuracy: 0.8571 - val_loss: 0.2996
# Epoch 150/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8821 - loss: 0.3463 - val_accuracy: 0.8571 - val_loss: 0.3001
# Epoch 151/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8758 - loss: 0.3572 - val_accuracy: 0.8701 - val_loss: 0.2913
# Epoch 152/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9058 - loss: 0.3064 - val_accuracy: 0.8701 - val_loss: 0.2921
# Epoch 153/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9025 - loss: 0.3225 - val_accuracy: 0.8571 - val_loss: 0.2990
# Epoch 154/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8980 - loss: 0.3088 - val_accuracy: 0.8571 - val_loss: 0.2942
# Epoch 155/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8956 - loss: 0.3297 - val_accuracy: 0.8571 - val_loss: 0.2919
# Epoch 156/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9047 - loss: 0.3185 - val_accuracy: 0.8701 - val_loss: 0.2869
# Epoch 157/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8867 - loss: 0.3344 - val_accuracy: 0.8701 - val_loss: 0.2869
# Epoch 158/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9016 - loss: 0.3295 - val_accuracy: 0.8701 - val_loss: 0.2869
# Epoch 159/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9105 - loss: 0.2954 - val_accuracy: 0.8701 - val_loss: 0.2878
# Epoch 160/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8893 - loss: 0.3159 - val_accuracy: 0.8701 - val_loss: 0.2884
# Epoch 161/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9093 - loss: 0.3250 - val_accuracy: 0.8701 - val_loss: 0.2824
# Epoch 162/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8969 - loss: 0.3231 - val_accuracy: 0.8571 - val_loss: 0.2901
# Epoch 163/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8845 - loss: 0.3141 - val_accuracy: 0.8831 - val_loss: 0.2801
# Epoch 164/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9162 - loss: 0.2843 - val_accuracy: 0.9091 - val_loss: 0.2707
# Epoch 165/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9069 - loss: 0.2888 - val_accuracy: 0.8571 - val_loss: 0.2792
# Epoch 166/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8871 - loss: 0.3212 - val_accuracy: 0.8571 - val_loss: 0.2938
# Epoch 167/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9151 - loss: 0.2888 - val_accuracy: 0.8831 - val_loss: 0.2732
# Epoch 168/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9136 - loss: 0.2919 - val_accuracy: 0.9091 - val_loss: 0.2642
# Epoch 169/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8869 - loss: 0.3374 - val_accuracy: 0.8831 - val_loss: 0.2807
# Epoch 170/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8923 - loss: 0.3019 - val_accuracy: 0.8831 - val_loss: 0.2773
# Epoch 171/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8945 - loss: 0.2965 - val_accuracy: 0.8831 - val_loss: 0.2779
# Epoch 172/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9143 - loss: 0.2824 - val_accuracy: 0.8961 - val_loss: 0.2647
# Epoch 173/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9082 - loss: 0.2810 - val_accuracy: 0.8961 - val_loss: 0.2638
# Epoch 174/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8980 - loss: 0.3013 - val_accuracy: 0.8831 - val_loss: 0.2754
# Epoch 175/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9153 - loss: 0.2748 - val_accuracy: 0.8831 - val_loss: 0.2789
# Epoch 176/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9125 - loss: 0.2830 - val_accuracy: 0.8961 - val_loss: 0.2711
# Epoch 177/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9110 - loss: 0.2658 - val_accuracy: 0.8961 - val_loss: 0.2631
# Epoch 178/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9067 - loss: 0.3077 - val_accuracy: 0.8961 - val_loss: 0.2602
# Epoch 179/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9001 - loss: 0.2911 - val_accuracy: 0.8831 - val_loss: 0.2636
# Epoch 180/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9075 - loss: 0.2863 - val_accuracy: 0.8961 - val_loss: 0.2599
# Epoch 181/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9016 - loss: 0.2876 - val_accuracy: 0.8831 - val_loss: 0.2656
# Epoch 182/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9197 - loss: 0.2730 - val_accuracy: 0.8831 - val_loss: 0.2582
# Epoch 183/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8860 - loss: 0.3102 - val_accuracy: 0.8961 - val_loss: 0.2627
# Epoch 184/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9210 - loss: 0.2844 - val_accuracy: 0.8961 - val_loss: 0.2646
# Epoch 185/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9240 - loss: 0.2820 - val_accuracy: 0.8961 - val_loss: 0.2600
# Epoch 186/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9097 - loss: 0.2797 - val_accuracy: 0.8961 - val_loss: 0.2539
# Epoch 187/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8882 - loss: 0.3000 - val_accuracy: 0.8961 - val_loss: 0.2540
# Epoch 188/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9175 - loss: 0.2842 - val_accuracy: 0.8701 - val_loss: 0.2615
# Epoch 189/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9169 - loss: 0.2544 - val_accuracy: 0.8701 - val_loss: 0.2657
# Epoch 190/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9199 - loss: 0.2650 - val_accuracy: 0.8961 - val_loss: 0.2544
# Epoch 191/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9234 - loss: 0.2678 - val_accuracy: 0.9091 - val_loss: 0.2508
# Epoch 192/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9182 - loss: 0.2582 - val_accuracy: 0.8571 - val_loss: 0.2669
# Epoch 193/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9169 - loss: 0.2728 - val_accuracy: 0.8961 - val_loss: 0.2499
# Epoch 194/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9247 - loss: 0.2409 - val_accuracy: 0.9091 - val_loss: 0.2502
# Epoch 195/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9158 - loss: 0.2612 - val_accuracy: 0.8831 - val_loss: 0.2570
# Epoch 196/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9234 - loss: 0.2524 - val_accuracy: 0.8831 - val_loss: 0.2565
# Epoch 197/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9058 - loss: 0.2580 - val_accuracy: 0.9091 - val_loss: 0.2417
# Epoch 198/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9340 - loss: 0.2328 - val_accuracy: 0.8831 - val_loss: 0.2408
# Epoch 199/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9288 - loss: 0.2333 - val_accuracy: 0.8701 - val_loss: 0.2539
# Epoch 200/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9306 - loss: 0.2274 - val_accuracy: 0.8831 - val_loss: 0.2512
# Epoch 201/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9195 - loss: 0.2512 - val_accuracy: 0.9091 - val_loss: 0.2426
# Epoch 202/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9086 - loss: 0.2542 - val_accuracy: 0.8961 - val_loss: 0.2486
# Epoch 203/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9290 - loss: 0.2393 - val_accuracy: 0.8701 - val_loss: 0.2548
# Epoch 204/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9356 - loss: 0.2200 - val_accuracy: 0.8961 - val_loss: 0.2392
# Epoch 205/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9295 - loss: 0.2661 - val_accuracy: 0.9091 - val_loss: 0.2298
# Epoch 206/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9253 - loss: 0.2306 - val_accuracy: 0.9091 - val_loss: 0.2311
# Epoch 207/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9343 - loss: 0.2239 - val_accuracy: 0.9091 - val_loss: 0.2312
# Epoch 208/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9017 - loss: 0.2562 - val_accuracy: 0.9091 - val_loss: 0.2300
# Epoch 209/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9362 - loss: 0.2185 - val_accuracy: 0.9091 - val_loss: 0.2291
# Epoch 210/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9560 - loss: 0.2051 - val_accuracy: 0.9091 - val_loss: 0.2276
# Epoch 211/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9310 - loss: 0.2326 - val_accuracy: 0.8961 - val_loss: 0.2341
# Epoch 212/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9367 - loss: 0.2050 - val_accuracy: 0.8961 - val_loss: 0.2375
# Epoch 213/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9354 - loss: 0.2408 - val_accuracy: 0.9091 - val_loss: 0.2330
# Epoch 214/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9338 - loss: 0.2105 - val_accuracy: 0.9091 - val_loss: 0.2289
# Epoch 215/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9317 - loss: 0.2269 - val_accuracy: 0.8961 - val_loss: 0.2287
# Epoch 216/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9382 - loss: 0.2073 - val_accuracy: 0.8961 - val_loss: 0.2385
# Epoch 217/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9456 - loss: 0.2016 - val_accuracy: 0.8961 - val_loss: 0.2218
# Epoch 218/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9349 - loss: 0.2091 - val_accuracy: 0.8961 - val_loss: 0.2201
# Epoch 219/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9404 - loss: 0.1964 - val_accuracy: 0.8961 - val_loss: 0.2182
# Epoch 220/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9467 - loss: 0.2146 - val_accuracy: 0.8961 - val_loss: 0.2220
# Epoch 221/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9382 - loss: 0.2097 - val_accuracy: 0.8961 - val_loss: 0.2241
# Epoch 222/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9454 - loss: 0.2049 - val_accuracy: 0.8961 - val_loss: 0.2213
# Epoch 223/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9589 - loss: 0.1833 - val_accuracy: 0.8961 - val_loss: 0.2223
# Epoch 224/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9595 - loss: 0.1671 - val_accuracy: 0.9091 - val_loss: 0.2153
# Epoch 225/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9350 - loss: 0.2265 - val_accuracy: 0.8961 - val_loss: 0.2206
# Epoch 226/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9486 - loss: 0.2008 - val_accuracy: 0.8961 - val_loss: 0.2123
# Epoch 227/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9573 - loss: 0.1707 - val_accuracy: 0.9091 - val_loss: 0.2165
# Epoch 228/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9513 - loss: 0.2057 - val_accuracy: 0.8831 - val_loss: 0.2398
# Epoch 229/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9530 - loss: 0.1949 - val_accuracy: 0.9091 - val_loss: 0.2172
# Epoch 230/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9584 - loss: 0.1980 - val_accuracy: 0.9091 - val_loss: 0.2196
# Epoch 231/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9656 - loss: 0.1744 - val_accuracy: 0.8831 - val_loss: 0.2391
# Epoch 232/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9497 - loss: 0.1667 - val_accuracy: 0.9091 - val_loss: 0.2136
# Epoch 233/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9502 - loss: 0.1794 - val_accuracy: 0.9091 - val_loss: 0.2079
# Epoch 234/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9611 - loss: 0.1681 - val_accuracy: 0.8961 - val_loss: 0.2153
# Epoch 235/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9615 - loss: 0.1609 - val_accuracy: 0.8961 - val_loss: 0.2137
# Epoch 236/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9619 - loss: 0.1565 - val_accuracy: 0.9091 - val_loss: 0.2054
# Epoch 237/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9673 - loss: 0.1377 - val_accuracy: 0.9091 - val_loss: 0.2079
# Epoch 238/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9550 - loss: 0.1644 - val_accuracy: 0.9091 - val_loss: 0.2039
# Epoch 239/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9598 - loss: 0.1664 - val_accuracy: 0.8961 - val_loss: 0.2079
# Epoch 240/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9615 - loss: 0.1682 - val_accuracy: 0.9091 - val_loss: 0.1968
# Epoch 241/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9526 - loss: 0.1571 - val_accuracy: 0.8961 - val_loss: 0.2108
# Epoch 242/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9626 - loss: 0.1598 - val_accuracy: 0.8961 - val_loss: 0.2028
# Epoch 243/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9595 - loss: 0.1780 - val_accuracy: 0.8961 - val_loss: 0.1931
# Epoch 244/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9706 - loss: 0.1619 - val_accuracy: 0.8961 - val_loss: 0.1932
# Epoch 245/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9634 - loss: 0.1555 - val_accuracy: 0.8961 - val_loss: 0.1970
# Epoch 246/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9543 - loss: 0.1524 - val_accuracy: 0.8961 - val_loss: 0.1931
# Epoch 247/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9617 - loss: 0.1465 - val_accuracy: 0.8961 - val_loss: 0.1940
# Epoch 248/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9715 - loss: 0.1437 - val_accuracy: 0.9091 - val_loss: 0.1894
# Epoch 249/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9702 - loss: 0.1570 - val_accuracy: 0.9221 - val_loss: 0.1958
# Epoch 250/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9665 - loss: 0.1747 - val_accuracy: 0.9091 - val_loss: 0.1849
# Epoch 251/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9808 - loss: 0.1243 - val_accuracy: 0.9221 - val_loss: 0.1823
# Epoch 252/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9654 - loss: 0.1634 - val_accuracy: 0.9091 - val_loss: 0.1994
# Epoch 253/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9639 - loss: 0.1387 - val_accuracy: 0.9351 - val_loss: 0.1766
# Epoch 254/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9643 - loss: 0.1514 - val_accuracy: 0.9221 - val_loss: 0.1924
# Epoch 255/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9739 - loss: 0.1313 - val_accuracy: 0.9221 - val_loss: 0.1922
# Epoch 256/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9873 - loss: 0.1174 - val_accuracy: 0.9351 - val_loss: 0.1732
# Epoch 257/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9787 - loss: 0.1260 - val_accuracy: 0.9221 - val_loss: 0.1914
# Epoch 258/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9793 - loss: 0.1135 - val_accuracy: 0.9091 - val_loss: 0.1853
# Epoch 259/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9765 - loss: 0.1413 - val_accuracy: 0.9221 - val_loss: 0.1851
# Epoch 260/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9774 - loss: 0.1188 - val_accuracy: 0.9221 - val_loss: 0.1908
# Epoch 261/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9784 - loss: 0.1112 - val_accuracy: 0.9351 - val_loss: 0.1799
# Epoch 262/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9719 - loss: 0.1103 - val_accuracy: 0.9351 - val_loss: 0.1836
# Epoch 263/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9682 - loss: 0.1389 - val_accuracy: 0.9221 - val_loss: 0.1760
# Epoch 264/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9748 - loss: 0.1276 - val_accuracy: 0.9351 - val_loss: 0.1777
# Epoch 265/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9706 - loss: 0.1257 - val_accuracy: 0.9351 - val_loss: 0.1768
# Epoch 266/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9772 - loss: 0.1195 - val_accuracy: 0.9481 - val_loss: 0.1693
# Epoch 267/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9717 - loss: 0.1368 - val_accuracy: 0.9481 - val_loss: 0.1658
# Epoch 268/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9759 - loss: 0.1347 - val_accuracy: 0.9351 - val_loss: 0.1779
# Epoch 269/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9702 - loss: 0.1216 - val_accuracy: 0.9351 - val_loss: 0.1775
# Epoch 270/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9654 - loss: 0.1298 - val_accuracy: 0.9351 - val_loss: 0.1743
# Epoch 271/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9839 - loss: 0.0985 - val_accuracy: 0.9351 - val_loss: 0.1705
# Epoch 272/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9685 - loss: 0.1221 - val_accuracy: 0.9351 - val_loss: 0.1796
# Epoch 273/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9691 - loss: 0.1199 - val_accuracy: 0.9351 - val_loss: 0.1796
# Epoch 274/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9791 - loss: 0.1179 - val_accuracy: 0.9481 - val_loss: 0.1620
# Epoch 275/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9845 - loss: 0.1069 - val_accuracy: 0.9481 - val_loss: 0.1675
# Epoch 276/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9713 - loss: 0.1070 - val_accuracy: 0.9351 - val_loss: 0.1836
# Epoch 277/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9789 - loss: 0.1040 - val_accuracy: 0.9610 - val_loss: 0.1658
# Epoch 278/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9878 - loss: 0.0934 - val_accuracy: 0.9351 - val_loss: 0.1706
# Epoch 279/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9813 - loss: 0.0825 - val_accuracy: 0.9351 - val_loss: 0.1817
# Epoch 280/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9791 - loss: 0.0955 - val_accuracy: 0.9610 - val_loss: 0.1678
# Epoch 281/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9763 - loss: 0.1078 - val_accuracy: 0.9351 - val_loss: 0.1727
# Epoch 282/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9648 - loss: 0.1176 - val_accuracy: 0.9351 - val_loss: 0.1837
# Epoch 283/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9745 - loss: 0.0988 - val_accuracy: 0.9610 - val_loss: 0.1662
# Epoch 284/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9745 - loss: 0.1064 - val_accuracy: 0.9351 - val_loss: 0.1766
# Epoch 285/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9774 - loss: 0.1028 - val_accuracy: 0.9351 - val_loss: 0.1790
# Epoch 286/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9739 - loss: 0.1047 - val_accuracy: 0.9351 - val_loss: 0.1845
# Epoch 287/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9854 - loss: 0.0897 - val_accuracy: 0.9481 - val_loss: 0.1666
# Epoch 288/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9800 - loss: 0.1090 - val_accuracy: 0.9351 - val_loss: 0.1827
# Epoch 289/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9776 - loss: 0.0846 - val_accuracy: 0.9351 - val_loss: 0.1862
# Epoch 290/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9824 - loss: 0.0909 - val_accuracy: 0.9481 - val_loss: 0.1654
# Epoch 291/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9722 - loss: 0.1065 - val_accuracy: 0.9481 - val_loss: 0.1600
# Epoch 292/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9780 - loss: 0.0845 - val_accuracy: 0.9351 - val_loss: 0.1767
# Epoch 293/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9713 - loss: 0.0902 - val_accuracy: 0.9481 - val_loss: 0.1638
# Epoch 294/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9798 - loss: 0.0922 - val_accuracy: 0.9481 - val_loss: 0.1644
# Epoch 295/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9745 - loss: 0.0901 - val_accuracy: 0.9221 - val_loss: 0.1698
# Epoch 296/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9878 - loss: 0.0867 - val_accuracy: 0.9481 - val_loss: 0.1622
# Epoch 297/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9804 - loss: 0.0876 - val_accuracy: 0.9221 - val_loss: 0.1699
# Epoch 298/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9808 - loss: 0.0849 - val_accuracy: 0.9351 - val_loss: 0.1737
# Epoch 299/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9704 - loss: 0.0899 - val_accuracy: 0.9481 - val_loss: 0.1598
# Epoch 300/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9824 - loss: 0.0853 - val_accuracy: 0.9481 - val_loss: 0.1502
# Epoch 301/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9809 - loss: 0.0755 - val_accuracy: 0.9481 - val_loss: 0.1673
# Epoch 302/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9726 - loss: 0.0846 - val_accuracy: 0.9481 - val_loss: 0.1591
# Epoch 303/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9835 - loss: 0.0784 - val_accuracy: 0.9481 - val_loss: 0.1595
# Epoch 304/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9769 - loss: 0.0931 - val_accuracy: 0.9481 - val_loss: 0.1615
# Epoch 305/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9861 - loss: 0.0736 - val_accuracy: 0.9481 - val_loss: 0.1526
# Epoch 306/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9828 - loss: 0.0691 - val_accuracy: 0.9481 - val_loss: 0.1638
# Epoch 307/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9795 - loss: 0.0878 - val_accuracy: 0.9610 - val_loss: 0.1606
# Epoch 308/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9828 - loss: 0.0662 - val_accuracy: 0.9481 - val_loss: 0.1518
# Epoch 309/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9748 - loss: 0.0828 - val_accuracy: 0.9351 - val_loss: 0.1728
# Epoch 310/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9815 - loss: 0.0814 - val_accuracy: 0.9481 - val_loss: 0.1654
# Epoch 311/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9872 - loss: 0.0825 - val_accuracy: 0.9481 - val_loss: 0.1494
# Epoch 312/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9824 - loss: 0.0712 - val_accuracy: 0.9481 - val_loss: 0.1549
# Epoch 313/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9852 - loss: 0.0720 - val_accuracy: 0.9481 - val_loss: 0.1628
# Epoch 314/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9835 - loss: 0.0724 - val_accuracy: 0.9481 - val_loss: 0.1577
# Epoch 315/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9856 - loss: 0.0672 - val_accuracy: 0.9610 - val_loss: 0.1503
# Epoch 316/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9935 - loss: 0.0668 - val_accuracy: 0.9740 - val_loss: 0.1425
# Epoch 317/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9854 - loss: 0.0641 - val_accuracy: 0.9481 - val_loss: 0.1498
# Epoch 318/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9774 - loss: 0.0661 - val_accuracy: 0.9610 - val_loss: 0.1497
# Epoch 319/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9869 - loss: 0.0724 - val_accuracy: 0.9481 - val_loss: 0.1491
# Epoch 320/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9837 - loss: 0.0674 - val_accuracy: 0.9481 - val_loss: 0.1652
# Epoch 321/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9763 - loss: 0.0657 - val_accuracy: 0.9351 - val_loss: 0.1722
# Epoch 322/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9761 - loss: 0.0850 - val_accuracy: 0.9481 - val_loss: 0.1719
# Epoch 323/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9717 - loss: 0.0922 - val_accuracy: 0.9481 - val_loss: 0.1743
# Epoch 324/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9800 - loss: 0.0721 - val_accuracy: 0.9481 - val_loss: 0.1623
# Epoch 325/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9802 - loss: 0.0774 - val_accuracy: 0.9610 - val_loss: 0.1756
# Epoch 326/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9843 - loss: 0.0712 - val_accuracy: 0.9610 - val_loss: 0.1580
# Epoch 327/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9806 - loss: 0.0699 - val_accuracy: 0.9481 - val_loss: 0.1556
# Epoch 328/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9796 - loss: 0.0594 - val_accuracy: 0.9481 - val_loss: 0.1693
# Epoch 329/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9906 - loss: 0.0705 - val_accuracy: 0.9481 - val_loss: 0.1684
# Epoch 330/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9876 - loss: 0.0591 - val_accuracy: 0.9481 - val_loss: 0.1694
# Epoch 331/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9787 - loss: 0.0754 - val_accuracy: 0.9481 - val_loss: 0.1603
# Epoch 332/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9911 - loss: 0.0629 - val_accuracy: 0.9610 - val_loss: 0.1654
# Epoch 333/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9932 - loss: 0.0533 - val_accuracy: 0.9481 - val_loss: 0.1761
# Epoch 334/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9835 - loss: 0.0869 - val_accuracy: 0.9610 - val_loss: 0.1634
# Epoch 335/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9828 - loss: 0.0853 - val_accuracy: 0.9481 - val_loss: 0.1653
# Epoch 336/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9880 - loss: 0.0562 - val_accuracy: 0.9481 - val_loss: 0.1527
# Epoch 337/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9841 - loss: 0.0472 - val_accuracy: 0.9610 - val_loss: 0.1534
# Epoch 338/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9896 - loss: 0.0669 - val_accuracy: 0.9481 - val_loss: 0.1693
# Epoch 339/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9928 - loss: 0.0441 - val_accuracy: 0.9610 - val_loss: 0.1584
# Epoch 340/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9898 - loss: 0.0543 - val_accuracy: 0.9610 - val_loss: 0.1661
# Epoch 341/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9939 - loss: 0.0516 - val_accuracy: 0.9481 - val_loss: 0.1676
# Epoch 342/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9863 - loss: 0.0594 - val_accuracy: 0.9610 - val_loss: 0.1521
# Epoch 343/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9817 - loss: 0.0506 - val_accuracy: 0.9481 - val_loss: 0.1669
# Epoch 344/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9874 - loss: 0.0566 - val_accuracy: 0.9481 - val_loss: 0.1845
# Epoch 345/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9889 - loss: 0.0591 - val_accuracy: 0.9610 - val_loss: 0.1619
# Epoch 346/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9833 - loss: 0.0630 - val_accuracy: 0.9610 - val_loss: 0.1644
# Epoch 347/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9789 - loss: 0.0636 - val_accuracy: 0.9481 - val_loss: 0.1846
# Epoch 348/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9874 - loss: 0.0561 - val_accuracy: 0.9481 - val_loss: 0.1875
# Epoch 349/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9841 - loss: 0.0498 - val_accuracy: 0.9610 - val_loss: 0.1660
# Epoch 350/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9880 - loss: 0.0552 - val_accuracy: 0.9610 - val_loss: 0.1621
# Epoch 351/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9915 - loss: 0.0467 - val_accuracy: 0.9610 - val_loss: 0.1640
# Epoch 352/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9841 - loss: 0.0612 - val_accuracy: 0.9610 - val_loss: 0.1602
# Epoch 353/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9924 - loss: 0.0483 - val_accuracy: 0.9610 - val_loss: 0.1700
# Epoch 354/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9874 - loss: 0.0601 - val_accuracy: 0.9610 - val_loss: 0.1608
# Epoch 355/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9939 - loss: 0.0495 - val_accuracy: 0.9610 - val_loss: 0.1590
# Epoch 356/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9913 - loss: 0.0504 - val_accuracy: 0.9740 - val_loss: 0.1683
# Epoch 357/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9889 - loss: 0.0566 - val_accuracy: 0.9610 - val_loss: 0.1690
# Epoch 358/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9874 - loss: 0.0574 - val_accuracy: 0.9610 - val_loss: 0.1629
# Epoch 359/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9852 - loss: 0.0499 - val_accuracy: 0.9610 - val_loss: 0.1617
# Epoch 360/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9830 - loss: 0.0541 - val_accuracy: 0.9610 - val_loss: 0.1739
# Epoch 361/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9841 - loss: 0.0580 - val_accuracy: 0.9481 - val_loss: 0.1895
# Epoch 362/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9961 - loss: 0.0652 - val_accuracy: 0.9610 - val_loss: 0.1757
# Epoch 363/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9900 - loss: 0.0408 - val_accuracy: 0.9610 - val_loss: 0.1705
# Epoch 364/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9830 - loss: 0.0603 - val_accuracy: 0.9481 - val_loss: 0.1877
# Epoch 365/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9972 - loss: 0.0472 - val_accuracy: 0.9481 - val_loss: 0.1701
# Epoch 366/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9856 - loss: 0.0529 - val_accuracy: 0.9610 - val_loss: 0.1571
# Epoch 367/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9809 - loss: 0.0449 - val_accuracy: 0.9740 - val_loss: 0.1746
# Epoch 368/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9852 - loss: 0.0517 - val_accuracy: 0.9610 - val_loss: 0.1760
# Epoch 369/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9896 - loss: 0.0373 - val_accuracy: 0.9481 - val_loss: 0.1632
# Epoch 370/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9893 - loss: 0.0461 - val_accuracy: 0.9610 - val_loss: 0.1651
# Epoch 371/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9867 - loss: 0.0551 - val_accuracy: 0.9740 - val_loss: 0.1723
# Epoch 372/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9906 - loss: 0.0576 - val_accuracy: 0.9610 - val_loss: 0.1571
# Epoch 373/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9943 - loss: 0.0407 - val_accuracy: 0.9610 - val_loss: 0.1627
# Epoch 374/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9819 - loss: 0.0602 - val_accuracy: 0.9610 - val_loss: 0.1871
# Epoch 375/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9900 - loss: 0.0570 - val_accuracy: 0.9610 - val_loss: 0.1814
# Epoch 376/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9900 - loss: 0.0467 - val_accuracy: 0.9610 - val_loss: 0.1673
# Epoch 377/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9900 - loss: 0.0591 - val_accuracy: 0.9610 - val_loss: 0.1744
# Epoch 378/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9809 - loss: 0.0504 - val_accuracy: 0.9610 - val_loss: 0.1804
# Epoch 379/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9898 - loss: 0.0410 - val_accuracy: 0.9610 - val_loss: 0.1842
# Epoch 380/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9972 - loss: 0.0416 - val_accuracy: 0.9610 - val_loss: 0.1595
# Epoch 381/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9880 - loss: 0.0458 - val_accuracy: 0.9610 - val_loss: 0.1509
# Epoch 382/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9900 - loss: 0.0484 - val_accuracy: 0.9610 - val_loss: 0.1604
# Epoch 383/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9874 - loss: 0.0353 - val_accuracy: 0.9610 - val_loss: 0.1711
# Epoch 384/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9898 - loss: 0.0420 - val_accuracy: 0.9610 - val_loss: 0.1717
# Epoch 385/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9911 - loss: 0.0497 - val_accuracy: 0.9610 - val_loss: 0.1740
# Epoch 386/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9943 - loss: 0.0389 - val_accuracy: 0.9610 - val_loss: 0.1861
# Epoch 387/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9891 - loss: 0.0391 - val_accuracy: 0.9610 - val_loss: 0.1742
# Epoch 388/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9891 - loss: 0.0447 - val_accuracy: 0.9610 - val_loss: 0.1659
# Epoch 389/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9983 - loss: 0.0328 - val_accuracy: 0.9481 - val_loss: 0.1651
# Epoch 390/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0316 - val_accuracy: 0.9610 - val_loss: 0.1604
# Epoch 391/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9956 - loss: 0.0425 - val_accuracy: 0.9610 - val_loss: 0.1530
# Epoch 392/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9924 - loss: 0.0494 - val_accuracy: 0.9610 - val_loss: 0.1470
# Epoch 393/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9978 - loss: 0.0419 - val_accuracy: 0.9610 - val_loss: 0.1436
# Epoch 394/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0364 - val_accuracy: 0.9610 - val_loss: 0.1531
# Epoch 395/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9926 - loss: 0.0464 - val_accuracy: 0.9610 - val_loss: 0.1717
# Epoch 396/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9989 - loss: 0.0359 - val_accuracy: 0.9610 - val_loss: 0.1730
# Epoch 397/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9978 - loss: 0.0357 - val_accuracy: 0.9610 - val_loss: 0.1639
# Epoch 398/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9852 - loss: 0.0423 - val_accuracy: 0.9610 - val_loss: 0.1672
# Epoch 399/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9943 - loss: 0.0299 - val_accuracy: 0.9610 - val_loss: 0.1665
# Epoch 400/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0377 - val_accuracy: 0.9610 - val_loss: 0.1603
# Epoch 401/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9963 - loss: 0.0369 - val_accuracy: 0.9481 - val_loss: 0.1565
# Epoch 402/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9983 - loss: 0.0380 - val_accuracy: 0.9610 - val_loss: 0.1536
# Epoch 403/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9943 - loss: 0.0382 - val_accuracy: 0.9610 - val_loss: 0.1789
# Epoch 404/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9852 - loss: 0.0351 - val_accuracy: 0.9610 - val_loss: 0.1622
# Epoch 405/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9852 - loss: 0.0387 - val_accuracy: 0.9481 - val_loss: 0.1510
# Epoch 406/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9978 - loss: 0.0311 - val_accuracy: 0.9740 - val_loss: 0.1714
# Epoch 407/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9924 - loss: 0.0330 - val_accuracy: 0.9610 - val_loss: 0.1603
# Epoch 408/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9939 - loss: 0.0404 - val_accuracy: 0.9481 - val_loss: 0.1612
# Epoch 409/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9926 - loss: 0.0418 - val_accuracy: 0.9481 - val_loss: 0.1882
# Epoch 410/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9943 - loss: 0.0444 - val_accuracy: 0.9351 - val_loss: 0.2037
# Epoch 411/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9946 - loss: 0.0330 - val_accuracy: 0.9481 - val_loss: 0.1851
# Epoch 412/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9989 - loss: 0.0450 - val_accuracy: 0.9610 - val_loss: 0.1716
# Epoch 413/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9950 - loss: 0.0413 - val_accuracy: 0.9610 - val_loss: 0.1592
# Epoch 414/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9898 - loss: 0.0390 - val_accuracy: 0.9610 - val_loss: 0.1656
# Epoch 415/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9974 - loss: 0.0384 - val_accuracy: 0.9610 - val_loss: 0.1674
# Epoch 416/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9983 - loss: 0.0366 - val_accuracy: 0.9610 - val_loss: 0.1711

# %% [markdown]
# #### Visualize Training Performance

# %%
# Get training and validation accuracy and loss from the history object
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation accuracy
plt.figure()
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
# Plot training and validation loss
plt.figure()
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
# Get the final accuracy and loss for the last epoch
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

# Print the final accuracy and loss
print("Final Training Accuracy:", final_train_acc)
print("Final Validation Accuracy:", final_val_acc)
print("Final Training Loss:", final_train_loss)
print("Final Validation Loss:", final_val_loss)
# Out:
# Final Training Accuracy: 0.9967213273048401
# Final Validation Accuracy: 0.9610389471054077
# Final Training Loss: 0.044577814638614655
# Final Validation Loss: 0.171139195561409

# %%
# Save the entire model as a `.keras` zip archive.
combined_model.save('MTFN_32Rank.keras')

# %% [markdown]
# ## Visualizations

# %% [markdown]
# #### VGG Feature Maps

# %%
iterator = iter(train_dataset)
first_element, label = next(iterator)

# %%
# Load the existing model (if needed)
# combined_model = tf.keras.models.load_model('AD_Multimodal_Model.keras')

# Choose a layer to visualize (e.g., the output of the first convolutional layer)
layer_name = 'block1_conv1'
intermediate_layer_model = tf.keras.models.Model(inputs=combined_model.input, outputs=combined_model.get_layer(layer_name).output)

# Load and preprocess an image
def load_and_preprocess_image(image_path):
    img = tf.keras.utils.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.vgg16.preprocess_input(img_array)
    return img_array

image_path = '/home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I124297.png'
preprocessed_image = load_and_preprocess_image(image_path)

# Get the feature maps
feature_maps = intermediate_layer_model.predict(first_element)

# Visualize the feature maps
def visualize_feature_maps(feature_maps):
    num_feature_maps = feature_maps.shape[-1]
    
    # Determine the layout for subplots (adjust as needed)
    grid_size = int(np.ceil(np.sqrt(num_feature_maps)))
    
    plt.figure(figsize=(12, 12))
    for i in range(num_feature_maps):
        plt.subplot(grid_size, grid_size, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(feature_maps[0, :, :, i], cmap='gray')
    plt.show()

visualize_feature_maps(feature_maps)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
plt.imshow(feature_maps[0, :, :, 1], cmap='CMRmap')
# plt.savefig('VGG_Feature_Map.png', dpi=300)  # Save as PNG with 300 DPI

# %% [markdown]
# ValueError: 'green' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
