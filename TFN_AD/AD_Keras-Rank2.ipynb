# %% [markdown]
# ## Imports

# %%
import keras
import numpy as np

import time

import os

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow.keras.layers as tfl

# import misc

import pandas as pd

import datetime

import glob

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, GlobalAveragePooling2D, Input, Conv1D, MaxPooling1D, Flatten, \
                                    Masking, LSTM, Softmax, Multiply, Layer, Concatenate, Lambda, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# from keras.utils import np_utils
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.datasets import load_files
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
# import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.preprocessing import image_dataset_from_directory

from sklearn.model_selection import train_test_split

import tensorly as tl
from tensorly.decomposition import tucker
# Out:
# WARNING:tensorflow:From C:\Users\myh04\anaconda3\envs\tf_gpu_env\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Set up imports & packages.

tl.set_backend('tensorflow')  # Use TensorFlow tensors instead of NumPy

# %% [markdown]
# ## Declare Sub-Models

# %%
# Default 16.
feature_vector_size = 2

# %% [markdown]
# ### Visual Embedder (VGG-16)

# %%
def build_visual_embedder():
    # Load the VGG16 model without the top layers
    visual_base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze the base model to retain pretrained weights during training
    visual_base_model.trainable = False

    # Add a top for 3-way classification
    x = visual_base_model.output
    x = GlobalAveragePooling2D()(x)  # Global Average Pooling layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(256, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization

    visual_base_features = Dense(feature_vector_size, activation='relu')(x) 

    # Define the final model
    visual_model = Model(inputs=visual_base_model.input, outputs=visual_base_features, name="VisualEmbedder")
    return visual_model

# %% [markdown]
# ### Demographic Embedder

# %%
def build_demographics_embedder():
    # Input layer for demographics data
    input_layer = Input(shape=(6, ), name="demographics_input")

    x = Dense(16, activation='relu')(input_layer)
    x = Dropout(0.1)(x)
    x = Dense(4, activation='relu')(x)
    x = Dropout(0.1)(x)
    
    # Classification head
    demographics_base_features = Dense(feature_vector_size, activation='relu')(x)
    
    # Define the model
    demographics_model = Model(inputs=input_layer, outputs=demographics_base_features, name="DemographicsEmbedder")
    return demographics_model

# %% [markdown]
# ### Time-Series Embedder

# %%
max_seq_length = 6

# %%
def build_time_embedder():
    # Input layer for time series data (4 input variables)
    time_series_input = Input(shape=(max_seq_length, 4), name="time_series_input")
    masked_input = Masking(mask_value=0.0)(time_series_input)

    # Use the last hidden state
    x = LSTM(32, return_sequences=False)(masked_input)

    # Dense layer to create time series output
    time_base_features = Dense(feature_vector_size, activation="relu")(x)
    
    # Define the model
    time_model = Model(inputs=time_series_input, outputs=time_base_features, name="TimeSeriesEmbedder")
    return time_model

# %% [markdown]
# ## Joint Model

# %%
visual_dim = feature_vector_size
demographics_dim = feature_vector_size
time_dim = feature_vector_size

# Tensor Fusion Layer
def tensor_fusion_layer(inputs):
    """
    Tensor fusion using Kronecker product via `tf.einsum`.
    Adds a 1 to each input tensor for core (0,0,0) alignment.
    """
    visual, demographics, time_series = inputs

    # Add a "1" to the feature vectors
    visual_h = tf.concat([tf.ones((tf.shape(visual)[0], 1)), visual], axis=1)
    demographics_h = tf.concat([tf.ones((tf.shape(demographics)[0], 1)), demographics], axis=1)
    time_series_h = tf.concat([tf.ones((tf.shape(time_series)[0], 1)), time_series], axis=1)

    # Perform Kronecker product using tf.einsum
    outer_xy = tf.einsum('bi,bj->bij', demographics_h, time_series_h)  # Shape: (batch_size, d_dim, t_dim)
    outer_xyz = tf.einsum('bij,bk->bijk', outer_xy, visual_h)  # Shape: (batch_size, d_dim, t_dim, v_dim)

    # core, factors = tucker(outer_xyz, rank=(8,8,8))

    # # Flatten the fused tensor
    fused_tensor = tf.reshape(outer_xyz, (tf.shape(outer_xyz)[0], -1))  # Shape: (batch_size, d_dim * t_dim * v_dim)

    return fused_tensor #outer_xyz

# %%
# Visual embedder
visual_embedder = build_visual_embedder()

# Demographics embedder
demographics_embedder = build_demographics_embedder()

# Time Series Embedder
time_embedder = build_time_embedder()

# Outputs from embedders
visual_features = visual_embedder.output
demographics_features = demographics_embedder.output
time_features = time_embedder.output

# Output shape of the fused tensor
fused_tensor_shape = (None, (visual_dim + 1) * (demographics_dim + 1) * (time_dim + 1))

# Apply Tensor Fusion
fused_features = Lambda(tensor_fusion_layer, output_shape=fused_tensor_shape)([visual_features, demographics_features, time_features])

# Add final classification layers
x = Dense(128, activation='relu')(fused_features)
x = Dense(64, activation='relu')(x)
final_output = Dense(3, activation='softmax', name="final_output")(x)

# Define the combined model
combined_model = Model(inputs=[visual_embedder.input, demographics_embedder.input, time_embedder.input], 
                       outputs=final_output, name="CombinedModel")

# %% [markdown]
# #### Joint-Model Structure

# %%
combined_model.summary()
# Out:
# Model: "CombinedModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ demographics_input  │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    262,656 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │        112 │ demographics_inp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_series_input   │ (None, 6, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 6, 4)      │          0 │ time_series_inpu… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4)         │         68 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 6, 4)      │          0 │ time_series_inpu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 6)         │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4)         │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 32)        │      4,736 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 2)         │        514 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 2)         │         10 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 2)         │         66 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, None, 27)  │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_6[0][0],    │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, None, 128) │      3,584 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, None, 64)  │      8,256 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, None, 3)   │        195 │ dense_9[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,388,869 (58.70 MB)
#  Trainable params: 674,181 (2.57 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# # Train Joint-Model

# %% [markdown]
# #### Load Data

# %%
# Mapping for string labels to integers
label_mapping = {"CN": 0, "MCI": 1, "Dementia": 2}

# %%
manifest = pd.read_csv("./AD_Patient_Manifest.csv")
manifest
# Out:
#            PTID                         path
# 0    002_S_0295  patients_csv\002_S_0295.pkl
# 1    002_S_0413  patients_csv\002_S_0413.pkl
# 2    002_S_0619  patients_csv\002_S_0619.pkl
# 3    002_S_0685  patients_csv\002_S_0685.pkl
# 4    002_S_0729  patients_csv\002_S_0729.pkl
# ..          ...                          ...
# 377  137_S_0994  patients_csv\137_S_0994.pkl
# 378  137_S_1041  patients_csv\137_S_1041.pkl
# 379  137_S_1414  patients_csv\137_S_1414.pkl
# 380  941_S_1194  patients_csv\941_S_1194.pkl
# 381  941_S_1202  patients_csv\941_S_1202.pkl
#
# [382 rows x 2 columns]

# %%
patient_df = pd.read_pickle("patients_csv/002_S_0295.pkl")
patient_df
# Out:
#    RID        PTID  DX  MMSE   AGE PTGENDER  PTEDUCAT         PTETHCAT  \
# 0  295  002_S_0295  CN  28.0  84.8     Male        18  Not Hisp/Latino
# 1  295  002_S_0295  CN  28.0  84.8     Male        18  Not Hisp/Latino
# 2  295  002_S_0295  CN  30.0  84.8     Male        18  Not Hisp/Latino
# 3  295  002_S_0295  CN  29.0  84.8     Male        18  Not Hisp/Latino
# 4  295  002_S_0295  CN  28.0  84.8     Male        18  Not Hisp/Latino
#
#   PTRACCAT  PTMARRY  ...  ADAS13  ADASQ4  Years_bl    EXAMDATE  \
# 0    White  Married  ...    4.00     1.0   0.00000  2006-05-09
# 1    White  Married  ...    6.33     1.0   0.48460  2006-11-02
# 2    White  Married  ...    5.67     1.0   1.04312  2007-05-25
# 3    White  Married  ...    5.67     2.0   2.23956  2008-08-04
# 4    White  Married  ...    6.67     3.0   2.99521  2009-05-07
#
#                                           image_path DX_encoded  \
# 0  /home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I118...          0
# 1  /home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I118...          0
# 2  /home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I640...          0
# 3  /home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I123...          0
# 4  /home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I150...          0
#
#    PTGENDER_encoded  PTETHCAT_encoded  PTRACCAT_encoded  PTMARRY_encoded
# 0                 1                 1                 2                1
# 1                 1                 1                 2                1
# 2                 1                 1                 2                1
# 3                 1                 1                 2                1
# 4                 1                 1                 2                1
#
# [5 rows x 21 columns]

# %%
# Load all data into memory. Not elegant, but works.
def load_all_data(manifest, target_size=(224, 224), demographic_columns=None, time_series_columns=None, label_mapping=None):
    image_data = []
    demographics_data = []
    time_series_data = []
    labels = []
    label_mapping = label_mapping or {}

    for _, row in manifest.iterrows():
        patient_path = row["path"]
        patient_df = pd.read_pickle(patient_path)

        # ✅ [중요] 경로 변경
        patient_df['image_path'] = patient_df['image_path'].apply(
            lambda x: x.replace("/home/mason/ADNI_Dataset/", "../ADNI_Dataset/")
        )

        # Load image data
        image_paths = [patient_df['image_path'].iloc[0]]
        for path in image_paths:
            # print(path)
            img = load_img(path, target_size=target_size)
            img_array = img_to_array(img)
            img_array = preprocess_input(img_array)
            image_data.append(img_array)

        # Process demographics data
        if demographic_columns is None:
            raise ValueError("Please specify the demographics columns.")
        
        # Get first row of demographic data (since it doesn't change over time)
        demographics = patient_df[demographic_columns].iloc[0]
        demographics = demographics.values.astype(np.float32)  # Convert to NumPy array
        demographics_data.append(demographics)

        # Process time series data
        if time_series_columns is None:
            raise ValueError("Please specify the time series columns.")
        
        # Extract the relevant time series columns
        time_series = patient_df[time_series_columns].values  # Extract as NumPy array

        # Truncate or pad to max_seq_length
        if len(time_series) > max_seq_length:
            time_series = time_series[:max_seq_length, :]
        elif len(time_series) < max_seq_length:
            padding = np.zeros((max_seq_length - len(time_series), len(time_series_columns)))
            time_series = np.vstack([time_series, padding])
        time_series_data.append(time_series)

        # Load labels
        label_str = patient_df['DX'].iloc[0]
        label_int = label_mapping[label_str]
        labels.append(label_int)

    # Convert to numpy arrays
    image_data = np.array(image_data, dtype=np.float32)
    demographics_data = np.array(demographics_data, dtype=np.float32)
    time_series_data = np.array(time_series_data, dtype=np.float32)
    labels = np.array(labels, dtype=np.int32)

    return image_data, demographics_data, time_series_data, labels

# %%
# Demographic variables to extract
demographic_columns = ['AGE', 'PTEDUCAT', 'PTGENDER_encoded', 
                        'PTETHCAT_encoded', 'PTRACCAT_encoded', 'PTMARRY_encoded']
# Time series variables to extract
time_series_columns = ['Years_bl', 'ADAS11', 'ADAS13', 'ADASQ4']

# Load all data into memory
image_data, demographics_data, time_series_data, labels = load_all_data(manifest, target_size=(224, 224), demographic_columns=demographic_columns, 
                                                      time_series_columns=time_series_columns, label_mapping=label_mapping)

# Split the data
test_size = 0.2  # 20% of the data for testing

(image_train, image_test,
 demographics_train, demographics_test,
 time_train, time_test,
 labels_train, labels_test) = train_test_split(
    image_data, demographics_data, time_series_data, labels, test_size=test_size, random_state=42, stratify=labels
)

# %%
batch_size = 64

# Create training dataset
train_dataset = tf.data.Dataset.from_tensor_slices(((image_train, demographics_train, time_train), labels_train))
train_dataset = train_dataset.shuffle(100).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Create testing (validation) dataset
test_dataset = tf.data.Dataset.from_tensor_slices(((image_test, demographics_test, time_test), labels_test))
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
print(f"Image train shape: {image_train.shape}")
print(f"Demographics train shape: {demographics_train.shape}")
print(f"Time train shape: {time_train.shape}")
print(f"Labels train shape: {labels_train.shape}")
# Out:
# Image train shape: (305, 224, 224, 3)
# Demographics train shape: (305, 6)
# Time train shape: (305, 6, 4)
# Labels train shape: (305,)

# %% [markdown]
# #### Train the Model

# %%
# Compile the model
combined_model.compile(optimizer=Adam(learning_rate=0.0001),
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

# %%
print("Model inputs:", combined_model.input)
# Out:
# Model inputs: [<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>, <KerasTensor shape=(None, 6), dtype=float32, sparse=False, name=demographics_input>, <KerasTensor shape=(None, 6, 4), dtype=float32, sparse=False, name=time_series_input>]

# %%
# Early stopping to prevent redundant training.
early_stopping = EarlyStopping(monitor='val_accuracy', patience=100, restore_best_weights=True)

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_built_with_cuda())
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.18.0
# False
# []

# %%
# Train the model
history = combined_model.fit(
    train_dataset, 
    validation_data=test_dataset,
    epochs=600,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/600
# C:\Users\myh04\anaconda3\envs\tf_gpu_env\lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'demographics_input', 'time_series_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.4061 - loss: 1.4175 - val_accuracy: 0.4026 - val_loss: 1.0344
# Epoch 2/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4549 - loss: 0.9962 - val_accuracy: 0.5195 - val_loss: 0.9288
# Epoch 3/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5858 - loss: 0.8978 - val_accuracy: 0.5584 - val_loss: 0.8702
# Epoch 4/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5802 - loss: 0.8944 - val_accuracy: 0.5974 - val_loss: 0.8495
# Epoch 5/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6117 - loss: 0.8340 - val_accuracy: 0.5844 - val_loss: 0.8343
# Epoch 6/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5913 - loss: 0.8236 - val_accuracy: 0.5844 - val_loss: 0.8129
# Epoch 7/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6143 - loss: 0.7679 - val_accuracy: 0.5844 - val_loss: 0.7927
# Epoch 8/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6404 - loss: 0.7795 - val_accuracy: 0.5584 - val_loss: 0.7781
# Epoch 9/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.5804 - loss: 0.7689 - val_accuracy: 0.5714 - val_loss: 0.7633
# Epoch 10/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 957ms/step - accuracy: 0.5657 - loss: 0.7657 - val_accuracy: 0.5714 - val_loss: 0.7505
# Epoch 11/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 967ms/step - accuracy: 0.6017 - loss: 0.7301 - val_accuracy: 0.5714 - val_loss: 0.7399
# Epoch 12/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 982ms/step - accuracy: 0.5993 - loss: 0.7378 - val_accuracy: 0.5844 - val_loss: 0.7301
# Epoch 13/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 988ms/step - accuracy: 0.5960 - loss: 0.7230 - val_accuracy: 0.5844 - val_loss: 0.7185
# Epoch 14/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6169 - loss: 0.7123 - val_accuracy: 0.6883 - val_loss: 0.7033
# Epoch 15/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 971ms/step - accuracy: 0.7094 - loss: 0.6992 - val_accuracy: 0.7013 - val_loss: 0.6891
# Epoch 16/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 973ms/step - accuracy: 0.7122 - loss: 0.7035 - val_accuracy: 0.7013 - val_loss: 0.6770
# Epoch 17/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 958ms/step - accuracy: 0.7085 - loss: 0.6619 - val_accuracy: 0.7143 - val_loss: 0.6660
# Epoch 18/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.7286 - loss: 0.6744 - val_accuracy: 0.7403 - val_loss: 0.6563
# Epoch 19/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 994ms/step - accuracy: 0.7127 - loss: 0.6700 - val_accuracy: 0.7143 - val_loss: 0.6513
# Epoch 20/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 993ms/step - accuracy: 0.7537 - loss: 0.6520 - val_accuracy: 0.7143 - val_loss: 0.6408
# Epoch 21/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 963ms/step - accuracy: 0.7653 - loss: 0.6421 - val_accuracy: 0.7143 - val_loss: 0.6347
# Epoch 22/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 972ms/step - accuracy: 0.7690 - loss: 0.6100 - val_accuracy: 0.7143 - val_loss: 0.6283
# Epoch 23/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 962ms/step - accuracy: 0.7683 - loss: 0.6247 - val_accuracy: 0.7273 - val_loss: 0.6204
# Epoch 24/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 975ms/step - accuracy: 0.7720 - loss: 0.6092 - val_accuracy: 0.7273 - val_loss: 0.6136
# Epoch 25/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 979ms/step - accuracy: 0.7851 - loss: 0.5573 - val_accuracy: 0.7273 - val_loss: 0.6078
# Epoch 26/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 980ms/step - accuracy: 0.7640 - loss: 0.6106 - val_accuracy: 0.7403 - val_loss: 0.6028
# Epoch 27/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 995ms/step - accuracy: 0.7797 - loss: 0.5958 - val_accuracy: 0.7403 - val_loss: 0.5959
# Epoch 28/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 959ms/step - accuracy: 0.7632 - loss: 0.5914 - val_accuracy: 0.7273 - val_loss: 0.5897
# Epoch 29/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 962ms/step - accuracy: 0.7862 - loss: 0.5730 - val_accuracy: 0.7403 - val_loss: 0.5847
# Epoch 30/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 968ms/step - accuracy: 0.7868 - loss: 0.5731 - val_accuracy: 0.7532 - val_loss: 0.5792
# Epoch 31/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 978ms/step - accuracy: 0.7701 - loss: 0.5697 - val_accuracy: 0.7662 - val_loss: 0.5746
# Epoch 32/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 971ms/step - accuracy: 0.8101 - loss: 0.5326 - val_accuracy: 0.7532 - val_loss: 0.5696
# Epoch 33/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7744 - loss: 0.5418 - val_accuracy: 0.7532 - val_loss: 0.5661
# Epoch 34/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 970ms/step - accuracy: 0.7784 - loss: 0.5404 - val_accuracy: 0.7403 - val_loss: 0.5605
# Epoch 35/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 954ms/step - accuracy: 0.7903 - loss: 0.5321 - val_accuracy: 0.7532 - val_loss: 0.5556
# Epoch 36/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 960ms/step - accuracy: 0.7827 - loss: 0.5205 - val_accuracy: 0.7792 - val_loss: 0.5524
# Epoch 37/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 972ms/step - accuracy: 0.7921 - loss: 0.5360 - val_accuracy: 0.7792 - val_loss: 0.5480
# Epoch 38/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 983ms/step - accuracy: 0.8094 - loss: 0.5116 - val_accuracy: 0.7662 - val_loss: 0.5427
# Epoch 39/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 995ms/step - accuracy: 0.7951 - loss: 0.5322 - val_accuracy: 0.7792 - val_loss: 0.5384
# Epoch 40/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.7860 - loss: 0.5319 - val_accuracy: 0.7792 - val_loss: 0.5363
# Epoch 41/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.8075 - loss: 0.5097 - val_accuracy: 0.7662 - val_loss: 0.5327
# Epoch 42/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8188 - loss: 0.5076 - val_accuracy: 0.7792 - val_loss: 0.5277
# Epoch 43/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8232 - loss: 0.5080 - val_accuracy: 0.7792 - val_loss: 0.5225
# Epoch 44/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8049 - loss: 0.5227 - val_accuracy: 0.7922 - val_loss: 0.5170
# Epoch 45/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8271 - loss: 0.5011 - val_accuracy: 0.7922 - val_loss: 0.5119
# Epoch 46/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.8297 - loss: 0.5047 - val_accuracy: 0.8052 - val_loss: 0.5066
# Epoch 47/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8377 - loss: 0.4812 - val_accuracy: 0.8052 - val_loss: 0.5011
# Epoch 48/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.8455 - loss: 0.4715 - val_accuracy: 0.8182 - val_loss: 0.4957
# Epoch 49/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8110 - loss: 0.5062 - val_accuracy: 0.8182 - val_loss: 0.4945
# Epoch 50/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.8216 - loss: 0.4943 - val_accuracy: 0.8182 - val_loss: 0.4871
# Epoch 51/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8418 - loss: 0.4700 - val_accuracy: 0.8182 - val_loss: 0.4805
# Epoch 52/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8297 - loss: 0.4745 - val_accuracy: 0.8182 - val_loss: 0.4749
# Epoch 53/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8286 - loss: 0.5017 - val_accuracy: 0.8312 - val_loss: 0.4668
# Epoch 54/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 949ms/step - accuracy: 0.8327 - loss: 0.4717 - val_accuracy: 0.8312 - val_loss: 0.4643
# Epoch 55/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.8258 - loss: 0.4644 - val_accuracy: 0.8312 - val_loss: 0.4589
# Epoch 56/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 943ms/step - accuracy: 0.8191 - loss: 0.4770 - val_accuracy: 0.8312 - val_loss: 0.4546
# Epoch 57/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.8355 - loss: 0.4487 - val_accuracy: 0.8442 - val_loss: 0.4489
# Epoch 58/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 949ms/step - accuracy: 0.8353 - loss: 0.4712 - val_accuracy: 0.8442 - val_loss: 0.4437
# Epoch 59/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 979ms/step - accuracy: 0.8477 - loss: 0.4291 - val_accuracy: 0.8442 - val_loss: 0.4408
# Epoch 60/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 935ms/step - accuracy: 0.8058 - loss: 0.4997 - val_accuracy: 0.8442 - val_loss: 0.4395
# Epoch 61/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.8379 - loss: 0.4321 - val_accuracy: 0.8442 - val_loss: 0.4365
# Epoch 62/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 935ms/step - accuracy: 0.8171 - loss: 0.4577 - val_accuracy: 0.8442 - val_loss: 0.4339
# Epoch 63/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.8273 - loss: 0.4552 - val_accuracy: 0.8442 - val_loss: 0.4311
# Epoch 64/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 962ms/step - accuracy: 0.8412 - loss: 0.4032 - val_accuracy: 0.8442 - val_loss: 0.4302
# Epoch 65/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8434 - loss: 0.4225 - val_accuracy: 0.8312 - val_loss: 0.4277
# Epoch 66/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 978ms/step - accuracy: 0.8362 - loss: 0.4116 - val_accuracy: 0.8571 - val_loss: 0.4233
# Epoch 67/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 977ms/step - accuracy: 0.8343 - loss: 0.4109 - val_accuracy: 0.8442 - val_loss: 0.4210
# Epoch 68/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 945ms/step - accuracy: 0.8401 - loss: 0.4302 - val_accuracy: 0.8442 - val_loss: 0.4197
# Epoch 69/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.8423 - loss: 0.4308 - val_accuracy: 0.8442 - val_loss: 0.4170
# Epoch 70/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 954ms/step - accuracy: 0.8336 - loss: 0.4223 - val_accuracy: 0.8571 - val_loss: 0.4177
# Epoch 71/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.8358 - loss: 0.4153 - val_accuracy: 0.8442 - val_loss: 0.4128
# Epoch 72/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 990ms/step - accuracy: 0.8216 - loss: 0.4426 - val_accuracy: 0.8442 - val_loss: 0.4091
# Epoch 73/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 941ms/step - accuracy: 0.8258 - loss: 0.4354 - val_accuracy: 0.8571 - val_loss: 0.4121
# Epoch 74/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 933ms/step - accuracy: 0.8536 - loss: 0.4136 - val_accuracy: 0.8442 - val_loss: 0.4073
# Epoch 75/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.8566 - loss: 0.4131 - val_accuracy: 0.8442 - val_loss: 0.4014
# Epoch 76/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.8199 - loss: 0.4516 - val_accuracy: 0.8312 - val_loss: 0.4005
# Epoch 77/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.8358 - loss: 0.4187 - val_accuracy: 0.8442 - val_loss: 0.4028
# Epoch 78/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 957ms/step - accuracy: 0.8414 - loss: 0.4325 - val_accuracy: 0.8442 - val_loss: 0.4017
# Epoch 79/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 969ms/step - accuracy: 0.8560 - loss: 0.4126 - val_accuracy: 0.8442 - val_loss: 0.3973
# Epoch 80/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.8488 - loss: 0.4238 - val_accuracy: 0.8442 - val_loss: 0.3927
# Epoch 81/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.8516 - loss: 0.4085 - val_accuracy: 0.8442 - val_loss: 0.3958
# Epoch 82/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.8252 - loss: 0.4354 - val_accuracy: 0.8442 - val_loss: 0.3895
# Epoch 83/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.8545 - loss: 0.4092 - val_accuracy: 0.8442 - val_loss: 0.3879
# Epoch 84/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 949ms/step - accuracy: 0.8710 - loss: 0.3795 - val_accuracy: 0.8571 - val_loss: 0.3829
# Epoch 85/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 977ms/step - accuracy: 0.8484 - loss: 0.3908 - val_accuracy: 0.8571 - val_loss: 0.3817
# Epoch 86/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 941ms/step - accuracy: 0.8440 - loss: 0.4057 - val_accuracy: 0.8571 - val_loss: 0.3807
# Epoch 87/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 940ms/step - accuracy: 0.8638 - loss: 0.3706 - val_accuracy: 0.8442 - val_loss: 0.3830
# Epoch 88/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.8399 - loss: 0.4145 - val_accuracy: 0.8312 - val_loss: 0.3842
# Epoch 89/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.8705 - loss: 0.3755 - val_accuracy: 0.8442 - val_loss: 0.3785
# Epoch 90/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 949ms/step - accuracy: 0.8603 - loss: 0.3879 - val_accuracy: 0.8571 - val_loss: 0.3715
# Epoch 91/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.8360 - loss: 0.4346 - val_accuracy: 0.8571 - val_loss: 0.3693
# Epoch 92/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 980ms/step - accuracy: 0.8367 - loss: 0.4109 - val_accuracy: 0.8701 - val_loss: 0.3697
# Epoch 93/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.8586 - loss: 0.3873 - val_accuracy: 0.8442 - val_loss: 0.3722
# Epoch 94/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.8464 - loss: 0.3989 - val_accuracy: 0.8701 - val_loss: 0.3665
# Epoch 95/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 940ms/step - accuracy: 0.8443 - loss: 0.3881 - val_accuracy: 0.8571 - val_loss: 0.3619
# Epoch 96/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 949ms/step - accuracy: 0.8532 - loss: 0.3553 - val_accuracy: 0.8571 - val_loss: 0.3598
# Epoch 97/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 956ms/step - accuracy: 0.8647 - loss: 0.3846 - val_accuracy: 0.8571 - val_loss: 0.3580
# Epoch 98/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 968ms/step - accuracy: 0.8651 - loss: 0.3576 - val_accuracy: 0.8701 - val_loss: 0.3570
# Epoch 99/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.8525 - loss: 0.3814 - val_accuracy: 0.8571 - val_loss: 0.3546
# Epoch 100/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 940ms/step - accuracy: 0.8712 - loss: 0.3366 - val_accuracy: 0.8571 - val_loss: 0.3549
# Epoch 101/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.8426 - loss: 0.3985 - val_accuracy: 0.8571 - val_loss: 0.3518
# Epoch 102/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 941ms/step - accuracy: 0.8827 - loss: 0.3319 - val_accuracy: 0.8701 - val_loss: 0.3457
# Epoch 103/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.8627 - loss: 0.3628 - val_accuracy: 0.8571 - val_loss: 0.3436
# Epoch 104/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 950ms/step - accuracy: 0.8606 - loss: 0.3717 - val_accuracy: 0.8701 - val_loss: 0.3439
# Epoch 105/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 980ms/step - accuracy: 0.8786 - loss: 0.3214 - val_accuracy: 0.8701 - val_loss: 0.3423
# Epoch 106/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.8799 - loss: 0.3628 - val_accuracy: 0.8701 - val_loss: 0.3379
# Epoch 107/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 943ms/step - accuracy: 0.8755 - loss: 0.3502 - val_accuracy: 0.8701 - val_loss: 0.3334
# Epoch 108/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.8699 - loss: 0.3360 - val_accuracy: 0.8701 - val_loss: 0.3318
# Epoch 109/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 945ms/step - accuracy: 0.8625 - loss: 0.3511 - val_accuracy: 0.8571 - val_loss: 0.3324
# Epoch 110/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.8608 - loss: 0.3378 - val_accuracy: 0.8701 - val_loss: 0.3294
# Epoch 111/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8762 - loss: 0.3426 - val_accuracy: 0.8831 - val_loss: 0.3212
# Epoch 112/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 968ms/step - accuracy: 0.8832 - loss: 0.3435 - val_accuracy: 0.8701 - val_loss: 0.3172
# Epoch 113/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 977ms/step - accuracy: 0.8501 - loss: 0.3463 - val_accuracy: 0.8571 - val_loss: 0.3222
# Epoch 114/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 967ms/step - accuracy: 0.8758 - loss: 0.3242 - val_accuracy: 0.8961 - val_loss: 0.3114
# Epoch 115/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 968ms/step - accuracy: 0.8678 - loss: 0.3103 - val_accuracy: 0.8961 - val_loss: 0.3091
# Epoch 116/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.8723 - loss: 0.3307 - val_accuracy: 0.8701 - val_loss: 0.3115
# Epoch 117/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 954ms/step - accuracy: 0.8740 - loss: 0.2961 - val_accuracy: 0.8831 - val_loss: 0.3035
# Epoch 118/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 978ms/step - accuracy: 0.8971 - loss: 0.2973 - val_accuracy: 0.8701 - val_loss: 0.3024
# Epoch 119/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9019 - loss: 0.2837 - val_accuracy: 0.8961 - val_loss: 0.3011
# Epoch 120/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.8541 - loss: 0.3341 - val_accuracy: 0.8701 - val_loss: 0.3052
# Epoch 121/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 941ms/step - accuracy: 0.8786 - loss: 0.2937 - val_accuracy: 0.8831 - val_loss: 0.2930
# Epoch 122/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 957ms/step - accuracy: 0.8843 - loss: 0.2967 - val_accuracy: 0.8961 - val_loss: 0.2875
# Epoch 123/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.8989 - loss: 0.3096 - val_accuracy: 0.8701 - val_loss: 0.2869
# Epoch 124/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 959ms/step - accuracy: 0.8940 - loss: 0.2948 - val_accuracy: 0.8701 - val_loss: 0.2850
# Epoch 125/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 963ms/step - accuracy: 0.9019 - loss: 0.2776 - val_accuracy: 0.8961 - val_loss: 0.2772
# Epoch 126/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.8993 - loss: 0.3325 - val_accuracy: 0.8961 - val_loss: 0.2723
# Epoch 127/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 940ms/step - accuracy: 0.9108 - loss: 0.2540 - val_accuracy: 0.8701 - val_loss: 0.2769
# Epoch 128/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 950ms/step - accuracy: 0.8921 - loss: 0.2923 - val_accuracy: 0.8961 - val_loss: 0.2695
# Epoch 129/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.8956 - loss: 0.2710 - val_accuracy: 0.8961 - val_loss: 0.2658
# Epoch 130/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.9030 - loss: 0.2835 - val_accuracy: 0.8961 - val_loss: 0.2690
# Epoch 131/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 970ms/step - accuracy: 0.9156 - loss: 0.2371 - val_accuracy: 0.8961 - val_loss: 0.2632
# Epoch 132/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.9075 - loss: 0.2813 - val_accuracy: 0.9221 - val_loss: 0.2579
# Epoch 133/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 941ms/step - accuracy: 0.9230 - loss: 0.2340 - val_accuracy: 0.8961 - val_loss: 0.2632
# Epoch 134/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9191 - loss: 0.2554 - val_accuracy: 0.9091 - val_loss: 0.2581
# Epoch 135/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 949ms/step - accuracy: 0.9000 - loss: 0.2534 - val_accuracy: 0.9221 - val_loss: 0.2446
# Epoch 136/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.9336 - loss: 0.2384 - val_accuracy: 0.9091 - val_loss: 0.2422
# Epoch 137/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 956ms/step - accuracy: 0.9219 - loss: 0.2571 - val_accuracy: 0.9091 - val_loss: 0.2448
# Epoch 138/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 973ms/step - accuracy: 0.9125 - loss: 0.2511 - val_accuracy: 0.9221 - val_loss: 0.2348
# Epoch 139/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9276 - loss: 0.2488 - val_accuracy: 0.9221 - val_loss: 0.2333
# Epoch 140/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9343 - loss: 0.2283 - val_accuracy: 0.9091 - val_loss: 0.2344
# Epoch 141/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9404 - loss: 0.2183 - val_accuracy: 0.9351 - val_loss: 0.2281
# Epoch 142/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.9304 - loss: 0.2467 - val_accuracy: 0.9351 - val_loss: 0.2230
# Epoch 143/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 959ms/step - accuracy: 0.9249 - loss: 0.2271 - val_accuracy: 0.9091 - val_loss: 0.2373
# Epoch 144/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 968ms/step - accuracy: 0.9271 - loss: 0.2240 - val_accuracy: 0.9351 - val_loss: 0.2175
# Epoch 145/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.9376 - loss: 0.2104 - val_accuracy: 0.9351 - val_loss: 0.2143
# Epoch 146/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9471 - loss: 0.2230 - val_accuracy: 0.9221 - val_loss: 0.2204
# Epoch 147/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9384 - loss: 0.2092 - val_accuracy: 0.9351 - val_loss: 0.2124
# Epoch 148/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.9478 - loss: 0.1903 - val_accuracy: 0.9351 - val_loss: 0.2116
# Epoch 149/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.9393 - loss: 0.2128 - val_accuracy: 0.9351 - val_loss: 0.2007
# Epoch 150/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.9347 - loss: 0.2078 - val_accuracy: 0.9351 - val_loss: 0.2049
# Epoch 151/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 977ms/step - accuracy: 0.9478 - loss: 0.1845 - val_accuracy: 0.9351 - val_loss: 0.1975
# Epoch 152/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9467 - loss: 0.1919 - val_accuracy: 0.9351 - val_loss: 0.1926
# Epoch 153/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9343 - loss: 0.1916 - val_accuracy: 0.9351 - val_loss: 0.1986
# Epoch 154/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9398 - loss: 0.1989 - val_accuracy: 0.9351 - val_loss: 0.1937
# Epoch 155/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 954ms/step - accuracy: 0.9452 - loss: 0.1847 - val_accuracy: 0.9351 - val_loss: 0.1845
# Epoch 156/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 950ms/step - accuracy: 0.9526 - loss: 0.1722 - val_accuracy: 0.9351 - val_loss: 0.1812
# Epoch 157/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 963ms/step - accuracy: 0.9456 - loss: 0.1955 - val_accuracy: 0.9351 - val_loss: 0.1849
# Epoch 158/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 978ms/step - accuracy: 0.9502 - loss: 0.1809 - val_accuracy: 0.9351 - val_loss: 0.1792
# Epoch 159/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 994ms/step - accuracy: 0.9500 - loss: 0.1707 - val_accuracy: 0.9351 - val_loss: 0.1825
# Epoch 160/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 988ms/step - accuracy: 0.9628 - loss: 0.1672 - val_accuracy: 0.9351 - val_loss: 0.1754
# Epoch 161/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 984ms/step - accuracy: 0.9458 - loss: 0.2038 - val_accuracy: 0.9351 - val_loss: 0.1760
# Epoch 162/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 971ms/step - accuracy: 0.9682 - loss: 0.1646 - val_accuracy: 0.9351 - val_loss: 0.1687
# Epoch 163/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.9691 - loss: 0.1380 - val_accuracy: 0.9351 - val_loss: 0.1645
# Epoch 164/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9619 - loss: 0.1691 - val_accuracy: 0.9351 - val_loss: 0.1614
# Epoch 165/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9613 - loss: 0.1715 - val_accuracy: 0.9351 - val_loss: 0.1596
# Epoch 166/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.9711 - loss: 0.1485 - val_accuracy: 0.9351 - val_loss: 0.1557
# Epoch 167/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.9695 - loss: 0.1527 - val_accuracy: 0.9351 - val_loss: 0.1572
# Epoch 168/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 969ms/step - accuracy: 0.9663 - loss: 0.1618 - val_accuracy: 0.9351 - val_loss: 0.1572
# Epoch 169/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 975ms/step - accuracy: 0.9676 - loss: 0.1620 - val_accuracy: 0.9481 - val_loss: 0.1490
# Epoch 170/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.9669 - loss: 0.1453 - val_accuracy: 0.9221 - val_loss: 0.1611
# Epoch 171/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9689 - loss: 0.1511 - val_accuracy: 0.9351 - val_loss: 0.1487
# Epoch 172/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 935ms/step - accuracy: 0.9782 - loss: 0.1245 - val_accuracy: 0.9351 - val_loss: 0.1475
# Epoch 173/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9665 - loss: 0.1448 - val_accuracy: 0.9351 - val_loss: 0.1428
# Epoch 174/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9665 - loss: 0.1402 - val_accuracy: 0.9351 - val_loss: 0.1378
# Epoch 175/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 982ms/step - accuracy: 0.9624 - loss: 0.1492 - val_accuracy: 0.9351 - val_loss: 0.1377
# Epoch 176/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9769 - loss: 0.1305 - val_accuracy: 0.9221 - val_loss: 0.1396
# Epoch 177/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9680 - loss: 0.1290 - val_accuracy: 0.9351 - val_loss: 0.1355
# Epoch 178/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9691 - loss: 0.1436 - val_accuracy: 0.9481 - val_loss: 0.1297
# Epoch 179/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 960ms/step - accuracy: 0.9719 - loss: 0.1287 - val_accuracy: 0.9221 - val_loss: 0.1363
# Epoch 180/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 962ms/step - accuracy: 0.9741 - loss: 0.1223 - val_accuracy: 0.9351 - val_loss: 0.1313
# Epoch 181/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 976ms/step - accuracy: 0.9700 - loss: 0.1267 - val_accuracy: 0.9351 - val_loss: 0.1294
# Epoch 182/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 959ms/step - accuracy: 0.9748 - loss: 0.1247 - val_accuracy: 0.9221 - val_loss: 0.1327
# Epoch 183/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 954ms/step - accuracy: 0.9628 - loss: 0.1484 - val_accuracy: 0.9221 - val_loss: 0.1249
# Epoch 184/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.9698 - loss: 0.1194 - val_accuracy: 0.9481 - val_loss: 0.1199
# Epoch 185/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9600 - loss: 0.1317 - val_accuracy: 0.9351 - val_loss: 0.1213
# Epoch 186/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9689 - loss: 0.1135 - val_accuracy: 0.9481 - val_loss: 0.1154
# Epoch 187/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.9643 - loss: 0.1376 - val_accuracy: 0.9481 - val_loss: 0.1170
# Epoch 188/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 982ms/step - accuracy: 0.9663 - loss: 0.1336 - val_accuracy: 0.9481 - val_loss: 0.1136
# Epoch 189/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 954ms/step - accuracy: 0.9750 - loss: 0.1143 - val_accuracy: 0.9481 - val_loss: 0.1097
# Epoch 190/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9754 - loss: 0.0970 - val_accuracy: 0.9481 - val_loss: 0.1127
# Epoch 191/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9789 - loss: 0.1138 - val_accuracy: 0.9610 - val_loss: 0.1036
# Epoch 192/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9828 - loss: 0.0918 - val_accuracy: 0.9481 - val_loss: 0.1044
# Epoch 193/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 933ms/step - accuracy: 0.9743 - loss: 0.1192 - val_accuracy: 0.9610 - val_loss: 0.1007
# Epoch 194/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 968ms/step - accuracy: 0.9737 - loss: 0.1031 - val_accuracy: 0.9740 - val_loss: 0.0980
# Epoch 195/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 967ms/step - accuracy: 0.9837 - loss: 0.0947 - val_accuracy: 0.9481 - val_loss: 0.1006
# Epoch 196/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.9737 - loss: 0.1206 - val_accuracy: 0.9481 - val_loss: 0.0993
# Epoch 197/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 943ms/step - accuracy: 0.9730 - loss: 0.0979 - val_accuracy: 0.9610 - val_loss: 0.0963
# Epoch 198/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9754 - loss: 0.0935 - val_accuracy: 0.9481 - val_loss: 0.1026
# Epoch 199/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9780 - loss: 0.0842 - val_accuracy: 0.9481 - val_loss: 0.0968
# Epoch 200/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.9685 - loss: 0.0944 - val_accuracy: 0.9481 - val_loss: 0.0955
# Epoch 201/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 986ms/step - accuracy: 0.9554 - loss: 0.1060 - val_accuracy: 0.9610 - val_loss: 0.0957
# Epoch 202/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.9704 - loss: 0.1054 - val_accuracy: 0.9610 - val_loss: 0.0937
# Epoch 203/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.9719 - loss: 0.0814 - val_accuracy: 0.9610 - val_loss: 0.0936
# Epoch 204/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 935ms/step - accuracy: 0.9772 - loss: 0.0814 - val_accuracy: 0.9740 - val_loss: 0.0873
# Epoch 205/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9769 - loss: 0.0902 - val_accuracy: 0.9610 - val_loss: 0.0861
# Epoch 206/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9700 - loss: 0.0925 - val_accuracy: 0.9481 - val_loss: 0.0918
# Epoch 207/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 962ms/step - accuracy: 0.9778 - loss: 0.0759 - val_accuracy: 0.9610 - val_loss: 0.0849
# Epoch 208/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 973ms/step - accuracy: 0.9769 - loss: 0.0868 - val_accuracy: 0.9610 - val_loss: 0.0838
# Epoch 209/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 958ms/step - accuracy: 0.9861 - loss: 0.0881 - val_accuracy: 0.9610 - val_loss: 0.0876
# Epoch 210/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 945ms/step - accuracy: 0.9791 - loss: 0.0799 - val_accuracy: 0.9870 - val_loss: 0.0827
# Epoch 211/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9752 - loss: 0.0777 - val_accuracy: 0.9870 - val_loss: 0.0831
# Epoch 212/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9620 - loss: 0.1075 - val_accuracy: 0.9610 - val_loss: 0.0847
# Epoch 213/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.9793 - loss: 0.0839 - val_accuracy: 0.9610 - val_loss: 0.0839
# Epoch 214/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 980ms/step - accuracy: 0.9687 - loss: 0.0806 - val_accuracy: 0.9610 - val_loss: 0.0822
# Epoch 215/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 960ms/step - accuracy: 0.9559 - loss: 0.0989 - val_accuracy: 0.9610 - val_loss: 0.0821
# Epoch 216/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.9833 - loss: 0.0848 - val_accuracy: 0.9610 - val_loss: 0.0819
# Epoch 217/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9758 - loss: 0.0795 - val_accuracy: 0.9610 - val_loss: 0.0828
# Epoch 218/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9891 - loss: 0.0749 - val_accuracy: 0.9740 - val_loss: 0.0798
# Epoch 219/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9722 - loss: 0.0845 - val_accuracy: 0.9610 - val_loss: 0.0803
# Epoch 220/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 949ms/step - accuracy: 0.9882 - loss: 0.0781 - val_accuracy: 0.9610 - val_loss: 0.0801
# Epoch 221/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 988ms/step - accuracy: 0.9796 - loss: 0.0864 - val_accuracy: 0.9610 - val_loss: 0.0789
# Epoch 222/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 959ms/step - accuracy: 0.9743 - loss: 0.0932 - val_accuracy: 0.9610 - val_loss: 0.0776
# Epoch 223/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.9887 - loss: 0.0680 - val_accuracy: 0.9740 - val_loss: 0.0791
# Epoch 224/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9761 - loss: 0.0701 - val_accuracy: 0.9610 - val_loss: 0.0863
# Epoch 225/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9748 - loss: 0.0976 - val_accuracy: 0.9610 - val_loss: 0.0743
# Epoch 226/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9811 - loss: 0.0620 - val_accuracy: 0.9740 - val_loss: 0.0704
# Epoch 227/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 970ms/step - accuracy: 0.9854 - loss: 0.0603 - val_accuracy: 0.9610 - val_loss: 0.0721
# Epoch 228/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 960ms/step - accuracy: 0.9915 - loss: 0.0630 - val_accuracy: 0.9610 - val_loss: 0.0730
# Epoch 229/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9717 - loss: 0.0841 - val_accuracy: 0.9740 - val_loss: 0.0722
# Epoch 230/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 941ms/step - accuracy: 0.9793 - loss: 0.0718 - val_accuracy: 0.9610 - val_loss: 0.0748
# Epoch 231/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9887 - loss: 0.0735 - val_accuracy: 0.9870 - val_loss: 0.0749
# Epoch 232/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 933ms/step - accuracy: 0.9789 - loss: 0.0639 - val_accuracy: 0.9610 - val_loss: 0.0715
# Epoch 233/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 959ms/step - accuracy: 0.9802 - loss: 0.0823 - val_accuracy: 0.9870 - val_loss: 0.0718
# Epoch 234/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 995ms/step - accuracy: 0.9824 - loss: 0.0682 - val_accuracy: 0.9610 - val_loss: 0.0717
# Epoch 235/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 971ms/step - accuracy: 0.9954 - loss: 0.0667 - val_accuracy: 0.9870 - val_loss: 0.0692
# Epoch 236/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 969ms/step - accuracy: 0.9795 - loss: 0.0628 - val_accuracy: 0.9610 - val_loss: 0.0699
# Epoch 237/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 950ms/step - accuracy: 0.9804 - loss: 0.0694 - val_accuracy: 0.9610 - val_loss: 0.0743
# Epoch 238/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9946 - loss: 0.0445 - val_accuracy: 0.9610 - val_loss: 0.0710
# Epoch 239/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9937 - loss: 0.0561 - val_accuracy: 0.9870 - val_loss: 0.0645
# Epoch 240/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 964ms/step - accuracy: 0.9906 - loss: 0.0590 - val_accuracy: 0.9610 - val_loss: 0.0621
# Epoch 241/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 971ms/step - accuracy: 0.9887 - loss: 0.0566 - val_accuracy: 0.9740 - val_loss: 0.0628
# Epoch 242/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.9898 - loss: 0.0582 - val_accuracy: 0.9740 - val_loss: 0.0637
# Epoch 243/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9922 - loss: 0.0730 - val_accuracy: 0.9740 - val_loss: 0.0663
# Epoch 244/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9826 - loss: 0.0702 - val_accuracy: 0.9610 - val_loss: 0.0678
# Epoch 245/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 940ms/step - accuracy: 0.9804 - loss: 0.0806 - val_accuracy: 0.9740 - val_loss: 0.0663
# Epoch 246/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 958ms/step - accuracy: 0.9861 - loss: 0.0536 - val_accuracy: 0.9610 - val_loss: 0.0636
# Epoch 247/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 997ms/step - accuracy: 0.9648 - loss: 0.0877 - val_accuracy: 0.9740 - val_loss: 0.0620
# Epoch 248/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 957ms/step - accuracy: 0.9919 - loss: 0.0495 - val_accuracy: 0.9740 - val_loss: 0.0615
# Epoch 249/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.9891 - loss: 0.0572 - val_accuracy: 0.9870 - val_loss: 0.0647
# Epoch 250/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9852 - loss: 0.0528 - val_accuracy: 0.9610 - val_loss: 0.0681
# Epoch 251/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9863 - loss: 0.0660 - val_accuracy: 0.9740 - val_loss: 0.0642
# Epoch 252/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9833 - loss: 0.0603 - val_accuracy: 0.9870 - val_loss: 0.0637
# Epoch 253/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 955ms/step - accuracy: 0.9802 - loss: 0.0520 - val_accuracy: 0.9610 - val_loss: 0.0646
# Epoch 254/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 975ms/step - accuracy: 0.9756 - loss: 0.0729 - val_accuracy: 0.9740 - val_loss: 0.0603
# Epoch 255/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 954ms/step - accuracy: 0.9858 - loss: 0.0540 - val_accuracy: 0.9870 - val_loss: 0.0580
# Epoch 256/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9828 - loss: 0.0641 - val_accuracy: 0.9870 - val_loss: 0.0631
# Epoch 257/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9895 - loss: 0.0526 - val_accuracy: 0.9610 - val_loss: 0.0674
# Epoch 258/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9915 - loss: 0.0606 - val_accuracy: 0.9740 - val_loss: 0.0657
# Epoch 259/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 943ms/step - accuracy: 0.9872 - loss: 0.0638 - val_accuracy: 0.9610 - val_loss: 0.0649
# Epoch 260/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 983ms/step - accuracy: 0.9822 - loss: 0.0680 - val_accuracy: 0.9610 - val_loss: 0.0614
# Epoch 261/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 956ms/step - accuracy: 0.9961 - loss: 0.0529 - val_accuracy: 0.9740 - val_loss: 0.0534
# Epoch 262/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 946ms/step - accuracy: 0.9880 - loss: 0.0672 - val_accuracy: 0.9740 - val_loss: 0.0594
# Epoch 263/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9856 - loss: 0.0568 - val_accuracy: 0.9610 - val_loss: 0.0630
# Epoch 264/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9928 - loss: 0.0482 - val_accuracy: 0.9740 - val_loss: 0.0649
# Epoch 265/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9939 - loss: 0.0433 - val_accuracy: 0.9740 - val_loss: 0.0661
# Epoch 266/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 960ms/step - accuracy: 0.9915 - loss: 0.0576 - val_accuracy: 0.9740 - val_loss: 0.0643
# Epoch 267/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 987ms/step - accuracy: 0.9954 - loss: 0.0480 - val_accuracy: 0.9740 - val_loss: 0.0603
# Epoch 268/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.9895 - loss: 0.0478 - val_accuracy: 0.9870 - val_loss: 0.0603
# Epoch 269/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9867 - loss: 0.0482 - val_accuracy: 0.9610 - val_loss: 0.0617
# Epoch 270/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.9930 - loss: 0.0533 - val_accuracy: 0.9870 - val_loss: 0.0628
# Epoch 271/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9819 - loss: 0.0537 - val_accuracy: 0.9870 - val_loss: 0.0656
# Epoch 272/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.9815 - loss: 0.0591 - val_accuracy: 0.9740 - val_loss: 0.0650
# Epoch 273/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 964ms/step - accuracy: 0.9917 - loss: 0.0534 - val_accuracy: 0.9740 - val_loss: 0.0622
# Epoch 274/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 970ms/step - accuracy: 0.9919 - loss: 0.0472 - val_accuracy: 0.9870 - val_loss: 0.0599
# Epoch 275/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 952ms/step - accuracy: 0.9843 - loss: 0.0625 - val_accuracy: 0.9740 - val_loss: 0.0590
# Epoch 276/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9900 - loss: 0.0398 - val_accuracy: 0.9610 - val_loss: 0.0570
# Epoch 277/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9937 - loss: 0.0477 - val_accuracy: 0.9870 - val_loss: 0.0540
# Epoch 278/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9839 - loss: 0.0535 - val_accuracy: 0.9870 - val_loss: 0.0559
# Epoch 279/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.9800 - loss: 0.0538 - val_accuracy: 0.9740 - val_loss: 0.0565
# Epoch 280/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 997ms/step - accuracy: 0.9900 - loss: 0.0511 - val_accuracy: 0.9740 - val_loss: 0.0604
# Epoch 281/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.9937 - loss: 0.0398 - val_accuracy: 0.9740 - val_loss: 0.0619
# Epoch 282/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 940ms/step - accuracy: 0.9924 - loss: 0.0491 - val_accuracy: 0.9740 - val_loss: 0.0610
# Epoch 283/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9900 - loss: 0.0429 - val_accuracy: 0.9610 - val_loss: 0.0603
# Epoch 284/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9926 - loss: 0.0568 - val_accuracy: 0.9870 - val_loss: 0.0576
# Epoch 285/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 945ms/step - accuracy: 0.9817 - loss: 0.0551 - val_accuracy: 0.9870 - val_loss: 0.0580
# Epoch 286/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 963ms/step - accuracy: 0.9961 - loss: 0.0333 - val_accuracy: 0.9610 - val_loss: 0.0579
# Epoch 287/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 976ms/step - accuracy: 0.9939 - loss: 0.0393 - val_accuracy: 0.9740 - val_loss: 0.0559
# Epoch 288/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.9900 - loss: 0.0396 - val_accuracy: 0.9740 - val_loss: 0.0585
# Epoch 289/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 948ms/step - accuracy: 0.9783 - loss: 0.0567 - val_accuracy: 0.9740 - val_loss: 0.0596
# Epoch 290/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 936ms/step - accuracy: 0.9924 - loss: 0.0317 - val_accuracy: 0.9740 - val_loss: 0.0574
# Epoch 291/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9917 - loss: 0.0589 - val_accuracy: 0.9870 - val_loss: 0.0534
# Epoch 292/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 953ms/step - accuracy: 0.9902 - loss: 0.0454 - val_accuracy: 0.9870 - val_loss: 0.0519
# Epoch 293/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 987ms/step - accuracy: 0.9926 - loss: 0.0424 - val_accuracy: 0.9610 - val_loss: 0.0594
# Epoch 294/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.9880 - loss: 0.0471 - val_accuracy: 0.9870 - val_loss: 0.0474
# Epoch 295/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 944ms/step - accuracy: 0.9902 - loss: 0.0348 - val_accuracy: 0.9740 - val_loss: 0.0517
# Epoch 296/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9867 - loss: 0.0390 - val_accuracy: 0.9870 - val_loss: 0.0577
# Epoch 297/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 938ms/step - accuracy: 0.9948 - loss: 0.0417 - val_accuracy: 0.9610 - val_loss: 0.0660
# Epoch 298/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step - accuracy: 0.9926 - loss: 0.0266 - val_accuracy: 0.9740 - val_loss: 0.0563
# Epoch 299/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 961ms/step - accuracy: 0.9924 - loss: 0.0586 - val_accuracy: 0.9740 - val_loss: 0.0577
# Epoch 300/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 991ms/step - accuracy: 0.9867 - loss: 0.0427 - val_accuracy: 0.9870 - val_loss: 0.0501
# Epoch 301/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 973ms/step - accuracy: 0.9924 - loss: 0.0351 - val_accuracy: 0.9740 - val_loss: 0.0521
# Epoch 302/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 941ms/step - accuracy: 0.9948 - loss: 0.0357 - val_accuracy: 0.9870 - val_loss: 0.0483
# Epoch 303/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 963ms/step - accuracy: 0.9930 - loss: 0.0380 - val_accuracy: 0.9740 - val_loss: 0.0527
# Epoch 304/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 947ms/step - accuracy: 0.9861 - loss: 0.0447 - val_accuracy: 0.9740 - val_loss: 0.0505
# Epoch 305/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.9946 - loss: 0.0309 - val_accuracy: 0.9740 - val_loss: 0.0542
# Epoch 306/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 990ms/step - accuracy: 0.9904 - loss: 0.0330 - val_accuracy: 0.9740 - val_loss: 0.0544
# Epoch 307/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 966ms/step - accuracy: 0.9893 - loss: 0.0485 - val_accuracy: 0.9740 - val_loss: 0.0566
# Epoch 308/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9926 - loss: 0.0473 - val_accuracy: 0.9740 - val_loss: 0.0551
# Epoch 309/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 942ms/step - accuracy: 0.9900 - loss: 0.0414 - val_accuracy: 0.9740 - val_loss: 0.0531
# Epoch 310/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 937ms/step - accuracy: 0.9917 - loss: 0.0418 - val_accuracy: 0.9870 - val_loss: 0.0541

# %% [markdown]
# #### Visualize Training Performance

# %%
# Get training and validation accuracy and loss from the history object
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation accuracy
plt.figure()
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
# Plot training and validation loss
plt.figure()
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
# Get the final accuracy and loss for the last epoch
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

# Print the final accuracy and loss
print("Final Training Accuracy:", final_train_acc)
print("Final Validation Accuracy:", final_val_acc)
print("Final Training Loss:", final_train_loss)
print("Final Validation Loss:", final_val_loss)
# Out:
# Final Training Accuracy: 0.9901639223098755
# Final Validation Accuracy: 0.9870129823684692
# Final Training Loss: 0.041887879371643066
# Final Validation Loss: 0.05407845601439476

# %%
# Save the entire model as a `.keras` zip archive.
combined_model.save('MTFN_32Rank.keras')

# %% [markdown]
# ## Visualizations

# %% [markdown]
# #### VGG Feature Maps

# %%
iterator = iter(train_dataset)
first_element, label = next(iterator)

# %%
# Load the existing model (if needed)
# combined_model = tf.keras.models.load_model('AD_Multimodal_Model.keras')

# Choose a layer to visualize (e.g., the output of the first convolutional layer)
layer_name = 'block1_conv1'
intermediate_layer_model = tf.keras.models.Model(inputs=combined_model.input, outputs=combined_model.get_layer(layer_name).output)

# Load and preprocess an image
def load_and_preprocess_image(image_path):
    img = tf.keras.utils.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.vgg16.preprocess_input(img_array)
    return img_array

image_path = '../ADNI_Dataset/ADNI_IMG_32.5%_x/I124297.png'
preprocessed_image = load_and_preprocess_image(image_path)

# Get the feature maps
feature_maps = intermediate_layer_model.predict(first_element)

# Visualize the feature maps
def visualize_feature_maps(feature_maps):
    num_feature_maps = feature_maps.shape[-1]
    
    # Determine the layout for subplots (adjust as needed)
    grid_size = int(np.ceil(np.sqrt(num_feature_maps)))
    
    plt.figure(figsize=(12, 12))
    for i in range(num_feature_maps):
        plt.subplot(grid_size, grid_size, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(feature_maps[0, :, :, i], cmap='gray')
    plt.show()

visualize_feature_maps(feature_maps)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
plt.imshow(feature_maps[0, :, :, 1], cmap='CMRmap')
# plt.savefig('VGG_Feature_Map.png', dpi=300)  # Save as PNG with 300 DPI

# %% [markdown]
# ValueError: 'green' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
