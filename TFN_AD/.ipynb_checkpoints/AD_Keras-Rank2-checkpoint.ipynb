# %% [markdown]
# ## Imports

# %%
import keras
import numpy as np

import time

import os

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow.keras.layers as tfl

# import misc

import pandas as pd

import datetime

import glob

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, GlobalAveragePooling2D, Input, Conv1D, MaxPooling1D, Flatten, \
                                    Masking, LSTM, Softmax, Multiply, Layer, Concatenate, Lambda, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# from keras.utils import np_utils
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.datasets import load_files
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
# import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.preprocessing import image_dataset_from_directory

from sklearn.model_selection import train_test_split

import tensorly as tl
from tensorly.decomposition import tucker
# Out:
# 2025-03-05 01:06:31.193459: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741165591.235723   64534 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741165591.245911   64534 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-05 01:06:31.284203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set up imports & packages.

tl.set_backend('tensorflow')  # Use TensorFlow tensors instead of NumPy

# %% [markdown]
# ## Declare Sub-Models

# %%
# Default 16.
feature_vector_size = 2

# %% [markdown]
# ### Visual Embedder (VGG-16)

# %%
def build_visual_embedder():
    # Load the VGG16 model without the top layers
    visual_base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze the base model to retain pretrained weights during training
    visual_base_model.trainable = False

    # Add a top for 3-way classification
    x = visual_base_model.output
    x = GlobalAveragePooling2D()(x)  # Global Average Pooling layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(256, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization

    visual_base_features = Dense(feature_vector_size, activation='relu')(x) 

    # Define the final model
    visual_model = Model(inputs=visual_base_model.input, outputs=visual_base_features, name="VisualEmbedder")
    return visual_model

# %% [markdown]
# ### Demographic Embedder

# %%
def build_demographics_embedder():
    # Input layer for demographics data
    input_layer = Input(shape=(6, ), name="demographics_input")

    x = Dense(16, activation='relu')(input_layer)
    x = Dropout(0.1)(x)
    x = Dense(4, activation='relu')(x)
    x = Dropout(0.1)(x)
    
    # Classification head
    demographics_base_features = Dense(feature_vector_size, activation='relu')(x)
    
    # Define the model
    demographics_model = Model(inputs=input_layer, outputs=demographics_base_features, name="DemographicsEmbedder")
    return demographics_model

# %% [markdown]
# ### Time-Series Embedder

# %%
max_seq_length = 6

# %%
def build_time_embedder():
    # Input layer for time series data (4 input variables)
    time_series_input = Input(shape=(max_seq_length, 4), name="time_series_input")
    masked_input = Masking(mask_value=0.0)(time_series_input)

    # Use the last hidden state
    x = LSTM(32, return_sequences=False)(masked_input)

    # Dense layer to create time series output
    time_base_features = Dense(feature_vector_size, activation="relu")(x)
    
    # Define the model
    time_model = Model(inputs=time_series_input, outputs=time_base_features, name="TimeSeriesEmbedder")
    return time_model

# %% [markdown]
# ## Joint Model

# %%
visual_dim = feature_vector_size
demographics_dim = feature_vector_size
time_dim = feature_vector_size

# Tensor Fusion Layer
def tensor_fusion_layer(inputs):
    """
    Tensor fusion using Kronecker product via `tf.einsum`.
    Adds a 1 to each input tensor for core (0,0,0) alignment.
    """
    visual, demographics, time_series = inputs

    # Add a "1" to the feature vectors
    visual_h = tf.concat([tf.ones((tf.shape(visual)[0], 1)), visual], axis=1)
    demographics_h = tf.concat([tf.ones((tf.shape(demographics)[0], 1)), demographics], axis=1)
    time_series_h = tf.concat([tf.ones((tf.shape(time_series)[0], 1)), time_series], axis=1)

    # Perform Kronecker product using tf.einsum
    outer_xy = tf.einsum('bi,bj->bij', demographics_h, time_series_h)  # Shape: (batch_size, d_dim, t_dim)
    outer_xyz = tf.einsum('bij,bk->bijk', outer_xy, visual_h)  # Shape: (batch_size, d_dim, t_dim, v_dim)

    # core, factors = tucker(outer_xyz, rank=(8,8,8))

    # # Flatten the fused tensor
    fused_tensor = tf.reshape(outer_xyz, (tf.shape(outer_xyz)[0], -1))  # Shape: (batch_size, d_dim * t_dim * v_dim)

    return fused_tensor #outer_xyz

# %%
# Visual embedder
visual_embedder = build_visual_embedder()

# Demographics embedder
demographics_embedder = build_demographics_embedder()

# Time Series Embedder
time_embedder = build_time_embedder()

# Outputs from embedders
visual_features = visual_embedder.output
demographics_features = demographics_embedder.output
time_features = time_embedder.output

# Output shape of the fused tensor
fused_tensor_shape = (None, (visual_dim + 1) * (demographics_dim + 1) * (time_dim + 1))

# Apply Tensor Fusion
fused_features = Lambda(tensor_fusion_layer, output_shape=fused_tensor_shape)([visual_features, demographics_features, time_features])

# Add final classification layers
x = Dense(128, activation='relu')(fused_features)
x = Dense(64, activation='relu')(x)
final_output = Dense(3, activation='softmax', name="final_output")(x)

# Define the combined model
combined_model = Model(inputs=[visual_embedder.input, demographics_embedder.input, time_embedder.input], 
                       outputs=final_output, name="CombinedModel")
# Out:
# W0000 00:00:1741165596.406837   64534 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# #### Joint-Model Structure

# %%
combined_model.summary()
# Out:
# Model: "CombinedModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ demographics_input  │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    262,656 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │        112 │ demographics_inp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_series_input   │ (None, 6, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 6, 4)      │          0 │ time_series_inpu… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4)         │         68 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 6, 4)      │          0 │ time_series_inpu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 6)         │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4)         │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 32)        │      4,736 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 2)         │        514 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 2)         │         10 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 2)         │         66 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, None, 27)  │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_6[0][0],    │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, None, 128) │      3,584 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, None, 64)  │      8,256 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, None, 3)   │        195 │ dense_9[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 15,388,869 (58.70 MB)
#  Trainable params: 674,181 (2.57 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# # Train Joint-Model

# %% [markdown]
# #### Load Data

# %%
# Mapping for string labels to integers
label_mapping = {"CN": 0, "MCI": 1, "Dementia": 2}

# %%
manifest = pd.read_csv("/home/mason/TFN_AD/AD_Patient_Manifest.csv")

# %%
# Load all data into memory. Not elegant, but works.
def load_all_data(manifest, target_size=(224, 224), demographic_columns=None, time_series_columns=None, label_mapping=None):
    image_data = []
    demographics_data = []
    time_series_data = []
    labels = []
    label_mapping = label_mapping or {}

    for _, row in manifest.iterrows():
        patient_path = row["path"]
        patient_df = pd.read_pickle(patient_path)

        # Load image data
        image_paths = [patient_df['image_path'].iloc[0]]
        for path in image_paths:
            img = load_img(path, target_size=target_size)
            img_array = img_to_array(img)
            img_array = preprocess_input(img_array)
            image_data.append(img_array)

        # Process demographics data
        if demographic_columns is None:
            raise ValueError("Please specify the demographics columns.")
        
        # Get first row of demographic data (since it doesn't change over time)
        demographics = patient_df[demographic_columns].iloc[0]
        demographics = demographics.values.astype(np.float32)  # Convert to NumPy array
        demographics_data.append(demographics)

        # Process time series data
        if time_series_columns is None:
            raise ValueError("Please specify the time series columns.")
        
        # Extract the relevant time series columns
        time_series = patient_df[time_series_columns].values  # Extract as NumPy array

        # Truncate or pad to max_seq_length
        if len(time_series) > max_seq_length:
            time_series = time_series[:max_seq_length, :]
        elif len(time_series) < max_seq_length:
            padding = np.zeros((max_seq_length - len(time_series), len(time_series_columns)))
            time_series = np.vstack([time_series, padding])
        time_series_data.append(time_series)

        # Load labels
        label_str = patient_df['DX'].iloc[0]
        label_int = label_mapping[label_str]
        labels.append(label_int)

    # Convert to numpy arrays
    image_data = np.array(image_data, dtype=np.float32)
    demographics_data = np.array(demographics_data, dtype=np.float32)
    time_series_data = np.array(time_series_data, dtype=np.float32)
    labels = np.array(labels, dtype=np.int32)

    return image_data, demographics_data, time_series_data, labels

# %%
# Demographic variables to extract
demographic_columns = ['AGE', 'PTEDUCAT', 'PTGENDER_encoded', 
                        'PTETHCAT_encoded', 'PTRACCAT_encoded', 'PTMARRY_encoded']
# Time series variables to extract
time_series_columns = ['Years_bl', 'ADAS11', 'ADAS13', 'ADASQ4']

# Load all data into memory
image_data, demographics_data, time_series_data, labels = load_all_data(manifest, target_size=(224, 224), demographic_columns=demographic_columns, 
                                                      time_series_columns=time_series_columns, label_mapping=label_mapping)

# Split the data
test_size = 0.2  # 20% of the data for testing

(image_train, image_test,
 demographics_train, demographics_test,
 time_train, time_test,
 labels_train, labels_test) = train_test_split(
    image_data, demographics_data, time_series_data, labels, test_size=test_size, random_state=42, stratify=labels
)

# %%
batch_size = 64

# Create training dataset
train_dataset = tf.data.Dataset.from_tensor_slices(((image_train, demographics_train, time_train), labels_train))
train_dataset = train_dataset.shuffle(100).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Create testing (validation) dataset
test_dataset = tf.data.Dataset.from_tensor_slices(((image_test, demographics_test, time_test), labels_test))
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
print(f"Image train shape: {image_train.shape}")
print(f"Demographics train shape: {demographics_train.shape}")
print(f"Time train shape: {time_train.shape}")
print(f"Labels train shape: {labels_train.shape}")
# Out:
# Image train shape: (305, 224, 224, 3)
# Demographics train shape: (305, 6)
# Time train shape: (305, 6, 4)
# Labels train shape: (305,)

# %% [markdown]
# #### Train the Model

# %%
# Compile the model
combined_model.compile(optimizer=Adam(learning_rate=0.0001),
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

# %%
print("Model inputs:", combined_model.input)
# Out:
# Model inputs: [<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>, <KerasTensor shape=(None, 6), dtype=float32, sparse=False, name=demographics_input>, <KerasTensor shape=(None, 6, 4), dtype=float32, sparse=False, name=time_series_input>]

# %%
# Early stopping to prevent redundant training.
early_stopping = EarlyStopping(monitor='val_accuracy', patience=100, restore_best_weights=True)

# %%
# Train the model
history = combined_model.fit(
    train_dataset, 
    validation_data=test_dataset,
    epochs=600,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/600
# /home/mason/.conda/envs/LOSresearch/lib/python3.9/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'demographics_input', 'time_series_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.4394 - loss: 4.0909 - val_accuracy: 0.4545 - val_loss: 1.5703
# Epoch 2/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4498 - loss: 1.6473 - val_accuracy: 0.3896 - val_loss: 1.4985
# Epoch 3/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.3883 - loss: 1.4880 - val_accuracy: 0.4286 - val_loss: 1.4167
# Epoch 4/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4861 - loss: 1.4287 - val_accuracy: 0.4545 - val_loss: 1.3548
# Epoch 5/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4610 - loss: 1.3874 - val_accuracy: 0.5455 - val_loss: 1.3018
# Epoch 6/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.5301 - loss: 1.2574 - val_accuracy: 0.5325 - val_loss: 1.2567
# Epoch 7/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5443 - loss: 1.1625 - val_accuracy: 0.5584 - val_loss: 1.2156
# Epoch 8/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5792 - loss: 1.2226 - val_accuracy: 0.5584 - val_loss: 1.1787
# Epoch 9/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5456 - loss: 1.1687 - val_accuracy: 0.5714 - val_loss: 1.1442
# Epoch 10/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5249 - loss: 1.1468 - val_accuracy: 0.5714 - val_loss: 1.1132
# Epoch 11/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5612 - loss: 1.1220 - val_accuracy: 0.5714 - val_loss: 1.0843
# Epoch 12/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5578 - loss: 1.0380 - val_accuracy: 0.5584 - val_loss: 1.0582
# Epoch 13/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.5579 - loss: 1.0293 - val_accuracy: 0.5584 - val_loss: 1.0341
# Epoch 14/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5639 - loss: 1.0769 - val_accuracy: 0.5584 - val_loss: 1.0107
# Epoch 15/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5751 - loss: 1.0167 - val_accuracy: 0.5584 - val_loss: 0.9889
# Epoch 16/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6071 - loss: 0.9452 - val_accuracy: 0.5584 - val_loss: 0.9688
# Epoch 17/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5843 - loss: 0.9507 - val_accuracy: 0.5584 - val_loss: 0.9520
# Epoch 18/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5667 - loss: 0.9453 - val_accuracy: 0.5714 - val_loss: 0.9355
# Epoch 19/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5992 - loss: 0.9146 - val_accuracy: 0.6364 - val_loss: 0.9195
# Epoch 20/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6272 - loss: 0.8789 - val_accuracy: 0.6494 - val_loss: 0.9036
# Epoch 21/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6517 - loss: 0.8905 - val_accuracy: 0.6753 - val_loss: 0.8881
# Epoch 22/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6604 - loss: 0.9057 - val_accuracy: 0.6883 - val_loss: 0.8738
# Epoch 23/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6620 - loss: 0.8715 - val_accuracy: 0.6883 - val_loss: 0.8600
# Epoch 24/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6644 - loss: 0.8595 - val_accuracy: 0.6883 - val_loss: 0.8466
# Epoch 25/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7070 - loss: 0.8298 - val_accuracy: 0.6883 - val_loss: 0.8330
# Epoch 26/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7003 - loss: 0.8219 - val_accuracy: 0.6883 - val_loss: 0.8199
# Epoch 27/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7306 - loss: 0.8073 - val_accuracy: 0.7013 - val_loss: 0.8076
# Epoch 28/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6950 - loss: 0.8140 - val_accuracy: 0.6883 - val_loss: 0.7958
# Epoch 29/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6990 - loss: 0.7987 - val_accuracy: 0.6883 - val_loss: 0.7845
# Epoch 30/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7152 - loss: 0.7691 - val_accuracy: 0.7013 - val_loss: 0.7727
# Epoch 31/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6657 - loss: 0.7741 - val_accuracy: 0.7013 - val_loss: 0.7616
# Epoch 32/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7309 - loss: 0.7470 - val_accuracy: 0.7013 - val_loss: 0.7515
# Epoch 33/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6962 - loss: 0.7827 - val_accuracy: 0.7013 - val_loss: 0.7414
# Epoch 34/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7222 - loss: 0.7507 - val_accuracy: 0.7013 - val_loss: 0.7329
# Epoch 35/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7155 - loss: 0.7508 - val_accuracy: 0.7143 - val_loss: 0.7244
# Epoch 36/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7264 - loss: 0.7194 - val_accuracy: 0.7013 - val_loss: 0.7160
# Epoch 37/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7368 - loss: 0.7456 - val_accuracy: 0.7013 - val_loss: 0.7062
# Epoch 38/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7446 - loss: 0.6897 - val_accuracy: 0.7273 - val_loss: 0.6972
# Epoch 39/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7296 - loss: 0.7229 - val_accuracy: 0.7273 - val_loss: 0.6878
# Epoch 40/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6925 - loss: 0.7253 - val_accuracy: 0.7273 - val_loss: 0.6804
# Epoch 41/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7316 - loss: 0.7114 - val_accuracy: 0.7273 - val_loss: 0.6731
# Epoch 42/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7333 - loss: 0.6873 - val_accuracy: 0.7403 - val_loss: 0.6668
# Epoch 43/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7218 - loss: 0.7356 - val_accuracy: 0.7403 - val_loss: 0.6617
# Epoch 44/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7499 - loss: 0.6796 - val_accuracy: 0.7403 - val_loss: 0.6582
# Epoch 45/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7361 - loss: 0.6837 - val_accuracy: 0.7403 - val_loss: 0.6517
# Epoch 46/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6948 - loss: 0.7062 - val_accuracy: 0.7532 - val_loss: 0.6443
# Epoch 47/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.6979 - loss: 0.7096 - val_accuracy: 0.7532 - val_loss: 0.6370
# Epoch 48/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7535 - loss: 0.6698 - val_accuracy: 0.7532 - val_loss: 0.6316
# Epoch 49/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7222 - loss: 0.6540 - val_accuracy: 0.7662 - val_loss: 0.6274
# Epoch 50/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7629 - loss: 0.6225 - val_accuracy: 0.7662 - val_loss: 0.6233
# Epoch 51/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7312 - loss: 0.6837 - val_accuracy: 0.7662 - val_loss: 0.6197
# Epoch 52/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7620 - loss: 0.6415 - val_accuracy: 0.7532 - val_loss: 0.6132
# Epoch 53/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.7263 - loss: 0.6613 - val_accuracy: 0.7532 - val_loss: 0.6082
# Epoch 54/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7336 - loss: 0.6671 - val_accuracy: 0.7662 - val_loss: 0.6079
# Epoch 55/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7831 - loss: 0.6022 - val_accuracy: 0.7662 - val_loss: 0.6036
# Epoch 56/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7481 - loss: 0.6125 - val_accuracy: 0.7662 - val_loss: 0.5978
# Epoch 57/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7560 - loss: 0.5957 - val_accuracy: 0.7532 - val_loss: 0.5916
# Epoch 58/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7425 - loss: 0.6397 - val_accuracy: 0.7662 - val_loss: 0.5869
# Epoch 59/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7303 - loss: 0.6353 - val_accuracy: 0.7662 - val_loss: 0.5835
# Epoch 60/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7568 - loss: 0.6154 - val_accuracy: 0.7662 - val_loss: 0.5816
# Epoch 61/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7646 - loss: 0.6065 - val_accuracy: 0.7662 - val_loss: 0.5786
# Epoch 62/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7559 - loss: 0.5999 - val_accuracy: 0.7662 - val_loss: 0.5768
# Epoch 63/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7705 - loss: 0.6031 - val_accuracy: 0.7662 - val_loss: 0.5732
# Epoch 64/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7486 - loss: 0.6546 - val_accuracy: 0.7662 - val_loss: 0.5683
# Epoch 65/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7600 - loss: 0.5841 - val_accuracy: 0.7662 - val_loss: 0.5651
# Epoch 66/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7638 - loss: 0.5592 - val_accuracy: 0.7662 - val_loss: 0.5602
# Epoch 67/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7394 - loss: 0.6208 - val_accuracy: 0.7662 - val_loss: 0.5565
# Epoch 68/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7494 - loss: 0.5964 - val_accuracy: 0.7792 - val_loss: 0.5534
# Epoch 69/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7593 - loss: 0.6210 - val_accuracy: 0.7792 - val_loss: 0.5520
# Epoch 70/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7783 - loss: 0.5821 - val_accuracy: 0.7792 - val_loss: 0.5506
# Epoch 71/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7495 - loss: 0.5869 - val_accuracy: 0.7792 - val_loss: 0.5421
# Epoch 72/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7425 - loss: 0.6147 - val_accuracy: 0.7792 - val_loss: 0.5361
# Epoch 73/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7627 - loss: 0.5879 - val_accuracy: 0.7792 - val_loss: 0.5315
# Epoch 74/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7575 - loss: 0.5938 - val_accuracy: 0.7792 - val_loss: 0.5248
# Epoch 75/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7503 - loss: 0.5818 - val_accuracy: 0.7792 - val_loss: 0.5224
# Epoch 76/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7762 - loss: 0.5742 - val_accuracy: 0.7792 - val_loss: 0.5174
# Epoch 77/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7818 - loss: 0.5856 - val_accuracy: 0.7922 - val_loss: 0.5157
# Epoch 78/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7684 - loss: 0.5574 - val_accuracy: 0.7922 - val_loss: 0.5159
# Epoch 79/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7981 - loss: 0.5698 - val_accuracy: 0.7922 - val_loss: 0.5131
# Epoch 80/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7834 - loss: 0.5800 - val_accuracy: 0.8052 - val_loss: 0.5069
# Epoch 81/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7818 - loss: 0.5650 - val_accuracy: 0.8052 - val_loss: 0.4993
# Epoch 82/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7866 - loss: 0.5341 - val_accuracy: 0.8052 - val_loss: 0.4906
# Epoch 83/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8068 - loss: 0.5041 - val_accuracy: 0.8052 - val_loss: 0.4841
# Epoch 84/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7914 - loss: 0.5415 - val_accuracy: 0.8182 - val_loss: 0.4826
# Epoch 85/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7760 - loss: 0.5324 - val_accuracy: 0.8052 - val_loss: 0.4843
# Epoch 86/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7825 - loss: 0.5070 - val_accuracy: 0.8052 - val_loss: 0.4826
# Epoch 87/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7840 - loss: 0.5152 - val_accuracy: 0.8182 - val_loss: 0.4698
# Epoch 88/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7912 - loss: 0.5147 - val_accuracy: 0.8182 - val_loss: 0.4618
# Epoch 89/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8006 - loss: 0.5316 - val_accuracy: 0.8182 - val_loss: 0.4588
# Epoch 90/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8033 - loss: 0.5252 - val_accuracy: 0.8182 - val_loss: 0.4572
# Epoch 91/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8201 - loss: 0.5051 - val_accuracy: 0.8182 - val_loss: 0.4545
# Epoch 92/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7905 - loss: 0.5365 - val_accuracy: 0.8442 - val_loss: 0.4530
# Epoch 93/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8020 - loss: 0.4929 - val_accuracy: 0.8182 - val_loss: 0.4444
# Epoch 94/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8220 - loss: 0.4711 - val_accuracy: 0.8182 - val_loss: 0.4385
# Epoch 95/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8088 - loss: 0.5082 - val_accuracy: 0.8442 - val_loss: 0.4385
# Epoch 96/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8240 - loss: 0.4798 - val_accuracy: 0.8442 - val_loss: 0.4396
# Epoch 97/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.7940 - loss: 0.4858 - val_accuracy: 0.8442 - val_loss: 0.4437
# Epoch 98/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8199 - loss: 0.4418 - val_accuracy: 0.8442 - val_loss: 0.4279
# Epoch 99/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8140 - loss: 0.4894 - val_accuracy: 0.8442 - val_loss: 0.4192
# Epoch 100/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8375 - loss: 0.4058 - val_accuracy: 0.8442 - val_loss: 0.4129
# Epoch 101/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8168 - loss: 0.4753 - val_accuracy: 0.8442 - val_loss: 0.4118
# Epoch 102/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8318 - loss: 0.4277 - val_accuracy: 0.8442 - val_loss: 0.4087
# Epoch 103/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8392 - loss: 0.4544 - val_accuracy: 0.8442 - val_loss: 0.4004
# Epoch 104/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8379 - loss: 0.4447 - val_accuracy: 0.8571 - val_loss: 0.3930
# Epoch 105/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8486 - loss: 0.4345 - val_accuracy: 0.8442 - val_loss: 0.3929
# Epoch 106/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8149 - loss: 0.4343 - val_accuracy: 0.8442 - val_loss: 0.3930
# Epoch 107/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8595 - loss: 0.4043 - val_accuracy: 0.8571 - val_loss: 0.3889
# Epoch 108/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8242 - loss: 0.4384 - val_accuracy: 0.8571 - val_loss: 0.3831
# Epoch 109/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8301 - loss: 0.4158 - val_accuracy: 0.8571 - val_loss: 0.3809
# Epoch 110/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8238 - loss: 0.4469 - val_accuracy: 0.8571 - val_loss: 0.3758
# Epoch 111/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8306 - loss: 0.4385 - val_accuracy: 0.8571 - val_loss: 0.3663
# Epoch 112/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8519 - loss: 0.4172 - val_accuracy: 0.8571 - val_loss: 0.3664
# Epoch 113/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8430 - loss: 0.4110 - val_accuracy: 0.8571 - val_loss: 0.3718
# Epoch 114/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8490 - loss: 0.4276 - val_accuracy: 0.8571 - val_loss: 0.3717
# Epoch 115/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8575 - loss: 0.4357 - val_accuracy: 0.8571 - val_loss: 0.3587
# Epoch 116/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8438 - loss: 0.4060 - val_accuracy: 0.8571 - val_loss: 0.3495
# Epoch 117/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8434 - loss: 0.3848 - val_accuracy: 0.8571 - val_loss: 0.3472
# Epoch 118/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8527 - loss: 0.4019 - val_accuracy: 0.8571 - val_loss: 0.3537
# Epoch 119/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8606 - loss: 0.3651 - val_accuracy: 0.8571 - val_loss: 0.3508
# Epoch 120/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8814 - loss: 0.3611 - val_accuracy: 0.8571 - val_loss: 0.3379
# Epoch 121/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8712 - loss: 0.3700 - val_accuracy: 0.8571 - val_loss: 0.3390
# Epoch 122/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8714 - loss: 0.3576 - val_accuracy: 0.8571 - val_loss: 0.3398
# Epoch 123/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8799 - loss: 0.3590 - val_accuracy: 0.8571 - val_loss: 0.3320
# Epoch 124/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8564 - loss: 0.3869 - val_accuracy: 0.8571 - val_loss: 0.3201
# Epoch 125/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8621 - loss: 0.3598 - val_accuracy: 0.8701 - val_loss: 0.3158
# Epoch 126/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8486 - loss: 0.4159 - val_accuracy: 0.8571 - val_loss: 0.3212
# Epoch 127/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8643 - loss: 0.3826 - val_accuracy: 0.8442 - val_loss: 0.3221
# Epoch 128/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8621 - loss: 0.3764 - val_accuracy: 0.8571 - val_loss: 0.3125
# Epoch 129/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8766 - loss: 0.3427 - val_accuracy: 0.8571 - val_loss: 0.3128
# Epoch 130/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8769 - loss: 0.3524 - val_accuracy: 0.8442 - val_loss: 0.3168
# Epoch 131/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8658 - loss: 0.3959 - val_accuracy: 0.8442 - val_loss: 0.3131
# Epoch 132/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8742 - loss: 0.3404 - val_accuracy: 0.8701 - val_loss: 0.3042
# Epoch 133/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8814 - loss: 0.3424 - val_accuracy: 0.8831 - val_loss: 0.2965
# Epoch 134/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8589 - loss: 0.3718 - val_accuracy: 0.8701 - val_loss: 0.2988
# Epoch 135/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8534 - loss: 0.3672 - val_accuracy: 0.8831 - val_loss: 0.2955
# Epoch 136/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8803 - loss: 0.3324 - val_accuracy: 0.8571 - val_loss: 0.2953
# Epoch 137/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8862 - loss: 0.3498 - val_accuracy: 0.8571 - val_loss: 0.2988
# Epoch 138/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8927 - loss: 0.3357 - val_accuracy: 0.8571 - val_loss: 0.2905
# Epoch 139/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8893 - loss: 0.3445 - val_accuracy: 0.8831 - val_loss: 0.2848
# Epoch 140/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8868 - loss: 0.3133 - val_accuracy: 0.8571 - val_loss: 0.2931
# Epoch 141/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8979 - loss: 0.3155 - val_accuracy: 0.8571 - val_loss: 0.2870
# Epoch 142/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8951 - loss: 0.3208 - val_accuracy: 0.8701 - val_loss: 0.2780
# Epoch 143/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8984 - loss: 0.3046 - val_accuracy: 0.8701 - val_loss: 0.2787
# Epoch 144/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9049 - loss: 0.3255 - val_accuracy: 0.8701 - val_loss: 0.2770
# Epoch 145/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9201 - loss: 0.3320 - val_accuracy: 0.8831 - val_loss: 0.2719
# Epoch 146/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8967 - loss: 0.3334 - val_accuracy: 0.8961 - val_loss: 0.2662
# Epoch 147/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8980 - loss: 0.3004 - val_accuracy: 0.8831 - val_loss: 0.2716
# Epoch 148/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8999 - loss: 0.3319 - val_accuracy: 0.8701 - val_loss: 0.2797
# Epoch 149/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8967 - loss: 0.3157 - val_accuracy: 0.8831 - val_loss: 0.2672
# Epoch 150/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8921 - loss: 0.2932 - val_accuracy: 0.8831 - val_loss: 0.2619
# Epoch 151/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8932 - loss: 0.2935 - val_accuracy: 0.8701 - val_loss: 0.2728
# Epoch 152/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9138 - loss: 0.2877 - val_accuracy: 0.8831 - val_loss: 0.2611
# Epoch 153/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9127 - loss: 0.2865 - val_accuracy: 0.9221 - val_loss: 0.2493
# Epoch 154/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9047 - loss: 0.2810 - val_accuracy: 0.8831 - val_loss: 0.2550
# Epoch 155/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9078 - loss: 0.2734 - val_accuracy: 0.8701 - val_loss: 0.2655
# Epoch 156/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9082 - loss: 0.2868 - val_accuracy: 0.8571 - val_loss: 0.2641
# Epoch 157/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9025 - loss: 0.3025 - val_accuracy: 0.8961 - val_loss: 0.2437
# Epoch 158/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9310 - loss: 0.2658 - val_accuracy: 0.8831 - val_loss: 0.2450
# Epoch 159/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9221 - loss: 0.2866 - val_accuracy: 0.8831 - val_loss: 0.2504
# Epoch 160/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9256 - loss: 0.2731 - val_accuracy: 0.8831 - val_loss: 0.2472
# Epoch 161/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9110 - loss: 0.2740 - val_accuracy: 0.9091 - val_loss: 0.2372
# Epoch 162/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9254 - loss: 0.3169 - val_accuracy: 0.8831 - val_loss: 0.2411
# Epoch 163/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9277 - loss: 0.2886 - val_accuracy: 0.8831 - val_loss: 0.2405
# Epoch 164/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9216 - loss: 0.2715 - val_accuracy: 0.8831 - val_loss: 0.2471
# Epoch 165/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9282 - loss: 0.2747 - val_accuracy: 0.8831 - val_loss: 0.2439
# Epoch 166/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9273 - loss: 0.2866 - val_accuracy: 0.8831 - val_loss: 0.2373
# Epoch 167/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9217 - loss: 0.2670 - val_accuracy: 0.9091 - val_loss: 0.2333
# Epoch 168/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9158 - loss: 0.3016 - val_accuracy: 0.8831 - val_loss: 0.2391
# Epoch 169/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9236 - loss: 0.2632 - val_accuracy: 0.8961 - val_loss: 0.2428
# Epoch 170/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9238 - loss: 0.2726 - val_accuracy: 0.9091 - val_loss: 0.2298
# Epoch 171/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9310 - loss: 0.2709 - val_accuracy: 0.9221 - val_loss: 0.2216
# Epoch 172/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9336 - loss: 0.2554 - val_accuracy: 0.9091 - val_loss: 0.2252
# Epoch 173/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9267 - loss: 0.2543 - val_accuracy: 0.8961 - val_loss: 0.2410
# Epoch 174/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9167 - loss: 0.2675 - val_accuracy: 0.9091 - val_loss: 0.2315
# Epoch 175/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9241 - loss: 0.2625 - val_accuracy: 0.9351 - val_loss: 0.2139
# Epoch 176/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9284 - loss: 0.2476 - val_accuracy: 0.8961 - val_loss: 0.2358
# Epoch 177/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9269 - loss: 0.2526 - val_accuracy: 0.9091 - val_loss: 0.2276
# Epoch 178/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9347 - loss: 0.2225 - val_accuracy: 0.9221 - val_loss: 0.2184
# Epoch 179/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9317 - loss: 0.2280 - val_accuracy: 0.9221 - val_loss: 0.2293
# Epoch 180/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9286 - loss: 0.2226 - val_accuracy: 0.9221 - val_loss: 0.2264
# Epoch 181/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9067 - loss: 0.2664 - val_accuracy: 0.9351 - val_loss: 0.2173
# Epoch 182/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9121 - loss: 0.2761 - val_accuracy: 0.9351 - val_loss: 0.2159
# Epoch 183/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9271 - loss: 0.2408 - val_accuracy: 0.9351 - val_loss: 0.2183
# Epoch 184/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9260 - loss: 0.2506 - val_accuracy: 0.9351 - val_loss: 0.2107
# Epoch 185/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9421 - loss: 0.2190 - val_accuracy: 0.9351 - val_loss: 0.2142
# Epoch 186/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9167 - loss: 0.2455 - val_accuracy: 0.9351 - val_loss: 0.2092
# Epoch 187/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9430 - loss: 0.2449 - val_accuracy: 0.9221 - val_loss: 0.2064
# Epoch 188/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9308 - loss: 0.2488 - val_accuracy: 0.9351 - val_loss: 0.2086
# Epoch 189/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9275 - loss: 0.2324 - val_accuracy: 0.9351 - val_loss: 0.2133
# Epoch 190/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9423 - loss: 0.2389 - val_accuracy: 0.9351 - val_loss: 0.2053
# Epoch 191/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9340 - loss: 0.2334 - val_accuracy: 0.9351 - val_loss: 0.2114
# Epoch 192/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9271 - loss: 0.2434 - val_accuracy: 0.9351 - val_loss: 0.2007
# Epoch 193/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9336 - loss: 0.2291 - val_accuracy: 0.9351 - val_loss: 0.1979
# Epoch 194/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9447 - loss: 0.2175 - val_accuracy: 0.9351 - val_loss: 0.1943
# Epoch 195/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9323 - loss: 0.2474 - val_accuracy: 0.9351 - val_loss: 0.2049
# Epoch 196/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9406 - loss: 0.2356 - val_accuracy: 0.9351 - val_loss: 0.2043
# Epoch 197/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9375 - loss: 0.2222 - val_accuracy: 0.9351 - val_loss: 0.1980
# Epoch 198/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9395 - loss: 0.2258 - val_accuracy: 0.9351 - val_loss: 0.1963
# Epoch 199/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9369 - loss: 0.2231 - val_accuracy: 0.9351 - val_loss: 0.2006
# Epoch 200/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9399 - loss: 0.2352 - val_accuracy: 0.9351 - val_loss: 0.2050
# Epoch 201/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9393 - loss: 0.2281 - val_accuracy: 0.9351 - val_loss: 0.1970
# Epoch 202/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9451 - loss: 0.2101 - val_accuracy: 0.9351 - val_loss: 0.1932
# Epoch 203/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9332 - loss: 0.2346 - val_accuracy: 0.9351 - val_loss: 0.1879
# Epoch 204/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9540 - loss: 0.1812 - val_accuracy: 0.9351 - val_loss: 0.2001
# Epoch 205/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9465 - loss: 0.1975 - val_accuracy: 0.9351 - val_loss: 0.1915
# Epoch 206/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9386 - loss: 0.2419 - val_accuracy: 0.9351 - val_loss: 0.1831
# Epoch 207/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9538 - loss: 0.2282 - val_accuracy: 0.9351 - val_loss: 0.1896
# Epoch 208/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9558 - loss: 0.1952 - val_accuracy: 0.9351 - val_loss: 0.2015
# Epoch 209/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9517 - loss: 0.2113 - val_accuracy: 0.9351 - val_loss: 0.1952
# Epoch 210/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9432 - loss: 0.2322 - val_accuracy: 0.9351 - val_loss: 0.1872
# Epoch 211/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9491 - loss: 0.2067 - val_accuracy: 0.9351 - val_loss: 0.1805
# Epoch 212/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9564 - loss: 0.1888 - val_accuracy: 0.9351 - val_loss: 0.1878
# Epoch 213/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9428 - loss: 0.2199 - val_accuracy: 0.9351 - val_loss: 0.2037
# Epoch 214/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9449 - loss: 0.2075 - val_accuracy: 0.9351 - val_loss: 0.1767
# Epoch 215/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9491 - loss: 0.2179 - val_accuracy: 0.9481 - val_loss: 0.1723
# Epoch 216/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9432 - loss: 0.2088 - val_accuracy: 0.9351 - val_loss: 0.1930
# Epoch 217/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9282 - loss: 0.2074 - val_accuracy: 0.9351 - val_loss: 0.1812
# Epoch 218/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9517 - loss: 0.1758 - val_accuracy: 0.9481 - val_loss: 0.1718
# Epoch 219/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9417 - loss: 0.2084 - val_accuracy: 0.9351 - val_loss: 0.1890
# Epoch 220/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9354 - loss: 0.1816 - val_accuracy: 0.9351 - val_loss: 0.1905
# Epoch 221/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9401 - loss: 0.2091 - val_accuracy: 0.9351 - val_loss: 0.1678
# Epoch 222/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9406 - loss: 0.1936 - val_accuracy: 0.9351 - val_loss: 0.1687
# Epoch 223/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9532 - loss: 0.1950 - val_accuracy: 0.9351 - val_loss: 0.1805
# Epoch 224/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9419 - loss: 0.2158 - val_accuracy: 0.9351 - val_loss: 0.1786
# Epoch 225/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9510 - loss: 0.1823 - val_accuracy: 0.9351 - val_loss: 0.1748
# Epoch 226/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9591 - loss: 0.1833 - val_accuracy: 0.9351 - val_loss: 0.1746
# Epoch 227/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9484 - loss: 0.1656 - val_accuracy: 0.9351 - val_loss: 0.1684
# Epoch 228/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9530 - loss: 0.1672 - val_accuracy: 0.9351 - val_loss: 0.1692
# Epoch 229/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9376 - loss: 0.2317 - val_accuracy: 0.9351 - val_loss: 0.1722
# Epoch 230/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9523 - loss: 0.1831 - val_accuracy: 0.9351 - val_loss: 0.1674
# Epoch 231/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9539 - loss: 0.1646 - val_accuracy: 0.9351 - val_loss: 0.1719
# Epoch 232/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9458 - loss: 0.1795 - val_accuracy: 0.9351 - val_loss: 0.1767
# Epoch 233/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9673 - loss: 0.1603 - val_accuracy: 0.9351 - val_loss: 0.1813
# Epoch 234/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9613 - loss: 0.1744 - val_accuracy: 0.9351 - val_loss: 0.1696
# Epoch 235/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9571 - loss: 0.1617 - val_accuracy: 0.9481 - val_loss: 0.1546
# Epoch 236/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9587 - loss: 0.1828 - val_accuracy: 0.9351 - val_loss: 0.1766
# Epoch 237/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9632 - loss: 0.1631 - val_accuracy: 0.9351 - val_loss: 0.1845
# Epoch 238/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9360 - loss: 0.1768 - val_accuracy: 0.9351 - val_loss: 0.1617
# Epoch 239/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9487 - loss: 0.1812 - val_accuracy: 0.9481 - val_loss: 0.1595
# Epoch 240/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9501 - loss: 0.1734 - val_accuracy: 0.9351 - val_loss: 0.1734
# Epoch 241/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9491 - loss: 0.1943 - val_accuracy: 0.9481 - val_loss: 0.1567
# Epoch 242/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9552 - loss: 0.1552 - val_accuracy: 0.9481 - val_loss: 0.1568
# Epoch 243/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9369 - loss: 0.1777 - val_accuracy: 0.9351 - val_loss: 0.1648
# Epoch 244/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9415 - loss: 0.1988 - val_accuracy: 0.9351 - val_loss: 0.1659
# Epoch 245/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9521 - loss: 0.1667 - val_accuracy: 0.9351 - val_loss: 0.1672
# Epoch 246/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9611 - loss: 0.1509 - val_accuracy: 0.9351 - val_loss: 0.1652
# Epoch 247/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9408 - loss: 0.1620 - val_accuracy: 0.9351 - val_loss: 0.1591
# Epoch 248/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9580 - loss: 0.1397 - val_accuracy: 0.9351 - val_loss: 0.1607
# Epoch 249/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9600 - loss: 0.1401 - val_accuracy: 0.9481 - val_loss: 0.1681
# Epoch 250/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9534 - loss: 0.1582 - val_accuracy: 0.9351 - val_loss: 0.1543
# Epoch 251/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9732 - loss: 0.1520 - val_accuracy: 0.9481 - val_loss: 0.1479
# Epoch 252/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9595 - loss: 0.1517 - val_accuracy: 0.9481 - val_loss: 0.1526
# Epoch 253/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9632 - loss: 0.1399 - val_accuracy: 0.9481 - val_loss: 0.1659
# Epoch 254/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9663 - loss: 0.1332 - val_accuracy: 0.9481 - val_loss: 0.1558
# Epoch 255/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9545 - loss: 0.1560 - val_accuracy: 0.9481 - val_loss: 0.1527
# Epoch 256/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9569 - loss: 0.1426 - val_accuracy: 0.9481 - val_loss: 0.1616
# Epoch 257/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9628 - loss: 0.1430 - val_accuracy: 0.9481 - val_loss: 0.1555
# Epoch 258/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9643 - loss: 0.1401 - val_accuracy: 0.9610 - val_loss: 0.1620
# Epoch 259/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9693 - loss: 0.1439 - val_accuracy: 0.9481 - val_loss: 0.1546
# Epoch 260/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9691 - loss: 0.1104 - val_accuracy: 0.9481 - val_loss: 0.1515
# Epoch 261/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9691 - loss: 0.1694 - val_accuracy: 0.9481 - val_loss: 0.1567
# Epoch 262/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9726 - loss: 0.1412 - val_accuracy: 0.9610 - val_loss: 0.1573
# Epoch 263/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9691 - loss: 0.1294 - val_accuracy: 0.9481 - val_loss: 0.1503
# Epoch 264/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9643 - loss: 0.1525 - val_accuracy: 0.9481 - val_loss: 0.1598
# Epoch 265/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9591 - loss: 0.1147 - val_accuracy: 0.9481 - val_loss: 0.1603
# Epoch 266/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9632 - loss: 0.1360 - val_accuracy: 0.9610 - val_loss: 0.1318
# Epoch 267/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9615 - loss: 0.1551 - val_accuracy: 0.9610 - val_loss: 0.1500
# Epoch 268/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9567 - loss: 0.1216 - val_accuracy: 0.9481 - val_loss: 0.1614
# Epoch 269/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9671 - loss: 0.1180 - val_accuracy: 0.9740 - val_loss: 0.1414
# Epoch 270/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9747 - loss: 0.1172 - val_accuracy: 0.9740 - val_loss: 0.1417
# Epoch 271/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9593 - loss: 0.1260 - val_accuracy: 0.9481 - val_loss: 0.1587
# Epoch 272/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9539 - loss: 0.1657 - val_accuracy: 0.9740 - val_loss: 0.1473
# Epoch 273/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9637 - loss: 0.1266 - val_accuracy: 0.9610 - val_loss: 0.1333
# Epoch 274/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9680 - loss: 0.1392 - val_accuracy: 0.9740 - val_loss: 0.1465
# Epoch 275/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9663 - loss: 0.1170 - val_accuracy: 0.9481 - val_loss: 0.1557
# Epoch 276/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9676 - loss: 0.1232 - val_accuracy: 0.9740 - val_loss: 0.1454
# Epoch 277/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9691 - loss: 0.1296 - val_accuracy: 0.9740 - val_loss: 0.1354
# Epoch 278/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9787 - loss: 0.1178 - val_accuracy: 0.9740 - val_loss: 0.1444
# Epoch 279/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9636 - loss: 0.1375 - val_accuracy: 0.9610 - val_loss: 0.1492
# Epoch 280/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9765 - loss: 0.1248 - val_accuracy: 0.9740 - val_loss: 0.1445
# Epoch 281/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9743 - loss: 0.1005 - val_accuracy: 0.9610 - val_loss: 0.1596
# Epoch 282/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9708 - loss: 0.1348 - val_accuracy: 0.9740 - val_loss: 0.1442
# Epoch 283/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9747 - loss: 0.1297 - val_accuracy: 0.9740 - val_loss: 0.1299
# Epoch 284/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9554 - loss: 0.1268 - val_accuracy: 0.9740 - val_loss: 0.1359
# Epoch 285/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9832 - loss: 0.1070 - val_accuracy: 0.9610 - val_loss: 0.1436
# Epoch 286/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9678 - loss: 0.1101 - val_accuracy: 0.9610 - val_loss: 0.1331
# Epoch 287/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9763 - loss: 0.1397 - val_accuracy: 0.9740 - val_loss: 0.1330
# Epoch 288/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9543 - loss: 0.1229 - val_accuracy: 0.9740 - val_loss: 0.1489
# Epoch 289/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9758 - loss: 0.1030 - val_accuracy: 0.9740 - val_loss: 0.1345
# Epoch 290/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9769 - loss: 0.1025 - val_accuracy: 0.9740 - val_loss: 0.1273
# Epoch 291/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9650 - loss: 0.1288 - val_accuracy: 0.9740 - val_loss: 0.1477
# Epoch 292/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9691 - loss: 0.1218 - val_accuracy: 0.9740 - val_loss: 0.1437
# Epoch 293/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9763 - loss: 0.1018 - val_accuracy: 0.9740 - val_loss: 0.1305
# Epoch 294/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9643 - loss: 0.1044 - val_accuracy: 0.9610 - val_loss: 0.1299
# Epoch 295/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9802 - loss: 0.1048 - val_accuracy: 0.9610 - val_loss: 0.1432
# Epoch 296/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9654 - loss: 0.1005 - val_accuracy: 0.9610 - val_loss: 0.1456
# Epoch 297/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9743 - loss: 0.1061 - val_accuracy: 0.9610 - val_loss: 0.1350
# Epoch 298/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9706 - loss: 0.0988 - val_accuracy: 0.9610 - val_loss: 0.1351
# Epoch 299/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9728 - loss: 0.1072 - val_accuracy: 0.9610 - val_loss: 0.1359
# Epoch 300/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9778 - loss: 0.1268 - val_accuracy: 0.9740 - val_loss: 0.1342
# Epoch 301/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9843 - loss: 0.0996 - val_accuracy: 0.9740 - val_loss: 0.1328
# Epoch 302/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9730 - loss: 0.0873 - val_accuracy: 0.9740 - val_loss: 0.1315
# Epoch 303/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9791 - loss: 0.1012 - val_accuracy: 0.9740 - val_loss: 0.1338
# Epoch 304/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9628 - loss: 0.1260 - val_accuracy: 0.9740 - val_loss: 0.1288
# Epoch 305/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9756 - loss: 0.1006 - val_accuracy: 0.9740 - val_loss: 0.1374
# Epoch 306/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9728 - loss: 0.0864 - val_accuracy: 0.9610 - val_loss: 0.1342
# Epoch 307/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9847 - loss: 0.0828 - val_accuracy: 0.9740 - val_loss: 0.1256
# Epoch 308/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9774 - loss: 0.1022 - val_accuracy: 0.9740 - val_loss: 0.1280
# Epoch 309/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9815 - loss: 0.1053 - val_accuracy: 0.9740 - val_loss: 0.1278
# Epoch 310/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9680 - loss: 0.1149 - val_accuracy: 0.9740 - val_loss: 0.1150
# Epoch 311/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9678 - loss: 0.1148 - val_accuracy: 0.9740 - val_loss: 0.1267
# Epoch 312/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9754 - loss: 0.0954 - val_accuracy: 0.9740 - val_loss: 0.1291
# Epoch 313/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9748 - loss: 0.1074 - val_accuracy: 0.9740 - val_loss: 0.1255
# Epoch 314/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9867 - loss: 0.0788 - val_accuracy: 0.9740 - val_loss: 0.1252
# Epoch 315/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9704 - loss: 0.0932 - val_accuracy: 0.9610 - val_loss: 0.1249
# Epoch 316/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9887 - loss: 0.0703 - val_accuracy: 0.9740 - val_loss: 0.1389
# Epoch 317/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9735 - loss: 0.1240 - val_accuracy: 0.9610 - val_loss: 0.1215
# Epoch 318/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9702 - loss: 0.1150 - val_accuracy: 0.9740 - val_loss: 0.1217
# Epoch 319/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9641 - loss: 0.1139 - val_accuracy: 0.9740 - val_loss: 0.1333
# Epoch 320/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9759 - loss: 0.1079 - val_accuracy: 0.9740 - val_loss: 0.1108
# Epoch 321/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9822 - loss: 0.0889 - val_accuracy: 0.9740 - val_loss: 0.1118
# Epoch 322/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9765 - loss: 0.0935 - val_accuracy: 0.9740 - val_loss: 0.1233
# Epoch 323/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9813 - loss: 0.0801 - val_accuracy: 0.9740 - val_loss: 0.1226
# Epoch 324/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9895 - loss: 0.0851 - val_accuracy: 0.9740 - val_loss: 0.1219
# Epoch 325/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9713 - loss: 0.0928 - val_accuracy: 0.9740 - val_loss: 0.1179
# Epoch 326/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9911 - loss: 0.0662 - val_accuracy: 0.9610 - val_loss: 0.1170
# Epoch 327/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9765 - loss: 0.0950 - val_accuracy: 0.9610 - val_loss: 0.1207
# Epoch 328/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9804 - loss: 0.0710 - val_accuracy: 0.9610 - val_loss: 0.1276
# Epoch 329/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9719 - loss: 0.0881 - val_accuracy: 0.9610 - val_loss: 0.1282
# Epoch 330/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9795 - loss: 0.0976 - val_accuracy: 0.9610 - val_loss: 0.1225
# Epoch 331/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9843 - loss: 0.0786 - val_accuracy: 0.9740 - val_loss: 0.1246
# Epoch 332/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9869 - loss: 0.0857 - val_accuracy: 0.9740 - val_loss: 0.1230
# Epoch 333/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9852 - loss: 0.1030 - val_accuracy: 0.9740 - val_loss: 0.1202
# Epoch 334/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9758 - loss: 0.0779 - val_accuracy: 0.9740 - val_loss: 0.1242
# Epoch 335/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9826 - loss: 0.0819 - val_accuracy: 0.9740 - val_loss: 0.1236
# Epoch 336/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9848 - loss: 0.0932 - val_accuracy: 0.9740 - val_loss: 0.1150
# Epoch 337/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9869 - loss: 0.0839 - val_accuracy: 0.9740 - val_loss: 0.1154
# Epoch 338/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9917 - loss: 0.0596 - val_accuracy: 0.9740 - val_loss: 0.1225
# Epoch 339/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9843 - loss: 0.0749 - val_accuracy: 0.9740 - val_loss: 0.1166
# Epoch 340/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9791 - loss: 0.0843 - val_accuracy: 0.9610 - val_loss: 0.1127
# Epoch 341/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9904 - loss: 0.0663 - val_accuracy: 0.9610 - val_loss: 0.1201
# Epoch 342/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9811 - loss: 0.0862 - val_accuracy: 0.9610 - val_loss: 0.1247
# Epoch 343/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9761 - loss: 0.0762 - val_accuracy: 0.9610 - val_loss: 0.1206
# Epoch 344/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9889 - loss: 0.0744 - val_accuracy: 0.9610 - val_loss: 0.1179
# Epoch 345/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9800 - loss: 0.0658 - val_accuracy: 0.9610 - val_loss: 0.1225
# Epoch 346/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9798 - loss: 0.0645 - val_accuracy: 0.9610 - val_loss: 0.1175
# Epoch 347/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9789 - loss: 0.0821 - val_accuracy: 0.9610 - val_loss: 0.1121
# Epoch 348/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9856 - loss: 0.0774 - val_accuracy: 0.9610 - val_loss: 0.1224
# Epoch 349/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9817 - loss: 0.0667 - val_accuracy: 0.9740 - val_loss: 0.1258
# Epoch 350/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9869 - loss: 0.0560 - val_accuracy: 0.9740 - val_loss: 0.1134
# Epoch 351/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9841 - loss: 0.0920 - val_accuracy: 0.9740 - val_loss: 0.1034
# Epoch 352/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9789 - loss: 0.0941 - val_accuracy: 0.9610 - val_loss: 0.1346
# Epoch 353/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9817 - loss: 0.1070 - val_accuracy: 0.9610 - val_loss: 0.1276
# Epoch 354/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9772 - loss: 0.0843 - val_accuracy: 0.9610 - val_loss: 0.1125
# Epoch 355/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9719 - loss: 0.0971 - val_accuracy: 0.9740 - val_loss: 0.1177
# Epoch 356/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9772 - loss: 0.0714 - val_accuracy: 0.9610 - val_loss: 0.1232
# Epoch 357/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9756 - loss: 0.0789 - val_accuracy: 0.9610 - val_loss: 0.1252
# Epoch 358/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9887 - loss: 0.0684 - val_accuracy: 0.9610 - val_loss: 0.1167
# Epoch 359/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9763 - loss: 0.0797 - val_accuracy: 0.9610 - val_loss: 0.1109
# Epoch 360/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9806 - loss: 0.0735 - val_accuracy: 0.9740 - val_loss: 0.1143
# Epoch 361/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9854 - loss: 0.0740 - val_accuracy: 0.9740 - val_loss: 0.1129
# Epoch 362/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9895 - loss: 0.0535 - val_accuracy: 0.9740 - val_loss: 0.1166
# Epoch 363/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9902 - loss: 0.0637 - val_accuracy: 0.9740 - val_loss: 0.1119
# Epoch 364/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9776 - loss: 0.0815 - val_accuracy: 0.9740 - val_loss: 0.1138
# Epoch 365/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9915 - loss: 0.0635 - val_accuracy: 0.9740 - val_loss: 0.1240
# Epoch 366/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9869 - loss: 0.0572 - val_accuracy: 0.9740 - val_loss: 0.1204
# Epoch 367/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9782 - loss: 0.0657 - val_accuracy: 0.9740 - val_loss: 0.1107
# Epoch 368/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9889 - loss: 0.0494 - val_accuracy: 0.9740 - val_loss: 0.1118
# Epoch 369/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9904 - loss: 0.0578 - val_accuracy: 0.9740 - val_loss: 0.1155

# %% [markdown]
# #### Visualize Training Performance

# %%
# Get training and validation accuracy and loss from the history object
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation accuracy
plt.figure()
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
# Plot training and validation loss
plt.figure()
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
# Get the final accuracy and loss for the last epoch
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

# Print the final accuracy and loss
print("Final Training Accuracy:", final_train_acc)
print("Final Validation Accuracy:", final_val_acc)
print("Final Training Loss:", final_train_loss)
print("Final Validation Loss:", final_val_loss)
# Out:
# Final Training Accuracy: 0.9836065769195557
# Final Validation Accuracy: 0.9740259647369385
# Final Training Loss: 0.08281803876161575
# Final Validation Loss: 0.11554747819900513

# %%
# Save the entire model as a `.keras` zip archive.
combined_model.save('MTFN_32Rank.keras')

# %% [markdown]
# ## Visualizations

# %% [markdown]
# #### VGG Feature Maps

# %%
iterator = iter(train_dataset)
first_element, label = next(iterator)

# %%
# Load the existing model (if needed)
# combined_model = tf.keras.models.load_model('AD_Multimodal_Model.keras')

# Choose a layer to visualize (e.g., the output of the first convolutional layer)
layer_name = 'block1_conv1'
intermediate_layer_model = tf.keras.models.Model(inputs=combined_model.input, outputs=combined_model.get_layer(layer_name).output)

# Load and preprocess an image
def load_and_preprocess_image(image_path):
    img = tf.keras.utils.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.vgg16.preprocess_input(img_array)
    return img_array

image_path = '/home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I124297.png'
preprocessed_image = load_and_preprocess_image(image_path)

# Get the feature maps
feature_maps = intermediate_layer_model.predict(first_element)

# Visualize the feature maps
def visualize_feature_maps(feature_maps):
    num_feature_maps = feature_maps.shape[-1]
    
    # Determine the layout for subplots (adjust as needed)
    grid_size = int(np.ceil(np.sqrt(num_feature_maps)))
    
    plt.figure(figsize=(12, 12))
    for i in range(num_feature_maps):
        plt.subplot(grid_size, grid_size, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(feature_maps[0, :, :, i], cmap='gray')
    plt.show()

visualize_feature_maps(feature_maps)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step

# %%
plt.imshow(feature_maps[0, :, :, 1], cmap='CMRmap')
# plt.savefig('VGG_Feature_Map.png', dpi=300)  # Save as PNG with 300 DPI

# %% [markdown]
# ValueError: 'green' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
