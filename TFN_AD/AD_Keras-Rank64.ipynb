# %% [markdown]
# ## Imports

# %%
import keras
import numpy as np

import time

import os

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow.keras.layers as tfl

# import misc

import pandas as pd

import datetime

import glob

from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, GlobalAveragePooling2D, Input, Conv1D, MaxPooling1D, Flatten, \
                                    Masking, LSTM, Softmax, Multiply, Layer, Concatenate, Lambda, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# from keras.utils import np_utils
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.datasets import load_files
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
# import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.preprocessing import image_dataset_from_directory

from sklearn.model_selection import train_test_split

import tensorly as tl
from tensorly.decomposition import tucker
# Out:
# 2025-03-05 03:03:18.206988: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741172598.231598   56788 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741172598.238190   56788 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-05 03:03:18.265369: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set up imports & packages.

tl.set_backend('tensorflow')  # Use TensorFlow tensors instead of NumPy

# %% [markdown]
# ## Declare Sub-Models

# %%
# Default 16.
feature_vector_size = 64

# %% [markdown]
# ### Visual Embedder (VGG-16)

# %%
def build_visual_embedder():
    # Load the VGG16 model without the top layers
    visual_base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze the base model to retain pretrained weights during training
    visual_base_model.trainable = False

    # Add a top for 3-way classification
    x = visual_base_model.output
    x = GlobalAveragePooling2D()(x)  # Global Average Pooling layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(512, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization
    x = Dense(256, activation='relu')(x)  # Fully connected layer
    x = Dropout(0.1)(x)              # Dropout for regularization

    visual_base_features = Dense(feature_vector_size, activation='relu')(x) 

    # Define the final model
    visual_model = Model(inputs=visual_base_model.input, outputs=visual_base_features, name="VisualEmbedder")
    return visual_model

# %% [markdown]
# ### Demographic Embedder

# %%
def build_demographics_embedder():
    # Input layer for demographics data
    input_layer = Input(shape=(6, ), name="demographics_input")

    x = Dense(16, activation='relu')(input_layer)
    x = Dropout(0.1)(x)
    x = Dense(4, activation='relu')(x)
    x = Dropout(0.1)(x)
    
    # Classification head
    demographics_base_features = Dense(feature_vector_size, activation='relu')(x)
    
    # Define the model
    demographics_model = Model(inputs=input_layer, outputs=demographics_base_features, name="DemographicsEmbedder")
    return demographics_model

# %% [markdown]
# ### Time-Series Embedder

# %%
max_seq_length = 6

# %%
def build_time_embedder():
    # Input layer for time series data (4 input variables)
    time_series_input = Input(shape=(max_seq_length, 4), name="time_series_input")
    masked_input = Masking(mask_value=0.0)(time_series_input)

    # Use the last hidden state
    x = LSTM(32, return_sequences=False)(masked_input)

    # Dense layer to create time series output
    time_base_features = Dense(feature_vector_size, activation="relu")(x)
    
    # Define the model
    time_model = Model(inputs=time_series_input, outputs=time_base_features, name="TimeSeriesEmbedder")
    return time_model

# %% [markdown]
# ## Joint Model

# %%
visual_dim = feature_vector_size
demographics_dim = feature_vector_size
time_dim = feature_vector_size

# Tensor Fusion Layer
def tensor_fusion_layer(inputs):
    """
    Tensor fusion using Kronecker product via `tf.einsum`.
    Adds a 1 to each input tensor for core (0,0,0) alignment.
    """
    visual, demographics, time_series = inputs

    # Add a "1" to the feature vectors
    visual_h = tf.concat([tf.ones((tf.shape(visual)[0], 1)), visual], axis=1)
    demographics_h = tf.concat([tf.ones((tf.shape(demographics)[0], 1)), demographics], axis=1)
    time_series_h = tf.concat([tf.ones((tf.shape(time_series)[0], 1)), time_series], axis=1)

    # Perform Kronecker product using tf.einsum
    outer_xy = tf.einsum('bi,bj->bij', demographics_h, time_series_h)  # Shape: (batch_size, d_dim, t_dim)
    outer_xyz = tf.einsum('bij,bk->bijk', outer_xy, visual_h)  # Shape: (batch_size, d_dim, t_dim, v_dim)

    # core, factors = tucker(outer_xyz, rank=(8,8,8))

    # # Flatten the fused tensor
    fused_tensor = tf.reshape(outer_xyz, (tf.shape(outer_xyz)[0], -1))  # Shape: (batch_size, d_dim * t_dim * v_dim)

    return fused_tensor #outer_xyz

# %%
# Visual embedder
visual_embedder = build_visual_embedder()

# Demographics embedder
demographics_embedder = build_demographics_embedder()

# Time Series Embedder
time_embedder = build_time_embedder()

# Outputs from embedders
visual_features = visual_embedder.output
demographics_features = demographics_embedder.output
time_features = time_embedder.output

# Output shape of the fused tensor
fused_tensor_shape = (None, (visual_dim + 1) * (demographics_dim + 1) * (time_dim + 1))

# Apply Tensor Fusion
fused_features = Lambda(tensor_fusion_layer, output_shape=fused_tensor_shape)([visual_features, demographics_features, time_features])

# Add final classification layers
x = Dense(128, activation='relu')(fused_features)
x = Dense(64, activation='relu')(x)
final_output = Dense(3, activation='softmax', name="final_output")(x)

# Define the combined model
combined_model = Model(inputs=[visual_embedder.input, demographics_embedder.input, time_embedder.input], 
                       outputs=final_output, name="CombinedModel")
# Out:
# W0000 00:00:1741172603.341451   56788 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# #### Joint-Model Structure

# %%
combined_model.summary()
# Out:
# Model: "CombinedModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 224, 224,  │      1,792 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 224, 224,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 112, 112,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 112, 112,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 112, 112,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 56, 56,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 56, 56,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 56, 56,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 56, 56,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 28, 28,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 28, 28,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 28, 28,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 28, 28,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 14, 14,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 14, 14,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 14, 14,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 14, 14,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_pool         │ (None, 7, 7, 512) │          0 │ block5_conv3[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ block5_pool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    262,656 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ demographics_input  │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    262,656 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │        112 │ demographics_inp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_series_input   │ (None, 6, 4)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 6, 4)      │          0 │ time_series_inpu… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4)         │         68 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 6, 4)      │          0 │ time_series_inpu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 6)         │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4)         │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 32)        │      4,736 │ masking[0][0],    │
# │                     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │     16,448 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │        320 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 64)        │      2,112 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, None,      │          0 │ dense_3[0][0],    │
# │                     │ 274625)           │            │ dense_6[0][0],    │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, None, 128) │ 35,152,128 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, None, 64)  │      8,256 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, None, 3)   │        195 │ dense_9[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 50,555,703 (192.85 MB)
#  Trainable params: 35,841,015 (136.72 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# # Train Joint-Model

# %% [markdown]
# #### Load Data

# %%
# Mapping for string labels to integers
label_mapping = {"CN": 0, "MCI": 1, "Dementia": 2}

# %%
manifest = pd.read_csv("/home/mason/TFN_AD/AD_Patient_Manifest.csv")

# %%
# Load all data into memory. Not elegant, but works.
def load_all_data(manifest, target_size=(224, 224), demographic_columns=None, time_series_columns=None, label_mapping=None):
    image_data = []
    demographics_data = []
    time_series_data = []
    labels = []
    label_mapping = label_mapping or {}

    for _, row in manifest.iterrows():
        patient_path = row["path"]
        patient_df = pd.read_pickle(patient_path)

        # Load image data
        image_paths = [patient_df['image_path'].iloc[0]]
        for path in image_paths:
            img = load_img(path, target_size=target_size)
            img_array = img_to_array(img)
            img_array = preprocess_input(img_array)
            image_data.append(img_array)

        # Process demographics data
        if demographic_columns is None:
            raise ValueError("Please specify the demographics columns.")
        
        # Get first row of demographic data (since it doesn't change over time)
        demographics = patient_df[demographic_columns].iloc[0]
        demographics = demographics.values.astype(np.float32)  # Convert to NumPy array
        demographics_data.append(demographics)

        # Process time series data
        if time_series_columns is None:
            raise ValueError("Please specify the time series columns.")
        
        # Extract the relevant time series columns
        time_series = patient_df[time_series_columns].values  # Extract as NumPy array

        # Truncate or pad to max_seq_length
        if len(time_series) > max_seq_length:
            time_series = time_series[:max_seq_length, :]
        elif len(time_series) < max_seq_length:
            padding = np.zeros((max_seq_length - len(time_series), len(time_series_columns)))
            time_series = np.vstack([time_series, padding])
        time_series_data.append(time_series)

        # Load labels
        label_str = patient_df['DX'].iloc[0]
        label_int = label_mapping[label_str]
        labels.append(label_int)

    # Convert to numpy arrays
    image_data = np.array(image_data, dtype=np.float32)
    demographics_data = np.array(demographics_data, dtype=np.float32)
    time_series_data = np.array(time_series_data, dtype=np.float32)
    labels = np.array(labels, dtype=np.int32)

    return image_data, demographics_data, time_series_data, labels

# %%
# Demographic variables to extract
demographic_columns = ['AGE', 'PTEDUCAT', 'PTGENDER_encoded', 
                        'PTETHCAT_encoded', 'PTRACCAT_encoded', 'PTMARRY_encoded']
# Time series variables to extract
time_series_columns = ['Years_bl', 'ADAS11', 'ADAS13', 'ADASQ4']

# Load all data into memory
image_data, demographics_data, time_series_data, labels = load_all_data(manifest, target_size=(224, 224), demographic_columns=demographic_columns, 
                                                      time_series_columns=time_series_columns, label_mapping=label_mapping)

# Split the data
test_size = 0.2  # 20% of the data for testing

(image_train, image_test,
 demographics_train, demographics_test,
 time_train, time_test,
 labels_train, labels_test) = train_test_split(
    image_data, demographics_data, time_series_data, labels, test_size=test_size, random_state=42, stratify=labels
)

# %%
batch_size = 64

# Create training dataset
train_dataset = tf.data.Dataset.from_tensor_slices(((image_train, demographics_train, time_train), labels_train))
train_dataset = train_dataset.shuffle(100).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Create testing (validation) dataset
test_dataset = tf.data.Dataset.from_tensor_slices(((image_test, demographics_test, time_test), labels_test))
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
print(f"Image train shape: {image_train.shape}")
print(f"Demographics train shape: {demographics_train.shape}")
print(f"Time train shape: {time_train.shape}")
print(f"Labels train shape: {labels_train.shape}")
# Out:
# Image train shape: (305, 224, 224, 3)
# Demographics train shape: (305, 6)
# Time train shape: (305, 6, 4)
# Labels train shape: (305,)

# %% [markdown]
# #### Train the Model

# %%
# Compile the model
combined_model.compile(optimizer=Adam(learning_rate=0.0001),
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

# %%
print("Model inputs:", combined_model.input)
# Out:
# Model inputs: [<KerasTensor shape=(None, 224, 224, 3), dtype=float32, sparse=False, name=keras_tensor>, <KerasTensor shape=(None, 6), dtype=float32, sparse=False, name=demographics_input>, <KerasTensor shape=(None, 6, 4), dtype=float32, sparse=False, name=time_series_input>]

# %%
# Early stopping to prevent redundant training.
early_stopping = EarlyStopping(monitor='val_accuracy', patience=100, restore_best_weights=True)

# %%
# Train the model
history = combined_model.fit(
    train_dataset, 
    validation_data=test_dataset,
    epochs=600,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/600
# /home/mason/.conda/envs/LOSresearch/lib/python3.9/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'demographics_input', 'time_series_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - accuracy: 0.4272 - loss: 2.4185 - val_accuracy: 0.4416 - val_loss: 1.1511
# Epoch 2/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.5343 - loss: 1.3998 - val_accuracy: 0.5195 - val_loss: 0.9792
# Epoch 3/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6048 - loss: 0.9235 - val_accuracy: 0.7143 - val_loss: 0.7558
# Epoch 4/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6711 - loss: 0.7609 - val_accuracy: 0.7013 - val_loss: 0.7620
# Epoch 5/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.6699 - loss: 0.7744 - val_accuracy: 0.7143 - val_loss: 0.6901
# Epoch 6/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.7077 - loss: 0.6752 - val_accuracy: 0.8052 - val_loss: 0.6087
# Epoch 7/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8266 - loss: 0.5197 - val_accuracy: 0.7662 - val_loss: 0.5667
# Epoch 8/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.7851 - loss: 0.5667 - val_accuracy: 0.8182 - val_loss: 0.5329
# Epoch 9/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8107 - loss: 0.5427 - val_accuracy: 0.8312 - val_loss: 0.4924
# Epoch 10/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8207 - loss: 0.5035 - val_accuracy: 0.7792 - val_loss: 0.5039
# Epoch 11/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8179 - loss: 0.4774 - val_accuracy: 0.8312 - val_loss: 0.4437
# Epoch 12/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8162 - loss: 0.4220 - val_accuracy: 0.8312 - val_loss: 0.4500
# Epoch 13/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8523 - loss: 0.3751 - val_accuracy: 0.8312 - val_loss: 0.4265
# Epoch 14/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8386 - loss: 0.4146 - val_accuracy: 0.8442 - val_loss: 0.4140
# Epoch 15/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8238 - loss: 0.4087 - val_accuracy: 0.8442 - val_loss: 0.3959
# Epoch 16/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8638 - loss: 0.3398 - val_accuracy: 0.8312 - val_loss: 0.4324
# Epoch 17/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8910 - loss: 0.2902 - val_accuracy: 0.8182 - val_loss: 0.4669
# Epoch 18/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8780 - loss: 0.3577 - val_accuracy: 0.8442 - val_loss: 0.3514
# Epoch 19/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8508 - loss: 0.4597 - val_accuracy: 0.8442 - val_loss: 0.3564
# Epoch 20/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8664 - loss: 0.2976 - val_accuracy: 0.8182 - val_loss: 0.4722
# Epoch 21/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8623 - loss: 0.3260 - val_accuracy: 0.8571 - val_loss: 0.3691
# Epoch 22/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8834 - loss: 0.3176 - val_accuracy: 0.8312 - val_loss: 0.4776
# Epoch 23/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8888 - loss: 0.2922 - val_accuracy: 0.8961 - val_loss: 0.3474
# Epoch 24/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8877 - loss: 0.2948 - val_accuracy: 0.8442 - val_loss: 0.3884
# Epoch 25/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8884 - loss: 0.3071 - val_accuracy: 0.8312 - val_loss: 0.3580
# Epoch 26/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8717 - loss: 0.2922 - val_accuracy: 0.8961 - val_loss: 0.3091
# Epoch 27/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9190 - loss: 0.2592 - val_accuracy: 0.8182 - val_loss: 0.4760
# Epoch 28/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8806 - loss: 0.3347 - val_accuracy: 0.9221 - val_loss: 0.3098
# Epoch 29/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8877 - loss: 0.2893 - val_accuracy: 0.8701 - val_loss: 0.3596
# Epoch 30/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8864 - loss: 0.3041 - val_accuracy: 0.8701 - val_loss: 0.3338
# Epoch 31/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8930 - loss: 0.2536 - val_accuracy: 0.8701 - val_loss: 0.3068
# Epoch 32/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9341 - loss: 0.2259 - val_accuracy: 0.8701 - val_loss: 0.3438
# Epoch 33/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9119 - loss: 0.2356 - val_accuracy: 0.9091 - val_loss: 0.2949
# Epoch 34/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.8967 - loss: 0.2440 - val_accuracy: 0.8701 - val_loss: 0.3630
# Epoch 35/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9282 - loss: 0.2037 - val_accuracy: 0.8312 - val_loss: 0.3114
# Epoch 36/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9619 - loss: 0.1619 - val_accuracy: 0.9221 - val_loss: 0.2856
# Epoch 37/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9022 - loss: 0.2314 - val_accuracy: 0.8442 - val_loss: 0.3901
# Epoch 38/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9198 - loss: 0.2685 - val_accuracy: 0.8831 - val_loss: 0.3456
# Epoch 39/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9343 - loss: 0.1861 - val_accuracy: 0.9091 - val_loss: 0.2771
# Epoch 40/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9091 - loss: 0.2327 - val_accuracy: 0.8182 - val_loss: 0.3509
# Epoch 41/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8975 - loss: 0.2630 - val_accuracy: 0.8312 - val_loss: 0.4323
# Epoch 42/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9152 - loss: 0.2549 - val_accuracy: 0.8571 - val_loss: 0.3683
# Epoch 43/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8880 - loss: 0.2294 - val_accuracy: 0.8831 - val_loss: 0.3508
# Epoch 44/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9399 - loss: 0.1531 - val_accuracy: 0.8831 - val_loss: 0.3372
# Epoch 45/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9173 - loss: 0.1959 - val_accuracy: 0.8831 - val_loss: 0.3523
# Epoch 46/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9213 - loss: 0.1709 - val_accuracy: 0.9221 - val_loss: 0.2992
# Epoch 47/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9238 - loss: 0.1709 - val_accuracy: 0.8571 - val_loss: 0.4501
# Epoch 48/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9407 - loss: 0.1741 - val_accuracy: 0.9091 - val_loss: 0.2974
# Epoch 49/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9460 - loss: 0.1425 - val_accuracy: 0.9221 - val_loss: 0.2641
# Epoch 50/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9700 - loss: 0.1127 - val_accuracy: 0.9091 - val_loss: 0.3137
# Epoch 51/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9634 - loss: 0.1226 - val_accuracy: 0.9221 - val_loss: 0.2545
# Epoch 52/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9565 - loss: 0.1466 - val_accuracy: 0.9091 - val_loss: 0.2769
# Epoch 53/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9708 - loss: 0.0933 - val_accuracy: 0.9091 - val_loss: 0.2813
# Epoch 54/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9595 - loss: 0.1153 - val_accuracy: 0.9091 - val_loss: 0.3100
# Epoch 55/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9765 - loss: 0.1051 - val_accuracy: 0.8961 - val_loss: 0.3986
# Epoch 56/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9495 - loss: 0.1322 - val_accuracy: 0.9091 - val_loss: 0.3860
# Epoch 57/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9497 - loss: 0.1460 - val_accuracy: 0.9091 - val_loss: 0.2971
# Epoch 58/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9491 - loss: 0.1426 - val_accuracy: 0.8831 - val_loss: 0.4450
# Epoch 59/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9695 - loss: 0.1342 - val_accuracy: 0.9091 - val_loss: 0.3129
# Epoch 60/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9471 - loss: 0.1460 - val_accuracy: 0.7532 - val_loss: 0.6057
# Epoch 61/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9045 - loss: 0.2763 - val_accuracy: 0.9221 - val_loss: 0.2973
# Epoch 62/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9589 - loss: 0.1232 - val_accuracy: 0.8571 - val_loss: 0.5473
# Epoch 63/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9217 - loss: 0.2113 - val_accuracy: 0.8831 - val_loss: 0.3519
# Epoch 64/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9502 - loss: 0.1417 - val_accuracy: 0.8442 - val_loss: 0.3820
# Epoch 65/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9158 - loss: 0.2029 - val_accuracy: 0.8312 - val_loss: 0.6579
# Epoch 66/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9113 - loss: 0.2964 - val_accuracy: 0.9221 - val_loss: 0.2649
# Epoch 67/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9741 - loss: 0.1274 - val_accuracy: 0.8701 - val_loss: 0.4172
# Epoch 68/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9687 - loss: 0.1379 - val_accuracy: 0.8961 - val_loss: 0.2909
# Epoch 69/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9756 - loss: 0.1024 - val_accuracy: 0.8961 - val_loss: 0.3422
# Epoch 70/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9759 - loss: 0.0762 - val_accuracy: 0.8961 - val_loss: 0.3062
# Epoch 71/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9687 - loss: 0.0842 - val_accuracy: 0.8831 - val_loss: 0.2716
# Epoch 72/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9598 - loss: 0.1006 - val_accuracy: 0.8831 - val_loss: 0.3968
# Epoch 73/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9643 - loss: 0.1159 - val_accuracy: 0.9091 - val_loss: 0.3045
# Epoch 74/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9569 - loss: 0.1086 - val_accuracy: 0.9221 - val_loss: 0.2784
# Epoch 75/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9719 - loss: 0.0911 - val_accuracy: 0.8312 - val_loss: 0.5975
# Epoch 76/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9652 - loss: 0.0913 - val_accuracy: 0.8961 - val_loss: 0.2954
# Epoch 77/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9817 - loss: 0.0684 - val_accuracy: 0.8701 - val_loss: 0.4908
# Epoch 78/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9689 - loss: 0.0940 - val_accuracy: 0.9221 - val_loss: 0.2963
# Epoch 79/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9750 - loss: 0.0740 - val_accuracy: 0.9221 - val_loss: 0.2926
# Epoch 80/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9813 - loss: 0.0529 - val_accuracy: 0.8961 - val_loss: 0.3744
# Epoch 81/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9769 - loss: 0.0584 - val_accuracy: 0.9221 - val_loss: 0.2356
# Epoch 82/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9611 - loss: 0.0936 - val_accuracy: 0.9091 - val_loss: 0.2790
# Epoch 83/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9765 - loss: 0.0583 - val_accuracy: 0.9091 - val_loss: 0.2630
# Epoch 84/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9904 - loss: 0.0303 - val_accuracy: 0.9351 - val_loss: 0.1911
# Epoch 85/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9798 - loss: 0.0919 - val_accuracy: 0.9221 - val_loss: 0.2835
# Epoch 86/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9891 - loss: 0.0338 - val_accuracy: 0.9221 - val_loss: 0.2157
# Epoch 87/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9709 - loss: 0.0560 - val_accuracy: 0.9221 - val_loss: 0.3041
# Epoch 88/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9878 - loss: 0.0384 - val_accuracy: 0.9221 - val_loss: 0.2281
# Epoch 89/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9861 - loss: 0.0357 - val_accuracy: 0.9091 - val_loss: 0.2703
# Epoch 90/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9778 - loss: 0.0462 - val_accuracy: 0.8961 - val_loss: 0.3665
# Epoch 91/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9793 - loss: 0.0694 - val_accuracy: 0.8831 - val_loss: 0.5253
# Epoch 92/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9265 - loss: 0.2661 - val_accuracy: 0.8961 - val_loss: 0.4543
# Epoch 93/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9617 - loss: 0.1127 - val_accuracy: 0.8701 - val_loss: 0.5994
# Epoch 94/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9810 - loss: 0.0797 - val_accuracy: 0.9221 - val_loss: 0.2706
# Epoch 95/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9863 - loss: 0.0575 - val_accuracy: 0.8961 - val_loss: 0.4558
# Epoch 96/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9793 - loss: 0.0691 - val_accuracy: 0.8961 - val_loss: 0.2972
# Epoch 97/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9678 - loss: 0.0688 - val_accuracy: 0.9091 - val_loss: 0.3303
# Epoch 98/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9904 - loss: 0.0443 - val_accuracy: 0.9091 - val_loss: 0.4917
# Epoch 99/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9643 - loss: 0.0979 - val_accuracy: 0.9091 - val_loss: 0.3866
# Epoch 100/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9974 - loss: 0.0313 - val_accuracy: 0.8961 - val_loss: 0.4278
# Epoch 101/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9983 - loss: 0.0215 - val_accuracy: 0.9091 - val_loss: 0.3302
# Epoch 102/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9767 - loss: 0.0460 - val_accuracy: 0.9091 - val_loss: 0.3134
# Epoch 103/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9867 - loss: 0.0406 - val_accuracy: 0.9091 - val_loss: 0.3638
# Epoch 104/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9715 - loss: 0.0555 - val_accuracy: 0.8961 - val_loss: 0.3000
# Epoch 105/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9917 - loss: 0.0273 - val_accuracy: 0.9221 - val_loss: 0.3384
# Epoch 106/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9922 - loss: 0.0308 - val_accuracy: 0.9221 - val_loss: 0.3171
# Epoch 107/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9898 - loss: 0.0346 - val_accuracy: 0.9091 - val_loss: 0.3948
# Epoch 108/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9756 - loss: 0.0415 - val_accuracy: 0.9091 - val_loss: 0.3005
# Epoch 109/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9917 - loss: 0.0260 - val_accuracy: 0.9091 - val_loss: 0.3740
# Epoch 110/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9776 - loss: 0.0605 - val_accuracy: 0.8961 - val_loss: 0.3540
# Epoch 111/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9956 - loss: 0.0211 - val_accuracy: 0.9351 - val_loss: 0.3970
# Epoch 112/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9806 - loss: 0.0495 - val_accuracy: 0.8831 - val_loss: 0.6909
# Epoch 113/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9756 - loss: 0.0529 - val_accuracy: 0.9351 - val_loss: 0.2777
# Epoch 114/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9835 - loss: 0.0315 - val_accuracy: 0.8961 - val_loss: 0.5839
# Epoch 115/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - accuracy: 0.9672 - loss: 0.0864 - val_accuracy: 0.9481 - val_loss: 0.3172
# Epoch 116/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9839 - loss: 0.0391 - val_accuracy: 0.9221 - val_loss: 0.3723
# Epoch 117/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9906 - loss: 0.0316 - val_accuracy: 0.9091 - val_loss: 0.3901
# Epoch 118/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9878 - loss: 0.0253 - val_accuracy: 0.9221 - val_loss: 0.2688
# Epoch 119/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9935 - loss: 0.0270 - val_accuracy: 0.8961 - val_loss: 0.5000
# Epoch 120/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9950 - loss: 0.0280 - val_accuracy: 0.9221 - val_loss: 0.2936
# Epoch 121/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9956 - loss: 0.0149 - val_accuracy: 0.8961 - val_loss: 0.8466
# Epoch 122/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9870 - loss: 0.0410 - val_accuracy: 0.9610 - val_loss: 0.2415
# Epoch 123/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9739 - loss: 0.0681 - val_accuracy: 0.9221 - val_loss: 0.5477
# Epoch 124/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9869 - loss: 0.0405 - val_accuracy: 0.9481 - val_loss: 0.2430
# Epoch 125/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9935 - loss: 0.0232 - val_accuracy: 0.9091 - val_loss: 0.3037
# Epoch 126/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9874 - loss: 0.0279 - val_accuracy: 0.9221 - val_loss: 0.2545
# Epoch 127/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9748 - loss: 0.0658 - val_accuracy: 0.8961 - val_loss: 0.6406
# Epoch 128/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9722 - loss: 0.0607 - val_accuracy: 0.9481 - val_loss: 0.2319
# Epoch 129/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9726 - loss: 0.0664 - val_accuracy: 0.9091 - val_loss: 0.4688
# Epoch 130/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9943 - loss: 0.0163 - val_accuracy: 0.9610 - val_loss: 0.1951
# Epoch 131/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9935 - loss: 0.0222 - val_accuracy: 0.9091 - val_loss: 0.3937
# Epoch 132/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9726 - loss: 0.0504 - val_accuracy: 0.9481 - val_loss: 0.1960
# Epoch 133/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9700 - loss: 0.1223 - val_accuracy: 0.8701 - val_loss: 0.7025
# Epoch 134/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9835 - loss: 0.0610 - val_accuracy: 0.9610 - val_loss: 0.3799
# Epoch 135/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9726 - loss: 0.0664 - val_accuracy: 0.8701 - val_loss: 0.5842
# Epoch 136/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9906 - loss: 0.0421 - val_accuracy: 0.9351 - val_loss: 0.3553
# Epoch 137/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9896 - loss: 0.0270 - val_accuracy: 0.8701 - val_loss: 0.5956
# Epoch 138/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9972 - loss: 0.0218 - val_accuracy: 0.9091 - val_loss: 0.3874
# Epoch 139/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9893 - loss: 0.0450 - val_accuracy: 0.8961 - val_loss: 0.4919
# Epoch 140/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.8961 - val_loss: 0.4596
# Epoch 141/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9935 - loss: 0.0281 - val_accuracy: 0.9351 - val_loss: 0.3080
# Epoch 142/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9956 - loss: 0.0126 - val_accuracy: 0.9091 - val_loss: 0.4443
# Epoch 143/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9956 - loss: 0.0200 - val_accuracy: 0.9091 - val_loss: 0.5303
# Epoch 144/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9852 - loss: 0.0279 - val_accuracy: 0.9610 - val_loss: 0.2567
# Epoch 145/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9804 - loss: 0.0294 - val_accuracy: 0.9221 - val_loss: 0.4483
# Epoch 146/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9961 - loss: 0.0153 - val_accuracy: 0.9221 - val_loss: 0.3687
# Epoch 147/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9924 - loss: 0.0182 - val_accuracy: 0.9221 - val_loss: 0.3811
# Epoch 148/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9983 - loss: 0.0101 - val_accuracy: 0.9221 - val_loss: 0.4307
# Epoch 149/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9974 - loss: 0.0151 - val_accuracy: 0.9221 - val_loss: 0.3987
# Epoch 150/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9956 - loss: 0.0098 - val_accuracy: 0.9481 - val_loss: 0.2844
# Epoch 151/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9989 - loss: 0.0173 - val_accuracy: 0.9221 - val_loss: 0.4011
# Epoch 152/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9091 - val_loss: 0.5537
# Epoch 153/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9917 - loss: 0.0129 - val_accuracy: 0.9091 - val_loss: 0.4399
# Epoch 154/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9974 - loss: 0.0149 - val_accuracy: 0.9091 - val_loss: 0.5432
# Epoch 155/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9935 - loss: 0.0213 - val_accuracy: 0.9610 - val_loss: 0.2726
# Epoch 156/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9610 - val_loss: 0.2870
# Epoch 157/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.9091 - val_loss: 0.4425
# Epoch 158/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9935 - loss: 0.0467 - val_accuracy: 0.9610 - val_loss: 0.2941
# Epoch 159/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9880 - loss: 0.0305 - val_accuracy: 0.9091 - val_loss: 0.6482
# Epoch 160/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.9221 - val_loss: 0.6055
# Epoch 161/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0167 - val_accuracy: 0.9481 - val_loss: 0.3489
# Epoch 162/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0115 - val_accuracy: 0.9221 - val_loss: 0.4660
# Epoch 163/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.9091 - val_loss: 0.7049
# Epoch 164/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9861 - loss: 0.0397 - val_accuracy: 0.9610 - val_loss: 0.3398
# Epoch 165/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9885 - loss: 0.0624 - val_accuracy: 0.8961 - val_loss: 0.8654
# Epoch 166/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9833 - loss: 0.0454 - val_accuracy: 0.9091 - val_loss: 0.6058
# Epoch 167/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9926 - loss: 0.0301 - val_accuracy: 0.9091 - val_loss: 0.4596
# Epoch 168/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9946 - loss: 0.0220 - val_accuracy: 0.9091 - val_loss: 0.4657
# Epoch 169/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9930 - loss: 0.0372 - val_accuracy: 0.8961 - val_loss: 0.6689
# Epoch 170/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9859 - loss: 0.0747 - val_accuracy: 0.9091 - val_loss: 0.6730
# Epoch 171/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9351 - val_loss: 0.4626
# Epoch 172/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9896 - loss: 0.0385 - val_accuracy: 0.8961 - val_loss: 0.9348
# Epoch 173/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9961 - loss: 0.0143 - val_accuracy: 0.8961 - val_loss: 0.7343
# Epoch 174/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0099 - val_accuracy: 0.9221 - val_loss: 0.5188
# Epoch 175/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9939 - loss: 0.0145 - val_accuracy: 0.9091 - val_loss: 0.5378
# Epoch 176/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9978 - loss: 0.0130 - val_accuracy: 0.8961 - val_loss: 0.5920
# Epoch 177/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9961 - loss: 0.0106 - val_accuracy: 0.9091 - val_loss: 0.5410
# Epoch 178/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9974 - loss: 0.0106 - val_accuracy: 0.9221 - val_loss: 0.4490
# Epoch 179/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9830 - loss: 0.0420 - val_accuracy: 0.9091 - val_loss: 0.5560
# Epoch 180/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9943 - loss: 0.0343 - val_accuracy: 0.8961 - val_loss: 0.6243
# Epoch 181/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9935 - loss: 0.0153 - val_accuracy: 0.8961 - val_loss: 0.8169
# Epoch 182/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9961 - loss: 0.0167 - val_accuracy: 0.9351 - val_loss: 0.3735
# Epoch 183/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9961 - loss: 0.0149 - val_accuracy: 0.9351 - val_loss: 0.3936
# Epoch 184/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9091 - val_loss: 0.6213
# Epoch 185/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9989 - loss: 0.0138 - val_accuracy: 0.9091 - val_loss: 0.4912
# Epoch 186/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9989 - loss: 0.0101 - val_accuracy: 0.9351 - val_loss: 0.4283
# Epoch 187/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9091 - val_loss: 0.6279
# Epoch 188/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0188 - val_accuracy: 0.9351 - val_loss: 0.4219
# Epoch 189/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.9610 - val_loss: 0.3689
# Epoch 190/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9948 - loss: 0.0164 - val_accuracy: 0.9091 - val_loss: 0.6443
# Epoch 191/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9974 - loss: 0.0089 - val_accuracy: 0.9091 - val_loss: 0.6436
# Epoch 192/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9351 - val_loss: 0.4403
# Epoch 193/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 0.9091 - val_loss: 0.5865
# Epoch 194/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9952 - loss: 0.0159 - val_accuracy: 0.9351 - val_loss: 0.4804
# Epoch 195/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9909 - loss: 0.0197 - val_accuracy: 0.9091 - val_loss: 0.7028
# Epoch 196/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9939 - loss: 0.0217 - val_accuracy: 0.9091 - val_loss: 0.8012
# Epoch 197/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9974 - loss: 0.0197 - val_accuracy: 0.9091 - val_loss: 0.6858
# Epoch 198/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8831 - val_loss: 0.9386
# Epoch 199/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.8831 - val_loss: 0.9157
# Epoch 200/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.9091 - val_loss: 0.6710
# Epoch 201/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9989 - loss: 0.0089 - val_accuracy: 0.9351 - val_loss: 0.5443
# Epoch 202/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9865 - loss: 0.0272 - val_accuracy: 0.9221 - val_loss: 0.5759
# Epoch 203/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9922 - loss: 0.0170 - val_accuracy: 0.9091 - val_loss: 0.6247
# Epoch 204/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9972 - loss: 0.0055 - val_accuracy: 0.9091 - val_loss: 0.8755
# Epoch 205/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0123 - val_accuracy: 0.9351 - val_loss: 0.4248
# Epoch 206/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9708 - loss: 0.1016 - val_accuracy: 0.9221 - val_loss: 0.5930
# Epoch 207/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9878 - loss: 0.0624 - val_accuracy: 0.9221 - val_loss: 0.5485
# Epoch 208/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9869 - loss: 0.0537 - val_accuracy: 0.9221 - val_loss: 0.6425
# Epoch 209/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.9695 - loss: 0.0872 - val_accuracy: 0.9351 - val_loss: 0.5745
# Epoch 210/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9756 - loss: 0.1162 - val_accuracy: 0.8701 - val_loss: 0.8053
# Epoch 211/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9804 - loss: 0.0479 - val_accuracy: 0.9481 - val_loss: 0.3911
# Epoch 212/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9817 - loss: 0.0654 - val_accuracy: 0.8831 - val_loss: 0.6689
# Epoch 213/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9889 - loss: 0.0296 - val_accuracy: 0.9221 - val_loss: 0.6091
# Epoch 214/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9909 - loss: 0.0265 - val_accuracy: 0.9221 - val_loss: 0.4725
# Epoch 215/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9091 - val_loss: 0.8337
# Epoch 216/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9883 - loss: 0.0249 - val_accuracy: 0.9351 - val_loss: 0.4032
# Epoch 217/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 0.9351 - val_loss: 0.3819
# Epoch 218/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9974 - loss: 0.0156 - val_accuracy: 0.9221 - val_loss: 0.4758
# Epoch 219/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0103 - val_accuracy: 0.9221 - val_loss: 0.5583
# Epoch 220/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.9221 - val_loss: 0.6039
# Epoch 221/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0085 - val_accuracy: 0.9351 - val_loss: 0.5315
# Epoch 222/600
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9481 - val_loss: 0.4323

# %% [markdown]
# #### Visualize Training Performance

# %%
# Get training and validation accuracy and loss from the history object
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot training and validation accuracy
plt.figure()
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
# Plot training and validation loss
plt.figure()
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
# Get the final accuracy and loss for the last epoch
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

# Print the final accuracy and loss
print("Final Training Accuracy:", final_train_acc)
print("Final Validation Accuracy:", final_val_acc)
print("Final Training Loss:", final_train_loss)
print("Final Validation Loss:", final_val_loss)
# Out:
# Final Training Accuracy: 0.9967213273048401
# Final Validation Accuracy: 0.948051929473877
# Final Training Loss: 0.007515904027968645
# Final Validation Loss: 0.4323091506958008

# %%
# Save the entire model as a `.keras` zip archive.
combined_model.save('MTFN_32Rank.keras')

# %% [markdown]
# ## Visualizations

# %% [markdown]
# #### VGG Feature Maps

# %%
iterator = iter(train_dataset)
first_element, label = next(iterator)

# %%
# Load the existing model (if needed)
# combined_model = tf.keras.models.load_model('AD_Multimodal_Model.keras')

# Choose a layer to visualize (e.g., the output of the first convolutional layer)
layer_name = 'block1_conv1'
intermediate_layer_model = tf.keras.models.Model(inputs=combined_model.input, outputs=combined_model.get_layer(layer_name).output)

# Load and preprocess an image
def load_and_preprocess_image(image_path):
    img = tf.keras.utils.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.vgg16.preprocess_input(img_array)
    return img_array

image_path = '/home/mason/ADNI_Dataset/ADNI_IMG_32.5%_x/I124297.png'
preprocessed_image = load_and_preprocess_image(image_path)

# Get the feature maps
feature_maps = intermediate_layer_model.predict(first_element)

# Visualize the feature maps
def visualize_feature_maps(feature_maps):
    num_feature_maps = feature_maps.shape[-1]
    
    # Determine the layout for subplots (adjust as needed)
    grid_size = int(np.ceil(np.sqrt(num_feature_maps)))
    
    plt.figure(figsize=(12, 12))
    for i in range(num_feature_maps):
        plt.subplot(grid_size, grid_size, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(feature_maps[0, :, :, i], cmap='gray')
    plt.show()

visualize_feature_maps(feature_maps)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
plt.imshow(feature_maps[0, :, :, 1], cmap='CMRmap')
# plt.savefig('VGG_Feature_Map.png', dpi=300)  # Save as PNG with 300 DPI

# %% [markdown]
# ValueError: 'green' is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'
